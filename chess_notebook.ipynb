# %%
import os
import shutil
import subprocess
import time

def remove_folder_if_exists(folder_path: str) -> None:
    """
    Checks if a directory at `folder_path` exists,
    and deletes it if it does.
    """
    if os.path.exists(folder_path) and os.path.isdir(folder_path):
        print(f"Removing existing folder: {folder_path}")
        shutil.rmtree(folder_path)
    else:
        print(f"Folder does not exist: {folder_path}")

def activate_window(window_name):
    """
    Search for a visible window by name, activate it, and return its ID.
    """
    search_cmd = ['xdotool', 'search', '--onlyvisible', '--name', window_name]
    try:
        window_ids = subprocess.check_output(search_cmd).decode('utf-8').split()
        if not window_ids:
            print(f"No matching window found for '{window_name}'.")
            return None
        window_id = window_ids[0]
        print(f"Found window ID for '{window_name}': {window_id}")
        # Activate the window without --sync to reduce delay.
        subprocess.run(['xdotool', 'windowactivate', window_id], stderr=subprocess.DEVNULL)
        # A very short delay to let the activation register.
        time.sleep(0.1)
        return window_id
    except subprocess.CalledProcessError:
        print(f"Error: Could not find or activate window '{window_name}'.")
        return None
        
def next_move():
    # 1. Activate the "Black side" window.
    black_window = activate_window('Black side')
    
    # 2. Activate the "White side" window.
    white_window = activate_window('White side')
    
    # 3. Once the second window ("White side") is activated, send the space key.
    if white_window is not None:
        subprocess.run(['xdotool', 'key', 'space'], stderr=subprocess.DEVNULL)
        # Optionally, verify the active window.
        active_window = subprocess.check_output(
            ['xdotool', 'getactivewindow', 'getwindowname']
        ).decode('utf-8').strip()
        print("Active window now:", active_window)
    else:
        print("Could not activate 'White side', so no key press was sent.")

#home the robots
def home_red():
    # !python /home/jacob/Documents/robot_control/move_home.py red

def home_blue():
    # !python /home/jacob/Documents/robot_control/move_home.py blue

def move_red():
    #move the red robot
    remove_folder_if_exists("/home/jacob/.cache/huggingface/lerobot/Chojins/eval_chess_game_001_red_stereo")
    
    # !python lerobot/scripts/control_robot.py \
      --robot.type=so100-red \
      --control.type=record \
      --control.fps=30 \
      --control.single_task="Move the blue chess pieces as indicated by the highlighted squares" \
      --control.repo_id=Chojins/eval_chess_game_001_red_stereo \
      --control.tags='["tutorial"]' \
      --control.warmup_time_s=0 \
      --control.episode_time_s=30 \
      --control.reset_time_s=30 \
      --control.num_episodes=1 \
      --control.push_to_hub=false \
      --control.policy.path=/home/jacob/lerobot/outputs/train/chess_game_001_red_stereo/checkpoints/last/pretrained_model \
      2>&1 | head -20

def move_blue():
    #move the blue robot
    remove_folder_if_exists("/home/jacob/.cache/huggingface/lerobot/Chojins/eval_chess_game_001_blue_stereo")
    
    # !python lerobot/scripts/control_robot.py \
      --robot.type=so100-blue \
      --control.type=record \
      --control.fps=30 \
      --control.single_task="Move the blue chess pieces as indicated by the highlighted squares" \
      --control.repo_id=Chojins/eval_chess_game_001_blue_stereo \
      --control.tags='["tutorial"]' \
      --control.warmup_time_s=0 \
      --control.episode_time_s=30 \
      --control.reset_time_s=30 \
      --control.num_episodes=1 \
      --control.push_to_hub=false \
      --control.policy.path=/home/jacob/lerobot/outputs/train/chess_game_001_blue_stereo/checkpoints/last/pretrained_model\
      2>&1 | head -20

# %%
# !python /home/jacob/Documents/robot_control/move_home.py blue
# Out:
# Loaded home positions from /home/jacob/lerobot/.cache/calibration/so100/blue_home_position.json
# Connected to blue robot on port /dev/ttyACM2
# Calibration loaded.
# Moving to preset position...
# Positions after moving to preset:
#   shoulder_pan: -0.18
#   shoulder_lift: 163.74
#   elbow_flex: 123.75
#   wrist_flex: 78.93
#   wrist_roll: -100.81
#   gripper: 0.53
# Moving to home position...
# Final positions (home):
#   shoulder_pan: -1.05
#   shoulder_lift: 181.05
#   elbow_flex: 134.65
#   wrist_flex: 84.46
#   wrist_roll: -88.24
#   gripper: 0.53
# Disconnected.

# %%
# !python /home/jacob/Documents/robot_control/move_home.py red
# Out:
# Loaded home positions from /home/jacob/lerobot/.cache/calibration/so100/red_home_position.json
# Connected to red robot on port /dev/ttyACM1
# Calibration loaded.
# Moving to preset position...
# Positions after moving to preset:
#   shoulder_pan: -0.44
#   shoulder_lift: 163.74
#   elbow_flex: 124.19
#   wrist_flex: 79.10
#   wrist_roll: -100.81
#   gripper: 0.44
# Moving to home position...
# Final positions (home):
#   shoulder_pan: -0.44
#   shoulder_lift: 179.74
#   elbow_flex: 131.66
#   wrist_flex: 87.19
#   wrist_roll: -90.00
#   gripper: 0.59
# Disconnected.

# %%
#move the blue robot
next_move()

remove_folder_if_exists("/home/jacob/.cache/huggingface/lerobot/Chojins/eval_chess_game_001_blue_stereo")

# !python lerobot/scripts/control_robot.py \
  --robot.type=so100-blue \
  --control.type=record \
  --control.fps=30 \
  --control.single_task="Move the blue chess pieces as indicated by the highlighted squares" \
  --control.repo_id=Chojins/eval_chess_game_001_blue_stereo \
  --control.tags='["tutorial"]' \
  --control.warmup_time_s=0 \
  --control.episode_time_s=30 \
  --control.reset_time_s=30 \
  --control.num_episodes=1 \
  --control.push_to_hub=false \
  --control.policy.path=/home/jacob/lerobot/outputs/train/chess_game_001_blue_stereo/checkpoints/last/pretrained_model\
  2>&1 | head -20

#home
# !python /home/jacob/Documents/robot_control/move_home.py blue
# Out:
# Found window ID for 'Black side': 8388626
# Found window ID for 'White side': 8388630
# Active window now: White side
# Removing existing folder: /home/jacob/.cache/huggingface/lerobot/Chojins/eval_chess_game_001_blue_stereo
# INFO 2025-04-13 17:14:46 ol_robot.py:369 {'control': {'display_cameras': True,
#              'episode_time_s': 30,
#              'fps': 30,
#              'num_episodes': 1,
#              'num_image_writer_processes': 0,
#              'num_image_writer_threads_per_camera': 4,
#              'play_sounds': True,
#              'policy': {'chunk_size': 100,
#                         'device': 'cuda',
#                         'dim_feedforward': 3200,
#                         'dim_model': 512,
#                         'dropout': 0.1,
#                         'feedforward_activation': 'relu',
#                         'input_features': {'observation.images.laptop': {'shape': (3,
#                                                                                    480,
#                                                                                    640),
#                                                                          'type': <FeatureType.VISUAL: 'VISUAL'>},
#                                            'observation.images.phone': {'shape': (3,
#                                                                                   480,
#                                                                                   640),
# ^C
# Loaded home positions from /home/jacob/lerobot/.cache/calibration/so100/blue_home_position.json
# Connected to blue robot on port /dev/ttyACM2
# Calibration loaded.
# Moving to preset position...
# Positions after moving to preset:
#   shoulder_pan: -0.26
#   shoulder_lift: 127.79
#   elbow_flex: 120.59
#   wrist_flex: 77.61
#   wrist_roll: -100.72
#   gripper: 0.38
# Moving to home position...
# Final positions (home):
#   shoulder_pan: -1.05
#   shoulder_lift: 180.88
#   elbow_flex: 134.74
#   wrist_flex: 84.38
#   wrist_roll: -88.51
#   gripper: 0.38
# Disconnected.

# %%
#move the red robot
next_move()

remove_folder_if_exists("/home/jacob/.cache/huggingface/lerobot/Chojins/eval_chess_game_001_red_stereo")

# !python lerobot/scripts/control_robot.py \
  --robot.type=so100-red \
  --control.type=record \
  --control.fps=30 \
  --control.single_task="Move the blue chess pieces as indicated by the highlighted squares" \
  --control.repo_id=Chojins/eval_chess_game_001_red_stereo \
  --control.tags='["tutorial"]' \
  --control.warmup_time_s=0 \
  --control.episode_time_s=30 \
  --control.reset_time_s=30 \
  --control.num_episodes=1 \
  --control.push_to_hub=false \
  --control.policy.path=/home/jacob/lerobot/outputs/train/chess_game_001_red_stereo/checkpoints/last/pretrained_model \
  2>&1 | head -20

#home
# !python /home/jacob/Documents/robot_control/move_home.py red
# Out:
# Found window ID for 'Black side': 8388626
# Found window ID for 'White side': 8388630
# Active window now: White side
# Removing existing folder: /home/jacob/.cache/huggingface/lerobot/Chojins/eval_chess_game_001_red_stereo
# INFO 2025-04-13 17:12:52 ol_robot.py:369 {'control': {'display_cameras': True,
#              'episode_time_s': 30,
#              'fps': 30,
#              'num_episodes': 1,
#              'num_image_writer_processes': 0,
#              'num_image_writer_threads_per_camera': 4,
#              'play_sounds': True,
#              'policy': {'chunk_size': 100,
#                         'device': 'cuda',
#                         'dim_feedforward': 3200,
#                         'dim_model': 512,
#                         'dropout': 0.1,
#                         'feedforward_activation': 'relu',
#                         'input_features': {'observation.images.laptop': {'shape': (3,
#                                                                                    480,
#                                                                                    640),
#                                                                          'type': <FeatureType.VISUAL: 'VISUAL'>},
#                                            'observation.images.phone': {'shape': (3,
#                                                                                   480,
#                                                                                   640),
# ^C
# Loaded home positions from /home/jacob/lerobot/.cache/calibration/so100/red_home_position.json
# Connected to red robot on port /dev/ttyACM1
# Calibration loaded.
# Moving to preset position...
# Positions after moving to preset:
#   shoulder_pan: 0.09
#   shoulder_lift: 160.93
#   elbow_flex: 123.49
#   wrist_flex: 77.78
#   wrist_roll: -102.13
#   gripper: 0.51
# Moving to home position...
# Final positions (home):
#   shoulder_pan: -0.35
#   shoulder_lift: 179.47
#   elbow_flex: 131.57
#   wrist_flex: 87.28
#   wrist_roll: -90.09
#   gripper: 0.66
# Disconnected.

# %%
#add a single episode to the Red dataset
#Red side 'stereo' dataset record instruction
# !python lerobot/scripts/control_robot.py \
  --robot.type=so100-red \
  --control.type=record \
  --control.fps=30 \
  --control.single_task="Move the red chess pieces as indicated by the highlighted squares" \
  --control.repo_id="Chojins/chess_game_001_red_stereo" \
  --control.tags='["so100","chess"]' \
  --control.warmup_time_s=25 \
  --control.episode_time_s=360 \
  --control.reset_time_s=20 \
  --control.num_episodes=1 \
  --control.push_to_hub=true \
  --control.resume=true 

#home
# !python /home/jacob/Documents/robot_control/move_home.py red
# Out:
# INFO 2025-04-13 17:11:15 ol_robot.py:369 {'control': {'display_cameras': True,
#              'episode_time_s': 360,
#              'fps': 30,
#              'num_episodes': 1,
#              'num_image_writer_processes': 0,
#              'num_image_writer_threads_per_camera': 4,
#              'play_sounds': True,
#              'policy': None,
#              'private': False,
#              'push_to_hub': True,
#              'repo_id': 'Chojins/chess_game_001_red_stereo',
#              'reset_time_s': 20,
#              'resume': True,
#              'root': None,
#              'single_task': 'Move the red chess pieces as indicated by the '
#                             'highlighted squares',
#              'tags': ['so100', 'chess'],
#              'video': True,
#              'warmup_time_s': 25},
#  'robot': {'calibration_dir': '.cache/calibration/so100-red',
#            'cameras': {'laptop': {'camera_index': 5,
#                                   'channels': 3,
#                                   'color_mode': 'rgb',
#                                   'fps': 30,
#                                   'height': 480,
#                                   'mock': False,
#                                   'rotation': None,
#                                   'width': 640},
#                        'phone': {'camera_index': 4,
#                                  'channels': 3,
#                                  'color_mode': 'rgb',
#                                  'fps': 30,
#                                  'height': 480,
#                                  'mock': False,
#                                  'rotation': None,
#                                  'width': 640}},
#            'follower_arms': {'main': {'mock': False,
#                                       'motors': {'elbow_flex': [3, 'sts3215'],
#                                                  'gripper': [6, 'sts3215'],
#                                                  'shoulder_lift': [2,
#                                                                    'sts3215'],
#                                                  'shoulder_pan': [1, 'sts3215'],
#                                                  'wrist_flex': [4, 'sts3215'],
#                                                  'wrist_roll': [5, 'sts3215']},
#                                       'port': '/dev/ttyACM1'}},
#            'gripper_open_degree': None,
#            'leader_arms': {'main': {'mock': False,
#                                     'motors': {'elbow_flex': [3, 'sts3215'],
#                                                'gripper': [6, 'sts3215'],
#                                                'shoulder_lift': [2, 'sts3215'],
#                                                'shoulder_pan': [1, 'sts3215'],
#                                                'wrist_flex': [4, 'sts3215'],
#                                                'wrist_roll': [5, 'sts3215']},
#                                     'port': '/dev/ttyACM0'}},
#            'max_relative_target': None,
#            'mock': False}}
# Resolving data files: 100%|████████████████| 267/267 [00:00<00:00, 72059.66it/s]
# Downloading data: 100%|█████████████████| 267/267 [00:00<00:00, 51942.45files/s]
# Generating train split: 100324 examples [00:00, 653084.23 examples/s]
# Connecting main follower arm.
# Connecting main leader arm.
# Activating torque on main follower arm.
# INFO 2025-04-13 17:11:18 ls/utils.py:200 Warmup record
# INFO 2025-04-13 17:11:18 rol_utils.py:82 dt:201.40 (5.0hz) dtRlead: 1.67 (597.5hz) dtWfoll: 0.21 (4687.3hz) dtRfoll: 1.73 (576.7hz) dtRlaptop:35.10 (28.5hz) dtRphone:38.69 (25.8hz)
# INFO 2025-04-13 17:11:18 rol_utils.py:82 dt:33.40 (29.9hz) dtRlead: 1.63 (614.4hz) dtWfoll: 0.23 (4305.8hz) dtRfoll: 1.67 (597.3hz) dtRlaptop:24.25 (41.2hz) dtRphone:23.16 (43.2hz)
# INFO 2025-04-13 17:11:18 rol_utils.py:82 dt:33.48 (29.9hz) dtRlead: 1.62 (618.5hz) dtWfoll: 0.26 (3808.4hz) dtRfoll: 1.76 (568.4hz) dtRlaptop:34.87 (28.7hz) dtRphone:35.16 (28.4hz)
# INFO 2025-04-13 17:11:18 rol_utils.py:82 dt:33.42 (29.9hz) dtRlead: 2.08 (481.0hz) dtWfoll: 0.55 (1827.5hz) dtRfoll: 2.14 (467.2hz) dtRlaptop:34.87 (28.7hz) dtRphone:35.16 (28.4hz)
# INFO 2025-04-13 17:11:18 rol_utils.py:82 dt:33.45 (29.9hz) dtRlead: 2.24 (446.3hz) dtWfoll: 0.61 (1643.8hz) dtRfoll: 1.77 (563.8hz) dtRlaptop:27.18 (36.8hz) dtRphone:27.37 (36.5hz)
# INFO 2025-04-13 17:11:18 rol_utils.py:82 dt:33.41 (29.9hz) dtRlead: 1.86 (537.0hz) dtWfoll: 0.46 (2168.7hz) dtRfoll: 2.43 (410.9hz) dtRlaptop:33.83 (29.6hz) dtRphone:34.08 (29.3hz)
# INFO 2025-04-13 17:11:18 rol_utils.py:82 dt:33.42 (29.9hz) dtRlead: 2.09 (477.9hz) dtWfoll: 0.44 (2298.8hz) dtRfoll: 1.78 (562.5hz) dtRlaptop:33.12 (30.2hz) dtRphone:32.22 (31.0hz)
# INFO 2025-04-13 17:11:18 rol_utils.py:82 dt:33.40 (29.9hz) dtRlead: 1.74 (576.3hz) dtWfoll: 0.24 (4091.6hz) dtRfoll: 1.65 (607.7hz) dtRlaptop:32.46 (30.8hz) dtRphone:32.73 (30.6hz)
# INFO 2025-04-13 17:11:18 rol_utils.py:82 dt:33.41 (29.9hz) dtRlead: 1.73 (578.7hz) dtWfoll: 0.28 (3588.3hz) dtRfoll: 1.71 (583.2hz) dtRlaptop:28.10 (35.6hz) dtRphone:27.94 (35.8hz)
# INFO 2025-04-13 17:11:18 rol_utils.py:82 dt:33.42 (29.9hz) dtRlead: 2.18 (458.9hz) dtWfoll: 0.39 (2561.6hz) dtRfoll: 1.94 (516.7hz) dtRlaptop:28.10 (35.6hz) dtRphone:27.94 (35.8hz)
# INFO 2025-04-13 17:11:18 rol_utils.py:82 dt:33.42 (29.9hz) dtRlead: 1.90 (527.1hz) dtWfoll: 0.24 (4121.0hz) dtRfoll: 1.73 (576.5hz) dtRlaptop:26.07 (38.4hz) dtRphone:26.07 (38.4hz)
# INFO 2025-04-13 17:11:18 rol_utils.py:82 dt:33.40 (29.9hz) dtRlead: 1.94 (514.8hz) dtWfoll: 0.47 (2120.5hz) dtRfoll: 1.65 (604.5hz) dtRlaptop:26.07 (38.4hz) dtRphone:26.07 (38.4hz)
# INFO 2025-04-13 17:11:18 rol_utils.py:82 dt:33.41 (29.9hz) dtRlead: 1.82 (549.1hz) dtWfoll: 0.34 (2930.0hz) dtRfoll: 1.78 (560.6hz) dtRlaptop:31.20 (32.1hz) dtRphone:30.91 (32.4hz)
# INFO 2025-04-13 17:11:18 rol_utils.py:82 dt:33.41 (29.9hz) dtRlead: 1.87 (536.1hz) dtWfoll: 0.41 (2409.9hz) dtRfoll: 1.72 (582.4hz) dtRlaptop:32.45 (30.8hz) dtRphone:32.27 (31.0hz)
# INFO 2025-04-13 17:11:18 rol_utils.py:82 dt:33.40 (29.9hz) dtRlead: 1.96 (509.7hz) dtWfoll: 0.35 (2821.0hz) dtRfoll: 1.78 (562.1hz) dtRlaptop:32.45 (30.8hz) dtRphone:32.27 (31.0hz)
# INFO 2025-04-13 17:11:18 rol_utils.py:82 dt:33.41 (29.9hz) dtRlead: 1.82 (550.9hz) dtWfoll: 0.26 (3876.9hz) dtRfoll: 1.74 (575.9hz) dtRlaptop:37.85 (26.4hz) dtRphone:38.30 (26.1hz)
# INFO 2025-04-13 17:11:18 rol_utils.py:82 dt:33.40 (29.9hz) dtRlead: 1.88 (532.5hz) dtWfoll: 0.27 (3739.5hz) dtRfoll: 1.78 (561.9hz) dtRlaptop:25.63 (39.0hz) dtRphone:25.44 (39.3hz)
# INFO 2025-04-13 17:11:18 rol_utils.py:82 dt:33.41 (29.9hz) dtRlead: 1.86 (538.3hz) dtWfoll: 0.32 (3169.5hz) dtRfoll: 1.80 (555.9hz) dtRlaptop:33.23 (30.1hz) dtRphone:32.71 (30.6hz)
# INFO 2025-04-13 17:11:18 rol_utils.py:82 dt:33.41 (29.9hz) dtRlead: 1.87 (534.1hz) dtWfoll: 2.25 (444.2hz) dtRfoll: 2.13 (468.7hz) dtRlaptop:39.44 (25.4hz) dtRphone:39.15 (25.5hz)
# INFO 2025-04-13 17:11:18 rol_utils.py:82 dt:33.41 (29.9hz) dtRlead: 1.69 (591.2hz) dtWfoll: 0.25 (4015.5hz) dtRfoll: 1.73 (579.2hz) dtRlaptop:26.52 (37.7hz) dtRphone:26.18 (38.2hz)
# INFO 2025-04-13 17:11:18 rol_utils.py:82 dt:33.49 (29.9hz) dtRlead: 1.97 (506.4hz) dtWfoll: 0.34 (2941.8hz) dtRfoll: 1.84 (542.7hz) dtRlaptop:33.50 (29.9hz) dtRphone:33.96 (29.4hz)
# INFO 2025-04-13 17:11:18 rol_utils.py:82 dt:33.40 (29.9hz) dtRlead: 1.90 (526.6hz) dtWfoll: 0.30 (3331.4hz) dtRfoll: 1.74 (573.8hz) dtRlaptop:36.45 (27.4hz) dtRphone:36.80 (27.2hz)
# INFO 2025-04-13 17:11:18 rol_utils.py:82 dt:33.42 (29.9hz) dtRlead: 1.80 (554.9hz) dtWfoll: 0.24 (4092.4hz) dtRfoll: 1.77 (566.1hz) dtRlaptop:30.84 (32.4hz) dtRphone:30.45 (32.8hz)
# INFO 2025-04-13 17:11:19 rol_utils.py:82 dt:33.40 (29.9hz) dtRlead: 1.94 (515.6hz) dtWfoll: 0.30 (3297.0hz) dtRfoll: 1.73 (579.1hz) dtRlaptop:37.70 (26.5hz) dtRphone:38.07 (26.3hz)
# INFO 2025-04-13 17:11:19 rol_utils.py:82 dt:33.41 (29.9hz) dtRlead: 1.78 (562.8hz) dtWfoll: 0.26 (3904.0hz) dtRfoll: 1.80 (554.9hz) dtRlaptop:29.23 (34.2hz) dtRphone:28.83 (34.7hz)
# INFO 2025-04-13 17:11:19 rol_utils.py:82 dt:33.41 (29.9hz) dtRlead: 1.80 (557.1hz) dtWfoll: 0.28 (3518.1hz) dtRfoll: 1.75 (571.1hz) dtRlaptop:34.19 (29.3hz) dtRphone:33.64 (29.7hz)
# INFO 2025-04-13 17:11:19 rol_utils.py:82 dt:33.48 (29.9hz) dtRlead: 1.94 (514.8hz) dtWfoll: 0.55 (1814.3hz) dtRfoll: 2.17 (460.4hz) dtRlaptop:36.37 (27.5hz) dtRphone:36.40 (27.5hz)
# INFO 2025-04-13 17:11:19 rol_utils.py:82 dt:33.44 (29.9hz) dtRlead: 1.77 (564.1hz) dtWfoll: 0.28 (3604.3hz) dtRfoll: 1.94 (515.8hz) dtRlaptop:28.77 (34.8hz) dtRphone:29.87 (33.5hz)
# INFO 2025-04-13 17:11:19 rol_utils.py:82 dt:33.40 (29.9hz) dtRlead: 1.74 (574.9hz) dtWfoll: 0.27 (3761.6hz) dtRfoll: 1.86 (538.5hz) dtRlaptop:28.76 (34.8hz) dtRphone:28.36 (35.3hz)
# INFO 2025-04-13 17:11:19 rol_utils.py:82 dt:33.40 (29.9hz) dtRlead: 1.68 (595.3hz) dtWfoll: 0.29 (3466.0hz) dtRfoll: 1.73 (578.1hz) dtRlaptop:40.72 (24.6hz) dtRphone:40.62 (24.6hz)
# INFO 2025-04-13 17:11:19 rol_utils.py:82 dt:33.41 (29.9hz) dtRlead: 1.75 (570.8hz) dtWfoll: 0.24 (4162.4hz) dtRfoll: 1.68 (593.6hz) dtRlaptop:31.36 (31.9hz) dtRphone:31.40 (31.8hz)
# INFO 2025-04-13 17:11:19 rol_utils.py:82 dt:33.41 (29.9hz) dtRlead: 1.75 (571.4hz) dtWfoll: 0.23 (4313.7hz) dtRfoll: 1.83 (547.9hz) dtRlaptop:36.23 (27.6hz) dtRphone:36.27 (27.6hz)
# INFO 2025-04-13 17:11:19 rol_utils.py:82 dt:33.47 (29.9hz) dtRlead: 1.72 (581.1hz) dtWfoll: 0.22 (4472.5hz) dtRfoll: 1.76 (568.5hz) dtRlaptop:33.57 (29.8hz) dtRphone:33.91 (29.5hz)
# INFO 2025-04-13 17:11:19 rol_utils.py:82 dt:33.42 (29.9hz) dtRlead: 1.86 (538.1hz) dtWfoll: 0.36 (2783.9hz) dtRfoll: 1.84 (542.7hz) dtRlaptop:29.63 (33.8hz) dtRphone:29.71 (33.7hz)
# INFO 2025-04-13 17:11:19 rol_utils.py:82 dt:33.41 (29.9hz) dtRlead: 1.85 (539.4hz) dtWfoll: 0.29 (3490.5hz) dtRfoll: 1.75 (571.7hz) dtRlaptop:38.06 (26.3hz) dtRphone:38.54 (25.9hz)
# INFO 2025-04-13 17:11:19 rol_utils.py:82 dt:33.51 (29.8hz) dtRlead: 1.91 (523.7hz) dtWfoll: 0.39 (2588.7hz) dtRfoll: 1.87 (536.0hz) dtRlaptop:31.46 (31.8hz) dtRphone:30.86 (32.4hz)
# INFO 2025-04-13 17:11:19 rol_utils.py:82 dt:33.42 (29.9hz) dtRlead: 1.80 (554.5hz) dtWfoll: 0.35 (2817.1hz) dtRfoll: 1.80 (554.2hz) dtRlaptop:33.84 (29.6hz) dtRphone:34.02 (29.4hz)
# INFO 2025-04-13 17:11:19 rol_utils.py:82 dt:33.41 (29.9hz) dtRlead: 2.06 (485.7hz) dtWfoll: 0.39 (2549.9hz) dtRfoll: 2.02 (495.3hz) dtRlaptop:33.55 (29.8hz) dtRphone:33.80 (29.6hz)
# INFO 2025-04-13 17:11:19 rol_utils.py:82 dt:33.46 (29.9hz) dtRlead: 1.74 (574.0hz) dtWfoll: 0.24 (4155.4hz) dtRfoll: 1.78 (561.9hz) dtRlaptop:32.84 (30.4hz) dtRphone:32.79 (30.5hz)
# INFO 2025-04-13 17:11:19 rol_utils.py:82 dt:33.41 (29.9hz) dtRlead: 1.87 (534.6hz) dtWfoll: 0.32 (3127.6hz) dtRfoll: 2.00 (500.4hz) dtRlaptop:32.01 (31.2hz) dtRphone:31.83 (31.4hz)
# INFO 2025-04-13 17:11:19 rol_utils.py:82 dt:33.40 (29.9hz) dtRlead: 2.07 (483.1hz) dtWfoll: 0.36 (2802.5hz) dtRfoll: 1.84 (543.1hz) dtRlaptop:37.61 (26.6hz) dtRphone:38.04 (26.3hz)
# INFO 2025-04-13 17:11:19 rol_utils.py:82 dt:33.40 (29.9hz) dtRlead: 1.80 (555.9hz) dtWfoll: 0.25 (3981.0hz) dtRfoll: 1.70 (589.2hz) dtRlaptop:29.48 (33.9hz) dtRphone:29.00 (34.5hz)
# INFO 2025-04-13 17:11:19 rol_utils.py:82 dt:33.37 (30.0hz) dtRlead: 1.81 (553.7hz) dtWfoll: 0.29 (3391.0hz) dtRfoll: 1.75 (571.9hz) dtRlaptop:35.32 (28.3hz) dtRphone:35.51 (28.2hz)
# INFO 2025-04-13 17:11:19 rol_utils.py:82 dt:33.41 (29.9hz) dtRlead: 1.82 (549.4hz) dtWfoll: 0.27 (3705.1hz) dtRfoll: 1.75 (571.8hz) dtRlaptop:32.81 (30.5hz) dtRphone:32.11 (31.1hz)
# INFO 2025-04-13 17:11:19 rol_utils.py:82 dt:33.40 (29.9hz) dtRlead: 1.91 (522.2hz) dtWfoll: 0.30 (3280.5hz) dtRfoll: 1.83 (547.8hz) dtRlaptop:30.39 (32.9hz) dtRphone:30.40 (32.9hz)
# INFO 2025-04-13 17:11:19 rol_utils.py:82 dt:33.41 (29.9hz) dtRlead: 1.82 (549.1hz) dtWfoll: 0.33 (3014.5hz) dtRfoll: 1.75 (572.3hz) dtRlaptop:35.96 (27.8hz) dtRphone:35.98 (27.8hz)
# INFO 2025-04-13 17:11:19 rol_utils.py:82 dt:33.41 (29.9hz) dtRlead: 1.92 (521.6hz) dtWfoll: 0.37 (2708.6hz) dtRfoll: 1.86 (536.3hz) dtRlaptop:34.92 (28.6hz) dtRphone:35.02 (28.6hz)
# INFO 2025-04-13 17:11:19 rol_utils.py:82 dt:33.41 (29.9hz) dtRlead: 1.96 (511.2hz) dtWfoll: 2.55 (392.4hz) dtRfoll: 1.87 (533.7hz) dtRlaptop:28.08 (35.6hz) dtRphone:28.01 (35.7hz)
# INFO 2025-04-13 17:11:19 rol_utils.py:82 dt:33.41 (29.9hz) dtRlead: 2.20 (455.1hz) dtWfoll: 0.51 (1971.6hz) dtRfoll: 1.94 (515.1hz) dtRlaptop:35.60 (28.1hz) dtRphone:35.69 (28.0hz)
# INFO 2025-04-13 17:11:19 rol_utils.py:82 dt:33.41 (29.9hz) dtRlead: 1.72 (580.1hz) dtWfoll: 0.28 (3583.3hz) dtRfoll: 1.70 (586.8hz) dtRlaptop:36.66 (27.3hz) dtRphone:36.65 (27.3hz)
# INFO 2025-04-13 17:11:19 rol_utils.py:82 dt:33.42 (29.9hz) dtRlead: 1.92 (519.9hz) dtWfoll: 0.37 (2711.4hz) dtRfoll: 1.90 (525.6hz) dtRlaptop:26.60 (37.6hz) dtRphone:26.62 (37.6hz)
# INFO 2025-04-13 17:11:19 rol_utils.py:82 dt:33.52 (29.8hz) dtRlead: 1.86 (536.9hz) dtWfoll: 0.37 (2723.9hz) dtRfoll: 1.87 (534.5hz) dtRlaptop:35.87 (27.9hz) dtRphone:36.01 (27.8hz)
# INFO 2025-04-13 17:11:19 rol_utils.py:82 dt:33.41 (29.9hz) dtRlead: 1.93 (517.0hz) dtWfoll: 0.43 (2337.3hz) dtRfoll: 1.75 (571.6hz) dtRlaptop:37.71 (26.5hz) dtRphone:37.61 (26.6hz)
# INFO 2025-04-13 17:11:20 rol_utils.py:82 dt:33.41 (29.9hz) dtRlead: 1.93 (518.4hz) dtWfoll: 0.34 (2932.7hz) dtRfoll: 1.83 (545.8hz) dtRlaptop:26.79 (37.3hz) dtRphone:26.64 (37.5hz)
# INFO 2025-04-13 17:11:20 rol_utils.py:82 dt:33.42 (29.9hz) dtRlead: 1.84 (544.2hz) dtWfoll: 0.34 (2970.9hz) dtRfoll: 1.78 (562.9hz) dtRlaptop:36.00 (27.8hz) dtRphone:35.95 (27.8hz)
# INFO 2025-04-13 17:11:20 rol_utils.py:82 dt:33.41 (29.9hz) dtRlead: 1.94 (514.6hz) dtWfoll: 0.37 (2685.6hz) dtRfoll: 1.76 (567.8hz) dtRlaptop:34.66 (28.9hz) dtRphone:34.76 (28.8hz)
# INFO 2025-04-13 17:11:20 rol_utils.py:82 dt:33.48 (29.9hz) dtRlead: 1.85 (539.1hz) dtWfoll: 0.31 (3200.1hz) dtRfoll: 1.86 (536.7hz) dtRlaptop:32.67 (30.6hz) dtRphone:32.66 (30.6hz)
# INFO 2025-04-13 17:11:20 rol_utils.py:82 dt:33.41 (29.9hz) dtRlead: 2.04 (490.2hz) dtWfoll: 0.47 (2147.4hz) dtRfoll: 1.85 (541.5hz) dtRlaptop:34.54 (29.0hz) dtRphone:35.04 (28.5hz)
# INFO 2025-04-13 17:11:20 rol_utils.py:82 dt:33.46 (29.9hz) dtRlead: 1.79 (557.8hz) dtWfoll: 0.33 (3059.9hz) dtRfoll: 1.81 (553.5hz) dtRlaptop:31.85 (31.4hz) dtRphone:31.60 (31.6hz)
# INFO 2025-04-13 17:11:20 rol_utils.py:82 dt:33.41 (29.9hz) dtRlead: 1.96 (509.8hz) dtWfoll: 0.40 (2517.1hz) dtRfoll: 1.97 (508.9hz) dtRlaptop:37.50 (26.7hz) dtRphone:37.39 (26.7hz)
# INFO 2025-04-13 17:11:20 rol_utils.py:82 dt:33.41 (29.9hz) dtRlead: 1.82 (549.8hz) dtWfoll: 0.33 (3003.4hz) dtRfoll: 1.77 (566.6hz) dtRlaptop:27.07 (36.9hz) dtRphone:26.96 (37.1hz)
# INFO 2025-04-13 17:11:20 rol_utils.py:82 dt:33.41 (29.9hz) dtRlead: 1.84 (543.5hz) dtWfoll: 0.29 (3407.8hz) dtRfoll: 1.75 (570.6hz) dtRlaptop:36.86 (27.1hz) dtRphone:36.89 (27.1hz)
# INFO 2025-04-13 17:11:20 rol_utils.py:82 dt:33.41 (29.9hz) dtRlead: 1.86 (538.5hz) dtWfoll: 0.32 (3134.4hz) dtRfoll: 1.72 (581.4hz) dtRlaptop:33.03 (30.3hz) dtRphone:33.00 (30.3hz)
# INFO 2025-04-13 17:11:20 rol_utils.py:82 dt:33.40 (29.9hz) dtRlead: 1.79 (558.2hz) dtWfoll: 0.35 (2843.0hz) dtRfoll: 1.69 (593.4hz) dtRlaptop:31.03 (32.2hz) dtRphone:31.08 (32.2hz)
# INFO 2025-04-13 17:11:20 rol_utils.py:82 dt:33.46 (29.9hz) dtRlead: 1.85 (541.3hz) dtWfoll: 0.43 (2322.1hz) dtRfoll: 1.79 (558.0hz) dtRlaptop:30.79 (32.5hz) dtRphone:30.78 (32.5hz)
# INFO 2025-04-13 17:11:20 rol_utils.py:82 dt:33.43 (29.9hz) dtRlead: 1.78 (561.1hz) dtWfoll: 0.32 (3126.2hz) dtRfoll: 1.79 (558.8hz) dtRlaptop:37.29 (26.8hz) dtRphone:37.27 (26.8hz)
# INFO 2025-04-13 17:11:20 rol_utils.py:82 dt:33.42 (29.9hz) dtRlead: 1.85 (540.0hz) dtWfoll: 0.34 (2920.6hz) dtRfoll: 1.67 (600.1hz) dtRlaptop:33.70 (29.7hz) dtRphone:33.67 (29.7hz)
# INFO 2025-04-13 17:11:20 rol_utils.py:82 dt:33.41 (29.9hz) dtRlead: 1.93 (518.1hz) dtWfoll: 0.35 (2851.0hz) dtRfoll: 1.74 (573.9hz) dtRlaptop:30.02 (33.3hz) dtRphone:30.07 (33.3hz)
# INFO 2025-04-13 17:11:20 rol_utils.py:82 dt:33.41 (29.9hz) dtRlead: 1.90 (527.1hz) dtWfoll: 0.41 (2432.0hz) dtRfoll: 1.71 (583.6hz) dtRlaptop:34.94 (28.6hz) dtRphone:34.88 (28.7hz)
# INFO 2025-04-13 17:11:20 rol_utils.py:82 dt:33.41 (29.9hz) dtRlead: 1.92 (522.2hz) dtWfoll: 0.32 (3083.9hz) dtRfoll: 1.82 (548.4hz) dtRlaptop:41.36 (24.2hz) dtRphone:41.74 (24.0hz)
# INFO 2025-04-13 17:11:20 rol_utils.py:82 dt:33.42 (29.9hz) dtRlead: 1.94 (515.2hz) dtWfoll: 0.38 (2649.8hz) dtRfoll: 1.86 (537.1hz) dtRlaptop:25.71 (38.9hz) dtRphone:25.43 (39.3hz)
# INFO 2025-04-13 17:11:20 rol_utils.py:82 dt:33.43 (29.9hz) dtRlead: 2.03 (492.3hz) dtWfoll: 0.36 (2756.4hz) dtRfoll: 1.87 (536.2hz) dtRlaptop:37.33 (26.8hz) dtRphone:37.41 (26.7hz)
# INFO 2025-04-13 17:11:20 rol_utils.py:82 dt:33.48 (29.9hz) dtRlead: 2.21 (452.2hz) dtWfoll: 0.53 (1880.6hz) dtRfoll: 2.10 (477.3hz) dtRlaptop:29.69 (33.7hz) dtRphone:29.74 (33.6hz)
# INFO 2025-04-13 17:11:20 rol_utils.py:82 dt:33.41 (29.9hz) dtRlead: 1.94 (516.4hz) dtWfoll: 0.30 (3388.1hz) dtRfoll: 2.07 (483.6hz) dtRlaptop:39.91 (25.1hz) dtRphone:39.81 (25.1hz)
# INFO 2025-04-13 17:11:20 rol_utils.py:82 dt:33.48 (29.9hz) dtRlead: 1.90 (525.5hz) dtWfoll: 0.33 (3015.7hz) dtRfoll: 1.77 (565.0hz) dtRlaptop:24.55 (40.7hz) dtRphone:24.45 (40.9hz)
# INFO 2025-04-13 17:11:20 rol_utils.py:82 dt:33.48 (29.9hz) dtRlead: 1.75 (570.6hz) dtWfoll: 0.35 (2880.5hz) dtRfoll: 1.72 (581.7hz) dtRlaptop:40.35 (24.8hz) dtRphone:40.44 (24.7hz)
# INFO 2025-04-13 17:11:20 rol_utils.py:82 dt:33.41 (29.9hz) dtRlead: 1.88 (531.1hz) dtWfoll: 0.36 (2770.8hz) dtRfoll: 1.78 (560.4hz) dtRlaptop:32.92 (30.4hz) dtRphone:32.86 (30.4hz)
# INFO 2025-04-13 17:11:20 rol_utils.py:82 dt:33.42 (29.9hz) dtRlead: 1.96 (509.8hz) dtWfoll: 0.41 (2438.9hz) dtRfoll: 1.84 (544.7hz) dtRlaptop:26.45 (37.8hz) dtRphone:26.51 (37.7hz)
# INFO 2025-04-13 17:11:20 rol_utils.py:82 dt:33.51 (29.8hz) dtRlead: 2.11 (474.5hz) dtWfoll: 0.44 (2263.8hz) dtRfoll: 1.79 (557.4hz) dtRlaptop:36.47 (27.4hz) dtRphone:36.70 (27.2hz)
# INFO 2025-04-13 17:11:20 rol_utils.py:82 dt:33.48 (29.9hz) dtRlead: 2.17 (461.8hz) dtWfoll: 0.49 (2023.4hz) dtRfoll: 2.02 (495.4hz) dtRlaptop:38.04 (26.3hz) dtRphone:37.92 (26.4hz)
# INFO 2025-04-13 17:11:20 rol_utils.py:82 dt:33.54 (29.8hz) dtRlead: 2.02 (495.5hz) dtWfoll: 0.46 (2153.4hz) dtRfoll: 2.08 (480.0hz) dtRlaptop:31.35 (31.9hz) dtRphone:31.32 (31.9hz)
# INFO 2025-04-13 17:11:20 rol_utils.py:82 dt:33.45 (29.9hz) dtRlead: 2.30 (434.9hz) dtWfoll: 1.23 (815.4hz) dtRfoll: 2.05 (488.5hz) dtRlaptop:33.13 (30.2hz) dtRphone:33.18 (30.1hz)
# INFO 2025-04-13 17:11:20 rol_utils.py:82 dt:33.42 (29.9hz) dtRlead: 2.19 (456.1hz) dtWfoll: 0.37 (2721.7hz) dtRfoll: 1.77 (563.8hz) dtRlaptop:35.67 (28.0hz) dtRphone:35.73 (28.0hz)
# INFO 2025-04-13 17:11:21 rol_utils.py:82 dt:33.41 (29.9hz) dtRlead: 2.04 (490.0hz) dtWfoll: 0.35 (2836.9hz) dtRfoll: 1.98 (504.1hz) dtRlaptop:32.89 (30.4hz) dtRphone:33.29 (30.0hz)
# INFO 2025-04-13 17:11:21 rol_utils.py:82 dt:33.50 (29.9hz) dtRlead: 1.92 (520.7hz) dtWfoll: 0.34 (2974.4hz) dtRfoll: 1.67 (599.1hz) dtRlaptop:33.46 (29.9hz) dtRphone:33.43 (29.9hz)
# INFO 2025-04-13 17:11:21 rol_utils.py:82 dt:33.56 (29.8hz) dtRlead: 1.95 (512.9hz) dtWfoll: 0.52 (1905.6hz) dtRfoll: 2.09 (478.9hz) dtRlaptop:29.46 (33.9hz) dtRphone:29.00 (34.5hz)
# INFO 2025-04-13 17:11:21 rol_utils.py:82 dt:33.50 (29.9hz) dtRlead: 2.26 (441.9hz) dtWfoll: 0.84 (1197.5hz) dtRfoll: 1.95 (512.3hz) dtRlaptop:40.43 (24.7hz) dtRphone:40.50 (24.7hz)
# INFO 2025-04-13 17:11:21 rol_utils.py:82 dt:33.43 (29.9hz) dtRlead: 2.30 (435.3hz) dtWfoll: 0.56 (1784.2hz) dtRfoll: 2.17 (461.3hz) dtRlaptop:33.38 (30.0hz) dtRphone:33.36 (30.0hz)
# INFO 2025-04-13 17:11:21 rol_utils.py:82 dt:33.42 (29.9hz) dtRlead: 1.93 (519.3hz) dtWfoll: 0.50 (2010.7hz) dtRfoll: 1.85 (541.3hz) dtRlaptop:31.47 (31.8hz) dtRphone:31.43 (31.8hz)
# INFO 2025-04-13 17:11:21 rol_utils.py:82 dt:33.43 (29.9hz) dtRlead: 1.92 (520.5hz) dtWfoll: 0.37 (2711.8hz) dtRfoll: 1.88 (530.8hz) dtRlaptop:37.53 (26.6hz) dtRphone:38.36 (26.1hz)
# INFO 2025-04-13 17:11:21 rol_utils.py:82 dt:33.42 (29.9hz) dtRlead: 1.64 (608.6hz) dtWfoll: 0.20 (5020.2hz) dtRfoll: 2.88 (346.8hz) dtRlaptop:33.41 (29.9hz) dtRphone:33.23 (30.1hz)
# INFO 2025-04-13 17:11:21 rol_utils.py:82 dt:33.42 (29.9hz) dtRlead: 1.66 (600.9hz) dtWfoll: 0.16 (6275.9hz) dtRfoll: 1.69 (592.9hz) dtRlaptop:22.08 (45.3hz) dtRphone:21.75 (46.0hz)
# INFO 2025-04-13 17:11:21 rol_utils.py:82 dt:33.42 (29.9hz) dtRlead: 2.08 (480.1hz) dtWfoll: 0.40 (2490.5hz) dtRfoll: 1.99 (503.0hz) dtRlaptop:29.20 (34.2hz) dtRphone:29.04 (34.4hz)
# INFO 2025-04-13 17:11:21 rol_utils.py:82 dt:33.49 (29.9hz) dtRlead: 1.99 (501.4hz) dtWfoll: 0.49 (2043.0hz) dtRfoll: 2.38 (420.7hz) dtRlaptop:47.46 (21.1hz) dtRphone:47.48 (21.1hz)
# INFO 2025-04-13 17:11:21 rol_utils.py:82 dt:33.54 (29.8hz) dtRlead: 2.99 (334.9hz) dtWfoll: 0.67 (1487.3hz) dtRfoll: 2.42 (413.3hz) dtRlaptop:29.76 (33.6hz) dtRphone:29.63 (33.7hz)
# INFO 2025-04-13 17:11:21 rol_utils.py:82 dt:33.42 (29.9hz) dtRlead: 2.33 (428.3hz) dtWfoll: 0.57 (1755.7hz) dtRfoll: 2.20 (454.0hz) dtRlaptop:32.99 (30.3hz) dtRphone:33.06 (30.2hz)
# INFO 2025-04-13 17:11:21 rol_utils.py:82 dt:33.43 (29.9hz) dtRlead: 2.26 (442.8hz) dtWfoll: 0.97 (1026.1hz) dtRfoll: 2.05 (488.9hz) dtRlaptop:36.93 (27.1hz) dtRphone:36.94 (27.1hz)
# INFO 2025-04-13 17:11:21 rol_utils.py:82 dt:33.52 (29.8hz) dtRlead: 2.10 (476.5hz) dtWfoll: 0.51 (1977.5hz) dtRfoll: 1.95 (512.5hz) dtRlaptop:29.28 (34.1hz) dtRphone:29.16 (34.3hz)
# INFO 2025-04-13 17:11:21 rol_utils.py:82 dt:33.44 (29.9hz) dtRlead: 2.45 (408.3hz) dtWfoll: 0.72 (1389.0hz) dtRfoll: 2.24 (446.9hz) dtRlaptop:34.43 (29.0hz) dtRphone:34.76 (28.8hz)
# INFO 2025-04-13 17:11:21 rol_utils.py:82 dt:33.49 (29.9hz) dtRlead: 1.94 (514.4hz) dtWfoll: 0.52 (1925.6hz) dtRfoll: 1.83 (547.3hz) dtRlaptop:33.93 (29.5hz) dtRphone:33.85 (29.5hz)
# INFO 2025-04-13 17:11:21 rol_utils.py:82 dt:33.43 (29.9hz) dtRlead: 2.16 (463.6hz) dtWfoll: 0.58 (1720.6hz) dtRfoll: 2.15 (465.4hz) dtRlaptop:31.39 (31.9hz) dtRphone:31.65 (31.6hz)
# INFO 2025-04-13 17:11:21 rol_utils.py:82 dt:33.56 (29.8hz) dtRlead: 2.02 (494.4hz) dtWfoll: 0.47 (2122.9hz) dtRfoll: 1.86 (538.0hz) dtRlaptop:34.14 (29.3hz) dtRphone:34.32 (29.1hz)
# INFO 2025-04-13 17:11:21 rol_utils.py:82 dt:33.43 (29.9hz) dtRlead: 1.94 (514.9hz) dtWfoll: 0.53 (1891.1hz) dtRfoll: 1.77 (564.3hz) dtRlaptop:34.88 (28.7hz) dtRphone:34.18 (29.3hz)
# INFO 2025-04-13 17:11:21 rol_utils.py:82 dt:33.44 (29.9hz) dtRlead: 1.98 (504.9hz) dtWfoll: 0.41 (2468.8hz) dtRfoll: 1.79 (560.1hz) dtRlaptop:28.06 (35.6hz) dtRphone:28.09 (35.6hz)
# INFO 2025-04-13 17:11:21 rol_utils.py:82 dt:33.42 (29.9hz) dtRlead: 2.26 (441.9hz) dtWfoll: 0.58 (1733.9hz) dtRfoll: 1.64 (609.0hz) dtRlaptop:47.72 (21.0hz) dtRphone:48.85 (20.5hz)
# INFO 2025-04-13 17:11:21 rol_utils.py:82 dt:33.42 (29.9hz) dtRlead: 2.05 (487.7hz) dtWfoll: 0.42 (2388.5hz) dtRfoll: 1.96 (510.8hz) dtRlaptop:19.44 (51.4hz) dtRphone:18.87 (53.0hz)
# INFO 2025-04-13 17:11:21 rol_utils.py:82 dt:33.42 (29.9hz) dtRlead: 2.22 (450.3hz) dtWfoll: 0.47 (2125.6hz) dtRfoll: 2.01 (497.7hz) dtRlaptop:37.50 (26.7hz) dtRphone:37.44 (26.7hz)
# INFO 2025-04-13 17:11:21 rol_utils.py:82 dt:33.50 (29.8hz) dtRlead: 2.22 (450.4hz) dtWfoll: 0.52 (1919.3hz) dtRfoll: 1.90 (525.1hz) dtRlaptop:40.25 (24.8hz) dtRphone:40.62 (24.6hz)
# INFO 2025-04-13 17:11:21 rol_utils.py:82 dt:33.56 (29.8hz) dtRlead: 2.46 (407.0hz) dtWfoll: 0.71 (1413.2hz) dtRfoll: 2.30 (434.2hz) dtRlaptop:21.98 (45.5hz) dtRphone:21.11 (47.4hz)
# INFO 2025-04-13 17:11:21 rol_utils.py:82 dt:33.56 (29.8hz) dtRlead: 2.43 (412.3hz) dtWfoll: 0.66 (1507.9hz) dtRfoll: 2.24 (446.2hz) dtRlaptop:39.29 (25.5hz) dtRphone:39.46 (25.3hz)
# INFO 2025-04-13 17:11:21 rol_utils.py:82 dt:33.51 (29.8hz) dtRlead: 2.44 (409.1hz) dtWfoll: 0.61 (1629.2hz) dtRfoll: 1.82 (550.3hz) dtRlaptop:34.04 (29.4hz) dtRphone:33.98 (29.4hz)
# INFO 2025-04-13 17:11:21 rol_utils.py:82 dt:33.56 (29.8hz) dtRlead: 2.35 (425.6hz) dtWfoll: 0.61 (1650.0hz) dtRfoll: 2.14 (467.3hz) dtRlaptop:30.84 (32.4hz) dtRphone:30.74 (32.5hz)
# INFO 2025-04-13 17:11:22 rol_utils.py:82 dt:33.50 (29.9hz) dtRlead: 2.48 (403.8hz) dtWfoll: 0.66 (1507.4hz) dtRfoll: 2.11 (473.3hz) dtRlaptop:33.39 (30.0hz) dtRphone:33.61 (29.8hz)
# INFO 2025-04-13 17:11:22 rol_utils.py:82 dt:33.41 (29.9hz) dtRlead: 1.95 (513.4hz) dtWfoll: 0.38 (2654.1hz) dtRfoll: 1.74 (575.5hz) dtRlaptop:35.95 (27.8hz) dtRphone:36.46 (27.4hz)
# INFO 2025-04-13 17:11:22 rol_utils.py:82 dt:33.43 (29.9hz) dtRlead: 1.93 (518.6hz) dtWfoll: 0.38 (2619.0hz) dtRfoll: 1.74 (574.0hz) dtRlaptop:30.75 (32.5hz) dtRphone:30.60 (32.7hz)
# INFO 2025-04-13 17:11:22 rol_utils.py:82 dt:33.49 (29.9hz) dtRlead: 1.97 (507.6hz) dtWfoll: 0.48 (2090.5hz) dtRfoll: 1.90 (526.9hz) dtRlaptop:33.34 (30.0hz) dtRphone:33.33 (30.0hz)
# INFO 2025-04-13 17:11:22 rol_utils.py:82 dt:33.44 (29.9hz) dtRlead: 1.90 (527.2hz) dtWfoll: 0.34 (2981.5hz) dtRfoll: 1.73 (578.1hz) dtRlaptop:35.98 (27.8hz) dtRphone:36.12 (27.7hz)
# INFO 2025-04-13 17:11:22 rol_utils.py:82 dt:33.43 (29.9hz) dtRlead: 1.99 (503.2hz) dtWfoll: 0.41 (2423.4hz) dtRfoll: 1.90 (527.3hz) dtRlaptop:30.72 (32.6hz) dtRphone:30.50 (32.8hz)
# INFO 2025-04-13 17:11:22 rol_utils.py:82 dt:33.41 (29.9hz) dtRlead: 2.30 (434.7hz) dtWfoll: 0.39 (2551.6hz) dtRfoll: 1.63 (612.5hz) dtRlaptop:38.52 (26.0hz) dtRphone:38.14 (26.2hz)
# INFO 2025-04-13 17:11:22 rol_utils.py:82 dt:33.44 (29.9hz) dtRlead: 1.80 (556.9hz) dtWfoll: 0.36 (2747.4hz) dtRfoll: 1.82 (549.8hz) dtRlaptop:31.65 (31.6hz) dtRphone:31.53 (31.7hz)
# INFO 2025-04-13 17:11:22 rol_utils.py:82 dt:33.42 (29.9hz) dtRlead: 2.59 (386.0hz) dtWfoll: 0.64 (1569.7hz) dtRfoll: 1.96 (509.4hz) dtRlaptop:30.48 (32.8hz) dtRphone:30.63 (32.6hz)
# INFO 2025-04-13 17:11:22 rol_utils.py:82 dt:33.41 (29.9hz) dtRlead: 1.83 (547.6hz) dtWfoll: 0.38 (2613.2hz) dtRfoll: 1.76 (566.8hz) dtRlaptop:22.12 (45.2hz) dtRphone:22.06 (45.3hz)
# INFO 2025-04-13 17:11:22 rol_utils.py:82 dt:33.42 (29.9hz) dtRlead: 1.71 (584.2hz) dtWfoll: 0.27 (3710.9hz) dtRfoll: 1.69 (592.1hz) dtRlaptop:35.90 (27.9hz) dtRphone:36.41 (27.5hz)
# INFO 2025-04-13 17:11:22 rol_utils.py:82 dt:33.43 (29.9hz) dtRlead: 2.15 (465.4hz) dtWfoll: 0.72 (1389.4hz) dtRfoll: 2.21 (452.8hz) dtRlaptop:35.90 (27.9hz) dtRphone:36.41 (27.5hz)
# INFO 2025-04-13 17:11:22 rol_utils.py:82 dt:33.43 (29.9hz) dtRlead: 1.82 (550.2hz) dtWfoll: 0.32 (3172.6hz) dtRfoll: 1.76 (568.0hz) dtRlaptop:26.72 (37.4hz) dtRphone:26.91 (37.2hz)
# INFO 2025-04-13 17:11:22 rol_utils.py:82 dt:33.42 (29.9hz) dtRlead: 1.86 (538.2hz) dtWfoll: 0.34 (2936.6hz) dtRfoll: 1.72 (581.0hz) dtRlaptop:36.43 (27.4hz) dtRphone:36.22 (27.6hz)
# INFO 2025-04-13 17:11:22 rol_utils.py:82 dt:33.41 (29.9hz) dtRlead: 1.89 (528.8hz) dtWfoll: 0.36 (2776.2hz) dtRfoll: 1.97 (506.8hz) dtRlaptop:36.43 (27.4hz) dtRphone:36.22 (27.6hz)
# INFO 2025-04-13 17:11:22 rol_utils.py:82 dt:33.48 (29.9hz) dtRlead: 1.71 (584.6hz) dtWfoll: 0.23 (4403.8hz) dtRfoll: 1.74 (575.1hz) dtRlaptop:28.10 (35.6hz) dtRphone:28.16 (35.5hz)
# INFO 2025-04-13 17:11:22 rol_utils.py:82 dt:33.44 (29.9hz) dtRlead: 2.07 (482.2hz) dtWfoll: 0.35 (2888.8hz) dtRfoll: 1.86 (537.3hz) dtRlaptop:37.18 (26.9hz) dtRphone:37.10 (27.0hz)
# INFO 2025-04-13 17:11:22 rol_utils.py:82 dt:33.48 (29.9hz) dtRlead: 2.10 (476.9hz) dtWfoll: 0.45 (2225.6hz) dtRfoll: 1.95 (513.0hz) dtRlaptop:37.18 (26.9hz) dtRphone:37.10 (27.0hz)
# INFO 2025-04-13 17:11:22 rol_utils.py:82 dt:33.41 (29.9hz) dtRlead: 1.67 (600.1hz) dtWfoll: 0.37 (2716.5hz) dtRfoll: 1.69 (592.1hz) dtRlaptop:21.00 (47.6hz) dtRphone:21.14 (47.3hz)
# INFO 2025-04-13 17:11:22 rol_utils.py:82 dt:33.42 (29.9hz) dtRlead: 1.92 (519.9hz) dtWfoll: 0.36 (2756.2hz) dtRfoll: 1.72 (581.8hz) dtRlaptop:21.00 (47.6hz) dtRphone:21.14 (47.3hz)
# INFO 2025-04-13 17:11:22 rol_utils.py:82 dt:33.41 (29.9hz) dtRlead: 1.82 (548.2hz) dtWfoll: 0.34 (2932.8hz) dtRfoll: 1.69 (593.1hz) dtRlaptop:46.68 (21.4hz) dtRphone:47.33 (21.1hz)
# Right arrow key pressed. Exiting loop...
# INFO 2025-04-13 17:11:22 rol_utils.py:82 dt:33.42 (29.9hz) dtRlead: 1.75 (571.3hz) dtWfoll: 0.30 (3285.8hz) dtRfoll: 1.81 (551.7hz) dtRlaptop:24.81 (40.3hz) dtRphone:24.02 (41.6hz)
# INFO 2025-04-13 17:11:22 ls/utils.py:200 Recording episode 267
# INFO 2025-04-13 17:11:22 rol_utils.py:82 dt:33.40 (29.9hz) dtRlead: 1.87 (534.8hz) dtWfoll: 0.26 (3815.1hz) dtRfoll: 1.81 (551.0hz) dtRlaptop:41.12 (24.3hz) dtRphone:41.79 (23.9hz)
# INFO 2025-04-13 17:11:22 rol_utils.py:82 dt:33.43 (29.9hz) dtRlead: 2.04 (491.1hz) dtWfoll: 0.31 (3258.8hz) dtRfoll: 1.59 (627.4hz) dtRlaptop:23.48 (42.6hz) dtRphone:23.16 (43.2hz)
# INFO 2025-04-13 17:11:22 rol_utils.py:82 dt:33.44 (29.9hz) dtRlead: 1.76 (568.8hz) dtWfoll: 0.26 (3800.4hz) dtRfoll: 1.76 (567.9hz) dtRlaptop:32.25 (31.0hz) dtRphone:32.39 (30.9hz)
# INFO 2025-04-13 17:11:22 rol_utils.py:82 dt:33.41 (29.9hz) dtRlead: 1.70 (589.9hz) dtWfoll: 0.37 (2688.3hz) dtRfoll: 1.57 (637.7hz) dtRlaptop:35.97 (27.8hz) dtRphone:35.89 (27.9hz)
# INFO 2025-04-13 17:11:22 rol_utils.py:82 dt:33.40 (29.9hz) dtRlead: 1.68 (597.0hz) dtWfoll: 0.22 (4543.6hz) dtRfoll: 1.66 (604.0hz) dtRlaptop:32.00 (31.3hz) dtRphone:32.03 (31.2hz)
# INFO 2025-04-13 17:11:22 rol_utils.py:82 dt:33.44 (29.9hz) dtRlead: 1.63 (612.7hz) dtWfoll: 0.29 (3444.0hz) dtRfoll: 1.62 (617.8hz) dtRlaptop:33.30 (30.0hz) dtRphone:33.04 (30.3hz)
# INFO 2025-04-13 17:11:22 rol_utils.py:82 dt:33.39 (29.9hz) dtRlead: 1.71 (584.6hz) dtWfoll: 0.26 (3885.3hz) dtRfoll: 1.63 (612.3hz) dtRlaptop:34.96 (28.6hz) dtRphone:34.89 (28.7hz)
# INFO 2025-04-13 17:11:22 rol_utils.py:82 dt:33.40 (29.9hz) dtRlead: 1.68 (596.0hz) dtWfoll: 0.19 (5140.9hz) dtRfoll: 1.73 (579.6hz) dtRlaptop:30.80 (32.5hz) dtRphone:30.54 (32.7hz)
# INFO 2025-04-13 17:11:23 rol_utils.py:82 dt:33.41 (29.9hz) dtRlead: 1.64 (610.3hz) dtWfoll: 0.23 (4441.2hz) dtRfoll: 1.78 (562.6hz) dtRlaptop:31.45 (31.8hz) dtRphone:31.57 (31.7hz)
# INFO 2025-04-13 17:11:23 rol_utils.py:82 dt:33.41 (29.9hz) dtRlead: 1.78 (560.5hz) dtWfoll: 0.43 (2310.1hz) dtRfoll: 1.66 (600.8hz) dtRlaptop:35.84 (27.9hz) dtRphone:35.89 (27.9hz)
# INFO 2025-04-13 17:11:23 rol_utils.py:82 dt:33.40 (29.9hz) dtRlead: 1.65 (606.6hz) dtWfoll: 0.24 (4082.9hz) dtRfoll: 1.72 (582.3hz) dtRlaptop:32.16 (31.1hz) dtRphone:32.11 (31.1hz)
# INFO 2025-04-13 17:11:23 rol_utils.py:82 dt:33.40 (29.9hz) dtRlead: 1.61 (619.8hz) dtWfoll: 0.19 (5343.6hz) dtRfoll: 1.63 (614.3hz) dtRlaptop:35.93 (27.8hz) dtRphone:35.97 (27.8hz)
# INFO 2025-04-13 17:11:23 rol_utils.py:82 dt:33.44 (29.9hz) dtRlead: 1.62 (618.8hz) dtWfoll: 0.22 (4634.9hz) dtRfoll: 1.66 (601.6hz) dtRlaptop:32.04 (31.2hz) dtRphone:32.03 (31.2hz)
# INFO 2025-04-13 17:11:23 rol_utils.py:82 dt:33.40 (29.9hz) dtRlead: 1.61 (622.3hz) dtWfoll: 0.14 (7329.5hz) dtRfoll: 1.66 (603.1hz) dtRlaptop:33.83 (29.6hz) dtRphone:33.98 (29.4hz)
# INFO 2025-04-13 17:11:23 rol_utils.py:82 dt:33.40 (29.9hz) dtRlead: 1.58 (631.9hz) dtWfoll: 0.16 (6126.1hz) dtRfoll: 1.75 (571.7hz) dtRlaptop:34.94 (28.6hz) dtRphone:34.84 (28.7hz)
# INFO 2025-04-13 17:11:23 rol_utils.py:82 dt:33.45 (29.9hz) dtRlead: 1.56 (639.4hz) dtWfoll: 0.20 (5044.2hz) dtRfoll: 1.64 (608.8hz) dtRlaptop:31.42 (31.8hz) dtRphone:31.12 (32.1hz)
# INFO 2025-04-13 17:11:23 rol_utils.py:82 dt:33.40 (29.9hz) dtRlead: 1.56 (640.6hz) dtWfoll: 0.25 (4024.2hz) dtRfoll: 1.62 (618.0hz) dtRlaptop:31.80 (31.4hz) dtRphone:31.87 (31.4hz)
# INFO 2025-04-13 17:11:23 rol_utils.py:82 dt:33.44 (29.9hz) dtRlead: 1.77 (565.9hz) dtWfoll: 0.29 (3488.7hz) dtRfoll: 1.61 (620.5hz) dtRlaptop:37.63 (26.6hz) dtRphone:37.71 (26.5hz)
# INFO 2025-04-13 17:11:23 rol_utils.py:82 dt:33.40 (29.9hz) dtRlead: 1.65 (606.1hz) dtWfoll: 0.27 (3743.5hz) dtRfoll: 1.65 (606.7hz) dtRlaptop:30.38 (32.9hz) dtRphone:30.33 (33.0hz)
# INFO 2025-04-13 17:11:23 rol_utils.py:82 dt:33.44 (29.9hz) dtRlead: 1.73 (577.3hz) dtWfoll: 0.21 (4801.5hz) dtRfoll: 1.73 (576.5hz) dtRlaptop:31.56 (31.7hz) dtRphone:31.86 (31.4hz)
# INFO 2025-04-13 17:11:23 rol_utils.py:82 dt:33.40 (29.9hz) dtRlead: 1.66 (603.5hz) dtWfoll: 0.26 (3911.2hz) dtRfoll: 1.65 (604.5hz) dtRlaptop:36.26 (27.6hz) dtRphone:36.43 (27.5hz)
# INFO 2025-04-13 17:11:23 rol_utils.py:82 dt:33.40 (29.9hz) dtRlead: 1.64 (608.4hz) dtWfoll: 0.26 (3796.3hz) dtRfoll: 1.61 (620.8hz) dtRlaptop:33.30 (30.0hz) dtRphone:33.45 (29.9hz)
# INFO 2025-04-13 17:11:23 rol_utils.py:82 dt:33.41 (29.9hz) dtRlead: 1.58 (634.3hz) dtWfoll: 0.21 (4794.8hz) dtRfoll: 1.59 (628.5hz) dtRlaptop:30.76 (32.5hz) dtRphone:30.63 (32.7hz)
# INFO 2025-04-13 17:11:23 rol_utils.py:82 dt:33.40 (29.9hz) dtRlead: 1.68 (596.9hz) dtWfoll: 0.24 (4156.1hz) dtRfoll: 1.71 (584.8hz) dtRlaptop:35.69 (28.0hz) dtRphone:35.80 (27.9hz)
# INFO 2025-04-13 17:11:23 rol_utils.py:82 dt:33.40 (29.9hz) dtRlead: 1.67 (597.8hz) dtWfoll: 0.34 (2958.2hz) dtRfoll: 1.63 (613.1hz) dtRlaptop:31.67 (31.6hz) dtRphone:31.33 (31.9hz)
# INFO 2025-04-13 17:11:23 rol_utils.py:82 dt:33.40 (29.9hz) dtRlead: 1.71 (584.3hz) dtWfoll: 0.24 (4176.3hz) dtRfoll: 1.84 (543.0hz) dtRlaptop:32.80 (30.5hz) dtRphone:32.49 (30.8hz)
# INFO 2025-04-13 17:11:23 rol_utils.py:82 dt:33.40 (29.9hz) dtRlead: 1.55 (645.2hz) dtWfoll: 0.19 (5284.7hz) dtRfoll: 1.62 (616.9hz) dtRlaptop:35.61 (28.1hz) dtRphone:35.86 (27.9hz)
# INFO 2025-04-13 17:11:23 rol_utils.py:82 dt:33.40 (29.9hz) dtRlead: 1.59 (627.1hz) dtWfoll: 0.23 (4360.6hz) dtRfoll: 1.54 (651.5hz) dtRlaptop:32.01 (31.2hz) dtRphone:32.05 (31.2hz)
# INFO 2025-04-13 17:11:23 rol_utils.py:82 dt:33.40 (29.9hz) dtRlead: 1.67 (597.4hz) dtWfoll: 0.19 (5280.7hz) dtRfoll: 1.70 (588.1hz) dtRlaptop:36.28 (27.6hz) dtRphone:36.29 (27.6hz)
# INFO 2025-04-13 17:11:23 rol_utils.py:82 dt:33.45 (29.9hz) dtRlead: 1.63 (614.0hz) dtWfoll: 0.18 (5544.3hz) dtRfoll: 1.73 (578.1hz) dtRlaptop:32.42 (30.8hz) dtRphone:32.50 (30.8hz)
# INFO 2025-04-13 17:11:23 rol_utils.py:82 dt:33.40 (29.9hz) dtRlead: 1.60 (623.6hz) dtWfoll: 0.27 (3734.0hz) dtRfoll: 1.56 (639.1hz) dtRlaptop:32.93 (30.4hz) dtRphone:33.08 (30.2hz)
# INFO 2025-04-13 17:11:23 rol_utils.py:82 dt:33.45 (29.9hz) dtRlead: 1.75 (571.2hz) dtWfoll: 0.26 (3891.6hz) dtRfoll: 1.61 (621.2hz) dtRlaptop:36.26 (27.6hz) dtRphone:36.12 (27.7hz)
# INFO 2025-04-13 17:11:23 rol_utils.py:82 dt:33.36 (30.0hz) dtRlead: 1.59 (630.0hz) dtWfoll: 0.25 (4006.8hz) dtRfoll: 1.57 (637.4hz) dtRlaptop:32.05 (31.2hz) dtRphone:32.02 (31.2hz)
# INFO 2025-04-13 17:11:23 rol_utils.py:82 dt:33.44 (29.9hz) dtRlead: 1.65 (605.2hz) dtWfoll: 0.17 (5838.6hz) dtRfoll: 1.69 (593.1hz) dtRlaptop:30.37 (32.9hz) dtRphone:30.37 (32.9hz)
# INFO 2025-04-13 17:11:23 rol_utils.py:82 dt:33.40 (29.9hz) dtRlead: 1.65 (605.4hz) dtWfoll: 0.25 (4003.9hz) dtRfoll: 1.59 (628.0hz) dtRlaptop:35.92 (27.8hz) dtRphone:36.18 (27.6hz)
# INFO 2025-04-13 17:11:23 rol_utils.py:82 dt:33.40 (29.9hz) dtRlead: 1.66 (603.5hz) dtWfoll: 0.24 (4254.3hz) dtRfoll: 1.72 (582.7hz) dtRlaptop:32.03 (31.2hz) dtRphone:31.99 (31.3hz)
# INFO 2025-04-13 17:11:23 rol_utils.py:82 dt:33.40 (29.9hz) dtRlead: 1.58 (631.5hz) dtWfoll: 0.23 (4338.4hz) dtRfoll: 1.64 (609.1hz) dtRlaptop:32.52 (30.8hz) dtRphone:32.52 (30.8hz)
# INFO 2025-04-13 17:11:23 rol_utils.py:82 dt:33.43 (29.9hz) dtRlead: 1.74 (574.2hz) dtWfoll: 0.22 (4607.2hz) dtRfoll: 1.85 (539.6hz) dtRlaptop:34.94 (28.6hz) dtRphone:34.96 (28.6hz)
# INFO 2025-04-13 17:11:24 rol_utils.py:82 dt:33.40 (29.9hz) dtRlead: 1.77 (565.5hz) dtWfoll: 0.28 (3580.9hz) dtRfoll: 1.71 (585.0hz) dtRlaptop:32.10 (31.2hz) dtRphone:32.12 (31.1hz)
# INFO 2025-04-13 17:11:24 rol_utils.py:82 dt:33.40 (29.9hz) dtRlead: 1.71 (585.2hz) dtWfoll: 0.21 (4702.6hz) dtRfoll: 1.75 (570.7hz) dtRlaptop:32.03 (31.2hz) dtRphone:32.02 (31.2hz)
# INFO 2025-04-13 17:11:24 rol_utils.py:82 dt:33.46 (29.9hz) dtRlead: 1.66 (601.3hz) dtWfoll: 0.24 (4132.0hz) dtRfoll: 1.72 (580.3hz) dtRlaptop:36.02 (27.8hz) dtRphone:36.02 (27.8hz)
# INFO 2025-04-13 17:11:24 rol_utils.py:82 dt:33.40 (29.9hz) dtRlead: 1.71 (585.5hz) dtWfoll: 0.26 (3919.8hz) dtRfoll: 1.76 (568.7hz) dtRlaptop:31.99 (31.3hz) dtRphone:31.98 (31.3hz)
# INFO 2025-04-13 17:11:24 rol_utils.py:82 dt:33.40 (29.9hz) dtRlead: 1.76 (567.1hz) dtWfoll: 0.26 (3883.6hz) dtRfoll: 1.68 (594.9hz) dtRlaptop:35.88 (27.9hz) dtRphone:35.85 (27.9hz)
# INFO 2025-04-13 17:11:24 rol_utils.py:82 dt:33.40 (29.9hz) dtRlead: 1.69 (590.1hz) dtWfoll: 0.33 (3005.8hz) dtRfoll: 1.65 (606.5hz) dtRlaptop:32.16 (31.1hz) dtRphone:32.23 (31.0hz)
# INFO 2025-04-13 17:11:24 rol_utils.py:82 dt:33.40 (29.9hz) dtRlead: 1.66 (601.2hz) dtWfoll: 0.17 (5788.9hz) dtRfoll: 1.78 (560.4hz) dtRlaptop:32.01 (31.2hz) dtRphone:31.99 (31.3hz)
# INFO 2025-04-13 17:11:24 rol_utils.py:82 dt:33.40 (29.9hz) dtRlead: 1.70 (588.1hz) dtWfoll: 0.33 (3009.9hz) dtRfoll: 1.68 (596.3hz) dtRlaptop:35.62 (28.1hz) dtRphone:35.59 (28.1hz)
# INFO 2025-04-13 17:11:24 rol_utils.py:82 dt:33.40 (29.9hz) dtRlead: 1.74 (574.9hz) dtWfoll: 0.24 (4173.8hz) dtRfoll: 1.78 (562.5hz) dtRlaptop:31.97 (31.3hz) dtRphone:31.99 (31.3hz)
# INFO 2025-04-13 17:11:24 rol_utils.py:82 dt:33.46 (29.9hz) dtRlead: 1.72 (580.8hz) dtWfoll: 0.22 (4616.0hz) dtRfoll: 1.79 (558.7hz) dtRlaptop:33.95 (29.5hz) dtRphone:34.08 (29.3hz)
# INFO 2025-04-13 17:11:24 rol_utils.py:82 dt:33.45 (29.9hz) dtRlead: 1.81 (552.3hz) dtWfoll: 0.29 (3505.7hz) dtRfoll: 1.72 (582.6hz) dtRlaptop:34.74 (28.8hz) dtRphone:34.60 (28.9hz)
# INFO 2025-04-13 17:11:24 rol_utils.py:82 dt:33.44 (29.9hz) dtRlead: 1.66 (603.6hz) dtWfoll: 0.22 (4562.8hz) dtRfoll: 1.67 (598.2hz) dtRlaptop:31.37 (31.9hz) dtRphone:31.37 (31.9hz)
# INFO 2025-04-13 17:11:24 rol_utils.py:82 dt:33.39 (29.9hz) dtRlead: 1.71 (585.8hz) dtWfoll: 0.25 (3950.6hz) dtRfoll: 1.66 (603.2hz) dtRlaptop:32.18 (31.1hz) dtRphone:32.17 (31.1hz)
# INFO 2025-04-13 17:11:24 rol_utils.py:82 dt:33.44 (29.9hz) dtRlead: 1.59 (628.8hz) dtWfoll: 0.14 (7223.4hz) dtRfoll: 1.61 (619.7hz) dtRlaptop:35.96 (27.8hz) dtRphone:35.80 (27.9hz)
# INFO 2025-04-13 17:11:24 rol_utils.py:82 dt:33.40 (29.9hz) dtRlead: 1.77 (565.5hz) dtWfoll: 0.29 (3473.1hz) dtRfoll: 1.65 (607.8hz) dtRlaptop:31.75 (31.5hz) dtRphone:31.71 (31.5hz)
# INFO 2025-04-13 17:11:24 rol_utils.py:82 dt:33.40 (29.9hz) dtRlead: 1.60 (624.3hz) dtWfoll: 0.19 (5259.6hz) dtRfoll: 1.63 (615.0hz) dtRlaptop:32.55 (30.7hz) dtRphone:32.67 (30.6hz)
# INFO 2025-04-13 17:11:24 rol_utils.py:82 dt:33.40 (29.9hz) dtRlead: 1.62 (617.9hz) dtWfoll: 0.21 (4739.6hz) dtRfoll: 1.60 (625.1hz) dtRlaptop:35.34 (28.3hz) dtRphone:35.26 (28.4hz)
# INFO 2025-04-13 17:11:24 rol_utils.py:82 dt:33.40 (29.9hz) dtRlead: 1.67 (597.9hz) dtWfoll: 0.25 (4058.3hz) dtRfoll: 1.61 (620.2hz) dtRlaptop:32.65 (30.6hz) dtRphone:32.75 (30.5hz)
# INFO 2025-04-13 17:11:24 rol_utils.py:82 dt:33.40 (29.9hz) dtRlead: 1.58 (631.5hz) dtWfoll: 0.17 (5889.2hz) dtRfoll: 1.62 (618.1hz) dtRlaptop:31.78 (31.5hz) dtRphone:31.81 (31.4hz)
# INFO 2025-04-13 17:11:24 rol_utils.py:82 dt:33.40 (29.9hz) dtRlead: 1.66 (603.4hz) dtWfoll: 0.18 (5602.5hz) dtRfoll: 1.61 (622.8hz) dtRlaptop:35.99 (27.8hz) dtRphone:35.88 (27.9hz)
# INFO 2025-04-13 17:11:24 rol_utils.py:82 dt:33.41 (29.9hz) dtRlead: 1.59 (628.6hz) dtWfoll: 0.26 (3807.5hz) dtRfoll: 1.68 (596.3hz) dtRlaptop:32.94 (30.4hz) dtRphone:33.01 (30.3hz)
# INFO 2025-04-13 17:11:24 rol_utils.py:82 dt:33.40 (29.9hz) dtRlead: 1.65 (605.8hz) dtWfoll: 0.25 (3941.8hz) dtRfoll: 1.72 (580.0hz) dtRlaptop:35.44 (28.2hz) dtRphone:35.40 (28.2hz)
# INFO 2025-04-13 17:11:24 rol_utils.py:82 dt:33.40 (29.9hz) dtRlead: 1.68 (595.6hz) dtWfoll: 0.17 (5983.3hz) dtRfoll: 1.66 (604.2hz) dtRlaptop:31.83 (31.4hz) dtRphone:31.88 (31.4hz)
# INFO 2025-04-13 17:11:24 rol_utils.py:82 dt:33.40 (29.9hz) dtRlead: 2.20 (453.7hz) dtWfoll: 0.19 (5257.4hz) dtRfoll: 1.70 (589.1hz) dtRlaptop:31.52 (31.7hz) dtRphone:31.55 (31.7hz)
# INFO 2025-04-13 17:11:24 rol_utils.py:82 dt:33.46 (29.9hz) dtRlead: 1.58 (634.1hz) dtWfoll: 0.18 (5624.7hz) dtRfoll: 1.64 (608.4hz) dtRlaptop:36.65 (27.3hz) dtRphone:36.57 (27.3hz)
# INFO 2025-04-13 17:11:24 rol_utils.py:82 dt:33.46 (29.9hz) dtRlead: 1.71 (586.0hz) dtWfoll: 0.35 (2845.7hz) dtRfoll: 1.62 (618.8hz) dtRlaptop:31.50 (31.8hz) dtRphone:31.73 (31.5hz)
# INFO 2025-04-13 17:11:24 rol_utils.py:82 dt:33.41 (29.9hz) dtRlead: 1.76 (569.6hz) dtWfoll: 0.40 (2507.8hz) dtRfoll: 1.75 (572.7hz) dtRlaptop:32.29 (31.0hz) dtRphone:32.31 (30.9hz)
# INFO 2025-04-13 17:11:24 rol_utils.py:82 dt:33.47 (29.9hz) dtRlead: 1.77 (564.2hz) dtWfoll: 0.27 (3744.9hz) dtRfoll: 1.67 (598.4hz) dtRlaptop:35.67 (28.0hz) dtRphone:35.68 (28.0hz)
# INFO 2025-04-13 17:11:24 rol_utils.py:82 dt:33.40 (29.9hz) dtRlead: 1.77 (566.2hz) dtWfoll: 0.31 (3233.4hz) dtRfoll: 1.77 (565.3hz) dtRlaptop:32.17 (31.1hz) dtRphone:32.18 (31.1hz)
# INFO 2025-04-13 17:11:24 rol_utils.py:82 dt:33.45 (29.9hz) dtRlead: 1.61 (619.8hz) dtWfoll: 0.18 (5707.9hz) dtRfoll: 1.64 (609.5hz) dtRlaptop:32.01 (31.2hz) dtRphone:31.52 (31.7hz)
# INFO 2025-04-13 17:11:25 rol_utils.py:82 dt:33.40 (29.9hz) dtRlead: 1.68 (595.8hz) dtWfoll: 0.18 (5510.3hz) dtRfoll: 1.75 (570.8hz) dtRlaptop:37.22 (26.9hz) dtRphone:37.21 (26.9hz)
# INFO 2025-04-13 17:11:25 rol_utils.py:82 dt:33.40 (29.9hz) dtRlead: 1.61 (622.7hz) dtWfoll: 0.25 (4080.9hz) dtRfoll: 1.71 (584.8hz) dtRlaptop:31.16 (32.1hz) dtRphone:31.02 (32.2hz)
# INFO 2025-04-13 17:11:25 rol_utils.py:82 dt:33.40 (29.9hz) dtRlead: 1.67 (597.7hz) dtWfoll: 0.24 (4192.4hz) dtRfoll: 1.68 (595.6hz) dtRlaptop:33.05 (30.3hz) dtRphone:33.33 (30.0hz)
# INFO 2025-04-13 17:11:25 rol_utils.py:82 dt:33.40 (29.9hz) dtRlead: 1.65 (607.2hz) dtWfoll: 0.26 (3808.0hz) dtRfoll: 1.68 (594.2hz) dtRlaptop:34.51 (29.0hz) dtRphone:34.55 (28.9hz)
# INFO 2025-04-13 17:11:25 rol_utils.py:82 dt:33.40 (29.9hz) dtRlead: 1.68 (596.7hz) dtWfoll: 0.18 (5708.9hz) dtRfoll: 1.63 (613.3hz) dtRlaptop:32.33 (30.9hz) dtRphone:32.42 (30.8hz)
# INFO 2025-04-13 17:11:25 rol_utils.py:82 dt:33.44 (29.9hz) dtRlead: 1.64 (610.5hz) dtWfoll: 0.26 (3895.7hz) dtRfoll: 1.64 (608.9hz) dtRlaptop:35.81 (27.9hz) dtRphone:35.44 (28.2hz)
# INFO 2025-04-13 17:11:25 rol_utils.py:82 dt:33.40 (29.9hz) dtRlead: 1.68 (596.7hz) dtWfoll: 0.25 (3974.8hz) dtRfoll: 1.72 (581.5hz) dtRlaptop:32.46 (30.8hz) dtRphone:32.51 (30.8hz)
# INFO 2025-04-13 17:11:25 rol_utils.py:82 dt:33.40 (29.9hz) dtRlead: 1.75 (571.6hz) dtWfoll: 0.28 (3607.9hz) dtRfoll: 1.73 (579.5hz) dtRlaptop:31.69 (31.6hz) dtRphone:31.67 (31.6hz)
# INFO 2025-04-13 17:11:25 rol_utils.py:82 dt:33.40 (29.9hz) dtRlead: 1.68 (596.6hz) dtWfoll: 0.18 (5574.1hz) dtRfoll: 1.69 (591.5hz) dtRlaptop:35.54 (28.1hz) dtRphone:35.82 (27.9hz)
# INFO 2025-04-13 17:11:25 rol_utils.py:82 dt:33.40 (29.9hz) dtRlead: 1.73 (578.3hz) dtWfoll: 0.21 (4801.8hz) dtRfoll: 1.66 (603.8hz) dtRlaptop:32.09 (31.2hz) dtRphone:32.48 (30.8hz)
# INFO 2025-04-13 17:11:25 rol_utils.py:82 dt:33.40 (29.9hz) dtRlead: 1.67 (599.3hz) dtWfoll: 0.25 (4021.5hz) dtRfoll: 1.78 (563.1hz) dtRlaptop:33.09 (30.2hz) dtRphone:32.98 (30.3hz)
# INFO 2025-04-13 17:11:25 rol_utils.py:82 dt:33.40 (29.9hz) dtRlead: 1.55 (643.8hz) dtWfoll: 0.25 (3995.3hz) dtRfoll: 1.59 (629.6hz) dtRlaptop:34.66 (28.9hz) dtRphone:34.70 (28.8hz)
# INFO 2025-04-13 17:11:25 rol_utils.py:82 dt:33.40 (29.9hz) dtRlead: 1.60 (623.5hz) dtWfoll: 0.22 (4472.6hz) dtRfoll: 1.60 (626.3hz) dtRlaptop:31.93 (31.3hz) dtRphone:31.92 (31.3hz)
# INFO 2025-04-13 17:11:25 rol_utils.py:82 dt:33.40 (29.9hz) dtRlead: 1.64 (610.6hz) dtWfoll: 0.20 (5116.8hz) dtRfoll: 1.60 (625.9hz) dtRlaptop:32.20 (31.1hz) dtRphone:32.15 (31.1hz)
# INFO 2025-04-13 17:11:25 rol_utils.py:82 dt:33.40 (29.9hz) dtRlead: 1.56 (641.8hz) dtWfoll: 0.20 (5047.2hz) dtRfoll: 1.67 (599.1hz) dtRlaptop:35.59 (28.1hz) dtRphone:35.59 (28.1hz)
# INFO 2025-04-13 17:11:25 rol_utils.py:82 dt:33.40 (29.9hz) dtRlead: 1.55 (646.1hz) dtWfoll: 0.25 (4028.0hz) dtRfoll: 1.60 (624.7hz) dtRlaptop:32.23 (31.0hz) dtRphone:32.35 (30.9hz)
# INFO 2025-04-13 17:11:25 rol_utils.py:82 dt:33.40 (29.9hz) dtRlead: 1.57 (635.4hz) dtWfoll: 0.27 (3667.2hz) dtRfoll: 1.60 (625.9hz) dtRlaptop:32.95 (30.4hz) dtRphone:32.82 (30.5hz)
# INFO 2025-04-13 17:11:25 rol_utils.py:82 dt:33.40 (29.9hz) dtRlead: 1.57 (638.5hz) dtWfoll: 0.20 (4981.2hz) dtRfoll: 1.62 (617.5hz) dtRlaptop:36.48 (27.4hz) dtRphone:36.53 (27.4hz)
# INFO 2025-04-13 17:11:25 rol_utils.py:82 dt:33.40 (29.9hz) dtRlead: 1.69 (593.5hz) dtWfoll: 0.31 (3189.5hz) dtRfoll: 1.57 (637.4hz) dtRlaptop:31.00 (32.3hz) dtRphone:30.85 (32.4hz)
# INFO 2025-04-13 17:11:25 rol_utils.py:82 dt:33.45 (29.9hz) dtRlead: 1.55 (644.9hz) dtWfoll: 0.20 (5020.7hz) dtRfoll: 1.57 (636.1hz) dtRlaptop:35.91 (27.8hz) dtRphone:35.69 (28.0hz)
# INFO 2025-04-13 17:11:25 rol_utils.py:82 dt:33.40 (29.9hz) dtRlead: 1.63 (615.2hz) dtWfoll: 0.34 (2912.1hz) dtRfoll: 1.66 (604.1hz) dtRlaptop:31.89 (31.4hz) dtRphone:32.07 (31.2hz)
# INFO 2025-04-13 17:11:25 rol_utils.py:82 dt:33.40 (29.9hz) dtRlead: 1.64 (610.3hz) dtWfoll: 0.20 (5025.4hz) dtRfoll: 1.65 (606.2hz) dtRlaptop:31.72 (31.5hz) dtRphone:31.63 (31.6hz)
# INFO 2025-04-13 17:11:25 rol_utils.py:82 dt:33.44 (29.9hz) dtRlead: 1.71 (585.6hz) dtWfoll: 0.21 (4781.9hz) dtRfoll: 1.65 (606.1hz) dtRlaptop:35.96 (27.8hz) dtRphone:35.93 (27.8hz)
# INFO 2025-04-13 17:11:25 rol_utils.py:82 dt:33.40 (29.9hz) dtRlead: 1.68 (595.1hz) dtWfoll: 0.17 (5717.1hz) dtRfoll: 1.64 (608.8hz) dtRlaptop:32.22 (31.0hz) dtRphone:32.21 (31.0hz)
# INFO 2025-04-13 17:11:25 rol_utils.py:82 dt:33.40 (29.9hz) dtRlead: 1.64 (609.8hz) dtWfoll: 0.23 (4436.8hz) dtRfoll: 1.63 (614.8hz) dtRlaptop:31.84 (31.4hz) dtRphone:31.86 (31.4hz)
# INFO 2025-04-13 17:11:25 rol_utils.py:82 dt:33.40 (29.9hz) dtRlead: 1.66 (602.3hz) dtWfoll: 0.21 (4702.9hz) dtRfoll: 1.69 (592.7hz) dtRlaptop:36.07 (27.7hz) dtRphone:36.25 (27.6hz)
# INFO 2025-04-13 17:11:25 rol_utils.py:82 dt:33.40 (29.9hz) dtRlead: 1.60 (626.5hz) dtWfoll: 0.31 (3176.9hz) dtRfoll: 1.55 (643.1hz) dtRlaptop:32.39 (30.9hz) dtRphone:32.22 (31.0hz)
# INFO 2025-04-13 17:11:25 rol_utils.py:82 dt:33.43 (29.9hz) dtRlead: 1.72 (581.6hz) dtWfoll: 0.77 (1306.7hz) dtRfoll: 1.64 (609.1hz) dtRlaptop:31.97 (31.3hz) dtRphone:31.99 (31.3hz)
# INFO 2025-04-13 17:11:25 rol_utils.py:82 dt:33.40 (29.9hz) dtRlead: 1.71 (584.7hz) dtWfoll: 0.22 (4564.2hz) dtRfoll: 1.77 (564.3hz) dtRlaptop:37.21 (26.9hz) dtRphone:37.41 (26.7hz)
# INFO 2025-04-13 17:11:26 rol_utils.py:82 dt:33.37 (30.0hz) dtRlead: 1.70 (589.1hz) dtWfoll: 0.28 (3606.4hz) dtRfoll: 1.62 (616.2hz) dtRlaptop:31.57 (31.7hz) dtRphone:31.15 (32.1hz)
# INFO 2025-04-13 17:11:26 rol_utils.py:82 dt:33.41 (29.9hz) dtRlead: 1.67 (597.3hz) dtWfoll: 0.23 (4430.7hz) dtRfoll: 1.75 (572.0hz) dtRlaptop:31.35 (31.9hz) dtRphone:31.40 (31.8hz)
# INFO 2025-04-13 17:11:26 rol_utils.py:82 dt:33.40 (29.9hz) dtRlead: 1.71 (586.1hz) dtWfoll: 0.25 (4005.3hz) dtRfoll: 1.70 (589.3hz) dtRlaptop:35.47 (28.2hz) dtRphone:35.72 (28.0hz)
# INFO 2025-04-13 17:11:26 rol_utils.py:82 dt:33.40 (29.9hz) dtRlead: 1.62 (616.7hz) dtWfoll: 0.20 (4914.8hz) dtRfoll: 1.66 (600.9hz) dtRlaptop:31.77 (31.5hz) dtRphone:32.08 (31.2hz)
# INFO 2025-04-13 17:11:26 rol_utils.py:82 dt:33.40 (29.9hz) dtRlead: 1.55 (645.0hz) dtWfoll: 0.22 (4509.7hz) dtRfoll: 1.63 (615.4hz) dtRlaptop:32.57 (30.7hz) dtRphone:32.46 (30.8hz)
# INFO 2025-04-13 17:11:26 rol_utils.py:82 dt:33.40 (29.9hz) dtRlead: 1.87 (534.1hz) dtWfoll: 0.35 (2848.8hz) dtRfoll: 1.68 (593.6hz) dtRlaptop:36.29 (27.6hz) dtRphone:36.27 (27.6hz)
# INFO 2025-04-13 17:11:26 rol_utils.py:82 dt:33.40 (29.9hz) dtRlead: 1.71 (584.9hz) dtWfoll: 0.32 (3094.1hz) dtRfoll: 1.71 (583.7hz) dtRlaptop:32.82 (30.5hz) dtRphone:33.03 (30.3hz)
# INFO 2025-04-13 17:11:26 rol_utils.py:82 dt:33.40 (29.9hz) dtRlead: 1.70 (589.0hz) dtWfoll: 0.26 (3868.8hz) dtRfoll: 1.59 (627.5hz) dtRlaptop:34.51 (29.0hz) dtRphone:34.07 (29.4hz)
# INFO 2025-04-13 17:11:26 rol_utils.py:82 dt:33.40 (29.9hz) dtRlead: 1.55 (646.8hz) dtWfoll: 0.21 (4767.8hz) dtRfoll: 1.58 (631.3hz) dtRlaptop:31.48 (31.8hz) dtRphone:31.54 (31.7hz)
# INFO 2025-04-13 17:11:26 rol_utils.py:82 dt:33.40 (29.9hz) dtRlead: 1.65 (606.2hz) dtWfoll: 0.18 (5687.2hz) dtRfoll: 1.67 (599.1hz) dtRlaptop:31.96 (31.3hz) dtRphone:31.99 (31.3hz)
# INFO 2025-04-13 17:11:26 rol_utils.py:82 dt:33.41 (29.9hz) dtRlead: 1.72 (582.4hz) dtWfoll: 0.31 (3277.8hz) dtRfoll: 1.71 (586.3hz) dtRlaptop:36.36 (27.5hz) dtRphone:36.36 (27.5hz)
# INFO 2025-04-13 17:11:26 rol_utils.py:82 dt:33.40 (29.9hz) dtRlead: 1.72 (580.3hz) dtWfoll: 0.32 (3129.1hz) dtRfoll: 1.76 (568.5hz) dtRlaptop:31.64 (31.6hz) dtRphone:31.77 (31.5hz)
# INFO 2025-04-13 17:11:26 rol_utils.py:82 dt:33.44 (29.9hz) dtRlead: 1.70 (586.7hz) dtWfoll: 0.21 (4804.5hz) dtRfoll: 1.69 (590.7hz) dtRlaptop:33.17 (30.1hz) dtRphone:33.28 (30.0hz)
# INFO 2025-04-13 17:11:26 rol_utils.py:82 dt:33.44 (29.9hz) dtRlead: 1.80 (557.0hz) dtWfoll: 0.22 (4460.9hz) dtRfoll: 1.71 (583.2hz) dtRlaptop:35.31 (28.3hz) dtRphone:35.32 (28.3hz)
# INFO 2025-04-13 17:11:26 rol_utils.py:82 dt:33.44 (29.9hz) dtRlead: 1.79 (559.2hz) dtWfoll: 0.30 (3296.1hz) dtRfoll: 1.64 (611.6hz) dtRlaptop:31.81 (31.4hz) dtRphone:31.75 (31.5hz)
# ...
# INFO 2025-04-13 17:11:39 rol_utils.py:82 dt:33.40 (29.9hz) dtRlead: 1.64 (608.8hz) dtWfoll: 0.61 (1626.3hz) dtRfoll: 1.60 (625.5hz) dtRlaptop:32.63 (30.6hz) dtRphone:32.64 (30.6hz)
# INFO 2025-04-13 17:11:39 rol_utils.py:82 dt:33.40 (29.9hz) dtRlead: 1.59 (630.7hz) dtWfoll: 0.22 (4599.3hz) dtRfoll: 1.57 (635.5hz) dtRlaptop:35.81 (27.9hz) dtRphone:35.49 (28.2hz)
# INFO 2025-04-13 17:11:39 rol_utils.py:82 dt:33.40 (29.9hz) dtRlead: 1.65 (605.0hz) dtWfoll: 0.17 (5879.9hz) dtRfoll: 1.76 (569.5hz) dtRlaptop:33.18 (30.1hz) dtRphone:34.18 (29.3hz)
# INFO 2025-04-13 17:11:39 rol_utils.py:82 dt:33.40 (29.9hz) dtRlead: 1.75 (570.7hz) dtWfoll: 0.24 (4242.0hz) dtRfoll: 1.74 (574.8hz) dtRlaptop:32.68 (30.6hz) dtRphone:32.38 (30.9hz)
# INFO 2025-04-13 17:11:39 rol_utils.py:82 dt:33.40 (29.9hz) dtRlead: 1.82 (549.8hz) dtWfoll: 0.25 (4062.9hz) dtRfoll: 1.92 (520.3hz) dtRlaptop:34.48 (29.0hz) dtRphone:33.84 (29.6hz)
# INFO 2025-04-13 17:11:39 rol_utils.py:82 dt:33.40 (29.9hz) dtRlead: 1.78 (561.5hz) dtWfoll: 0.18 (5511.3hz) dtRfoll: 1.62 (616.4hz) dtRlaptop:31.45 (31.8hz) dtRphone:31.84 (31.4hz)
# INFO 2025-04-13 17:11:39 rol_utils.py:82 dt:33.40 (29.9hz) dtRlead: 1.59 (630.7hz) dtWfoll: 0.26 (3880.0hz) dtRfoll: 1.64 (608.0hz) dtRlaptop:32.75 (30.5hz) dtRphone:32.48 (30.8hz)
# INFO 2025-04-13 17:11:39 rol_utils.py:82 dt:33.40 (29.9hz) dtRlead: 1.73 (576.7hz) dtWfoll: 0.36 (2809.9hz) dtRfoll: 1.66 (603.9hz) dtRlaptop:35.16 (28.4hz) dtRphone:34.95 (28.6hz)
# INFO 2025-04-13 17:11:39 rol_utils.py:82 dt:33.40 (29.9hz) dtRlead: 1.76 (566.7hz) dtWfoll: 0.38 (2605.3hz) dtRfoll: 1.79 (560.0hz) dtRlaptop:32.70 (30.6hz) dtRphone:32.72 (30.6hz)
# INFO 2025-04-13 17:11:39 rol_utils.py:82 dt:33.40 (29.9hz) dtRlead: 1.64 (609.3hz) dtWfoll: 0.26 (3859.9hz) dtRfoll: 1.64 (609.4hz) dtRlaptop:31.34 (31.9hz) dtRphone:31.21 (32.0hz)
# INFO 2025-04-13 17:11:39 rol_utils.py:82 dt:33.44 (29.9hz) dtRlead: 1.57 (635.2hz) dtWfoll: 0.14 (7266.5hz) dtRfoll: 1.77 (564.5hz) dtRlaptop:36.31 (27.5hz) dtRphone:36.40 (27.5hz)
# INFO 2025-04-13 17:11:39 rol_utils.py:82 dt:33.40 (29.9hz) dtRlead: 1.61 (622.0hz) dtWfoll: 0.27 (3653.1hz) dtRfoll: 1.59 (630.7hz) dtRlaptop:32.42 (30.8hz) dtRphone:32.36 (30.9hz)
# INFO 2025-04-13 17:11:39 rol_utils.py:82 dt:33.40 (29.9hz) dtRlead: 1.59 (629.0hz) dtWfoll: 0.22 (4470.9hz) dtRfoll: 1.59 (628.3hz) dtRlaptop:31.13 (32.1hz) dtRphone:31.18 (32.1hz)
# INFO 2025-04-13 17:11:39 rol_utils.py:82 dt:33.41 (29.9hz) dtRlead: 1.63 (613.1hz) dtWfoll: 0.24 (4148.7hz) dtRfoll: 1.81 (553.0hz) dtRlaptop:38.36 (26.1hz) dtRphone:38.24 (26.2hz)
# INFO 2025-04-13 17:11:39 rol_utils.py:82 dt:33.40 (29.9hz) dtRlead: 1.74 (576.1hz) dtWfoll: 0.30 (3334.3hz) dtRfoll: 1.67 (600.2hz) dtRlaptop:30.54 (32.7hz) dtRphone:30.44 (32.9hz)
# INFO 2025-04-13 17:11:39 rol_utils.py:82 dt:33.44 (29.9hz) dtRlead: 1.70 (589.0hz) dtWfoll: 0.52 (1940.4hz) dtRfoll: 1.67 (599.1hz) dtRlaptop:36.51 (27.4hz) dtRphone:36.97 (27.1hz)
# INFO 2025-04-13 17:11:39 rol_utils.py:82 dt:33.40 (29.9hz) dtRlead: 1.59 (630.8hz) dtWfoll: 0.23 (4443.1hz) dtRfoll: 1.65 (605.1hz) dtRlaptop:32.42 (30.8hz) dtRphone:32.54 (30.7hz)
# INFO 2025-04-13 17:11:39 rol_utils.py:82 dt:33.40 (29.9hz) dtRlead: 1.65 (605.8hz) dtWfoll: 0.27 (3714.9hz) dtRfoll: 1.60 (625.0hz) dtRlaptop:32.35 (30.9hz) dtRphone:32.55 (30.7hz)
# INFO 2025-04-13 17:11:39 rol_utils.py:82 dt:33.43 (29.9hz) dtRlead: 1.67 (598.9hz) dtWfoll: 0.32 (3086.8hz) dtRfoll: 1.62 (617.5hz) dtRlaptop:36.00 (27.8hz) dtRphone:35.94 (27.8hz)
# INFO 2025-04-13 17:11:39 rol_utils.py:82 dt:33.40 (29.9hz) dtRlead: 1.71 (585.7hz) dtWfoll: 0.30 (3300.6hz) dtRfoll: 1.63 (612.4hz) dtRlaptop:30.85 (32.4hz) dtRphone:30.61 (32.7hz)
# INFO 2025-04-13 17:11:40 rol_utils.py:82 dt:33.58 (29.8hz) dtRlead: 1.67 (599.5hz) dtWfoll: 0.31 (3242.2hz) dtRfoll: 1.59 (628.9hz) dtRlaptop:32.92 (30.4hz) dtRphone:33.05 (30.3hz)
# INFO 2025-04-13 17:11:40 rol_utils.py:82 dt:33.43 (29.9hz) dtRlead: 1.77 (563.5hz) dtWfoll: 0.29 (3471.4hz) dtRfoll: 1.68 (594.9hz) dtRlaptop:34.89 (28.7hz) dtRphone:34.76 (28.8hz)
# INFO 2025-04-13 17:11:40 rol_utils.py:82 dt:33.44 (29.9hz) dtRlead: 1.79 (558.7hz) dtWfoll: 0.28 (3542.3hz) dtRfoll: 1.65 (607.2hz) dtRlaptop:31.19 (32.1hz) dtRphone:31.24 (32.0hz)
# INFO 2025-04-13 17:11:40 rol_utils.py:82 dt:33.44 (29.9hz) dtRlead: 1.81 (551.6hz) dtWfoll: 0.29 (3408.8hz) dtRfoll: 1.72 (582.8hz) dtRlaptop:32.40 (30.9hz) dtRphone:32.37 (30.9hz)
# INFO 2025-04-13 17:11:40 rol_utils.py:82 dt:33.40 (29.9hz) dtRlead: 1.62 (617.8hz) dtWfoll: 0.23 (4340.6hz) dtRfoll: 1.70 (589.3hz) dtRlaptop:35.88 (27.9hz) dtRphone:35.90 (27.9hz)
# INFO 2025-04-13 17:11:40 rol_utils.py:82 dt:33.40 (29.9hz) dtRlead: 1.64 (608.4hz) dtWfoll: 0.23 (4286.1hz) dtRfoll: 1.59 (627.1hz) dtRlaptop:32.69 (30.6hz) dtRphone:32.71 (30.6hz)
# INFO 2025-04-13 17:11:40 rol_utils.py:82 dt:33.40 (29.9hz) dtRlead: 1.65 (604.4hz) dtWfoll: 0.21 (4660.0hz) dtRfoll: 1.68 (595.3hz) dtRlaptop:32.19 (31.1hz) dtRphone:32.13 (31.1hz)
# INFO 2025-04-13 17:11:40 rol_utils.py:82 dt:33.37 (30.0hz) dtRlead: 1.70 (589.2hz) dtWfoll: 0.29 (3416.9hz) dtRfoll: 1.71 (586.0hz) dtRlaptop:35.25 (28.4hz) dtRphone:35.28 (28.3hz)
# INFO 2025-04-13 17:11:40 rol_utils.py:82 dt:33.47 (29.9hz) dtRlead: 1.59 (628.3hz) dtWfoll: 0.29 (3479.8hz) dtRfoll: 1.58 (633.5hz) dtRlaptop:31.33 (31.9hz) dtRphone:31.48 (31.8hz)
# INFO 2025-04-13 17:11:40 rol_utils.py:82 dt:33.40 (29.9hz) dtRlead: 1.65 (606.5hz) dtWfoll: 0.30 (3387.1hz) dtRfoll: 1.65 (606.9hz) dtRlaptop:37.04 (27.0hz) dtRphone:36.94 (27.1hz)
# Right arrow key pressed. Exiting loop...
# INFO 2025-04-13 17:11:40 rol_utils.py:82 dt:33.40 (29.9hz) dtRlead: 1.59 (630.5hz) dtWfoll: 0.18 (5480.3hz) dtRfoll: 1.60 (625.3hz) dtRlaptop:32.06 (31.2hz) dtRphone:32.28 (31.0hz)
# Map: 100%|███████████████████████████| 526/526 [00:00<00:00, 5590.62 examples/s]
# Creating parquet from Arrow format: 100%|███████| 1/1 [00:00<00:00, 1865.79ba/s]
# Svt[info]: -------------------------------------------
# Svt[info]: SVT [version]:	SVT-AV1 Encoder Lib v3.0.0
# Svt[info]: SVT [build]  :	GCC 13.3.0	 64 bit
# Svt[info]: LIB Build date: Feb 21 2025 00:07:10
# Svt[info]: -------------------------------------------
# Svt[info]: Level of Parallelism: 6
# Svt[info]: Number of PPCS 305
# Svt[info]: [asm level on system : up to avx2]
# Svt[info]: [asm level selected : up to avx2]
# Svt[info]: -------------------------------------------
# Svt[info]: SVT [config]: main profile	tier (auto)	level (auto)
# Svt[info]: SVT [config]: width / height / fps numerator / fps denominator 		: 640 / 480 / 30 / 1
# Svt[info]: SVT [config]: bit-depth / color format 					: 8 / YUV420
# Svt[info]: SVT [config]: preset / tune / pred struct 					: 8 / PSNR / random access
# Svt[info]: SVT [config]: gop size / mini-gop size / key-frame type 			: 2 / 32 / key frame
# Svt[info]: SVT [config]: BRC mode / rate factor 					: CRF / 30
# Svt[info]: SVT [config]: AQ mode / variance boost 					: 2 / 0
# Svt[info]: SVT [config]: sharpness / luminance-based QP bias 			: 0 / 0
# Svt[info]: Svt[info]: -------------------------------------------
# Svt[info]: -------------------------------------------
# Svt[info]: SVT [version]:	SVT-AV1 Encoder Lib v3.0.0
# Svt[info]: SVT [build]  :	GCC 13.3.0	 64 bit
# Svt[info]: LIB Build date: Feb 21 2025 00:07:10
# Svt[info]: -------------------------------------------
# Svt[info]: Level of Parallelism: 6
# Svt[info]: Number of PPCS 305
# Svt[info]: [asm level on system : up to avx2]
# Svt[info]: [asm level selected : up to avx2]
# Svt[info]: -------------------------------------------
# Svt[info]: SVT [config]: main profile	tier (auto)	level (auto)
# Svt[info]: SVT [config]: width / height / fps numerator / fps denominator 		: 640 / 480 / 30 / 1
# Svt[info]: SVT [config]: bit-depth / color format 					: 8 / YUV420
# Svt[info]: SVT [config]: preset / tune / pred struct 					: 8 / PSNR / random access
# Svt[info]: SVT [config]: gop size / mini-gop size / key-frame type 			: 2 / 32 / key frame
# Svt[info]: SVT [config]: BRC mode / rate factor 					: CRF / 30
# Svt[info]: SVT [config]: AQ mode / variance boost 					: 2 / 0
# Svt[info]: SVT [config]: sharpness / luminance-based QP bias 			: 0 / 0
# Svt[info]: Svt[info]: -------------------------------------------
# INFO 2025-04-13 17:11:44 ls/utils.py:200 Stop recording
# It seems you are trying to upload a large folder at once. This might take some time and then fail if the folder is too large. For such cases, it is recommended to upload in smaller batches or to use `HfApi().upload_large_folder(...)`/`huggingface-cli upload-large-folder` instead. For more details, check out https://huggingface.co/docs/huggingface_hub/main/en/guides/upload#upload-a-large-folder.
# WARNING 2025-04-13 17:11:45 /hf_api.py:9196 It seems you are trying to upload a large folder at once. This might take some time and then fail if the folder is too large. For such cases, it is recommended to upload in smaller batches or to use `HfApi().upload_large_folder(...)`/`huggingface-cli upload-large-folder` instead. For more details, check out https://huggingface.co/docs/huggingface_hub/main/en/guides/upload#upload-a-large-folder.
# episode_000267.parquet:   0%|                       | 0.00/30.6k [00:00<?, ?B/s]
# episode_000267.mp4:   0%|                           | 0.00/6.34M [00:00<?, ?B/s]
#
# Upload 3 LFS files:   0%|                                 | 0/3 [00:00<?, ?it/s]
#
#
# episode_000267.mp4:   0%|                           | 0.00/10.7M [00:00<?, ?B/s]
#
#
# episode_000267.mp4:   3%|▌                  | 311k/10.7M [00:00<00:03, 2.75MB/s]
# episode_000267.mp4:   4%|▊                  | 279k/6.34M [00:00<00:02, 2.22MB/s]
# episode_000267.parquet: 100%|██████████████| 30.6k/30.6k [00:00<00:00, 89.6kB/s]
#
#
#
# episode_000267.mp4:   6%|█▏                 | 639k/10.7M [00:00<00:05, 1.75MB/s]
# episode_000267.mp4:  12%|██▎                | 786k/6.34M [00:00<00:03, 1.80MB/s]
#
#
# episode_000267.mp4:   8%|█▍                 | 836k/10.7M [00:00<00:06, 1.47MB/s]
# episode_000267.mp4:  18%|███▏              | 1.11M/6.34M [00:00<00:02, 1.91MB/s]
#
#
# episode_000267.mp4:  10%|█▋                | 1.03M/10.7M [00:00<00:07, 1.33MB/s]
#
# Upload 3 LFS files:  33%|████████▎                | 1/3 [00:00<00:01,  1.37it/s]
# episode_000267.mp4:  24%|████▎             | 1.51M/6.34M [00:00<00:02, 1.86MB/s]
#
#
# episode_000267.mp4:  11%|██                | 1.23M/10.7M [00:00<00:06, 1.39MB/s]
# episode_000267.mp4:  27%|████▊             | 1.70M/6.34M [00:00<00:02, 1.58MB/s]
#
#
# episode_000267.mp4:  13%|██▎               | 1.41M/10.7M [00:01<00:07, 1.20MB/s]
# episode_000267.mp4:  30%|█████▎            | 1.88M/6.34M [00:01<00:02, 1.51MB/s]
#
#
# episode_000267.mp4:  16%|██▊               | 1.67M/10.7M [00:01<00:06, 1.34MB/s]
#
#
# episode_000267.mp4:  18%|███▏              | 1.93M/10.7M [00:01<00:06, 1.43MB/s]
# episode_000267.mp4:  34%|██████            | 2.15M/6.34M [00:01<00:03, 1.35MB/s]
#
#
# episode_000267.mp4:  20%|███▌              | 2.11M/10.7M [00:01<00:06, 1.35MB/s]
# episode_000267.mp4:  38%|██████▊           | 2.39M/6.34M [00:01<00:02, 1.32MB/s]
#
#
# episode_000267.mp4:  21%|███▊              | 2.31M/10.7M [00:01<00:06, 1.31MB/s]
# episode_000267.mp4:  42%|███████▌          | 2.65M/6.34M [00:01<00:03, 1.22MB/s]
#
#
# episode_000267.mp4:  23%|████▏             | 2.51M/10.7M [00:01<00:06, 1.32MB/s]
#
#
# episode_000267.mp4:  25%|████▌             | 2.70M/10.7M [00:01<00:06, 1.28MB/s]
# episode_000267.mp4:  46%|████████▎         | 2.92M/6.34M [00:02<00:02, 1.20MB/s]
#
#
# episode_000267.mp4:  27%|████▊             | 2.88M/10.7M [00:02<00:06, 1.29MB/s]
#
#
# episode_000267.mp4:  29%|█████▏            | 3.08M/10.7M [00:02<00:05, 1.33MB/s]
# episode_000267.mp4:  50%|████████▉         | 3.16M/6.34M [00:02<00:02, 1.08MB/s]
#
#
# episode_000267.mp4:  30%|█████▍            | 3.28M/10.7M [00:02<00:05, 1.34MB/s]
# episode_000267.mp4:  53%|██████████         | 3.36M/6.34M [00:02<00:02, 998kB/s]
#
#
# episode_000267.mp4:  33%|█████▉            | 3.54M/10.7M [00:02<00:05, 1.34MB/s]
#
#
# episode_000267.mp4:  35%|██████▏           | 3.72M/10.7M [00:02<00:05, 1.35MB/s]
# episode_000267.mp4:  57%|██████████▎       | 3.62M/6.34M [00:02<00:02, 1.04MB/s]
#
#
# episode_000267.mp4:  36%|██████▌           | 3.92M/10.7M [00:02<00:04, 1.38MB/s]
#
#
# episode_000267.mp4:  38%|██████▉           | 4.11M/10.7M [00:02<00:04, 1.38MB/s]
# episode_000267.mp4:  61%|██████████▉       | 3.87M/6.34M [00:03<00:02, 1.06MB/s]
#
#
# episode_000267.mp4:  40%|███████▏          | 4.31M/10.7M [00:03<00:05, 1.26MB/s]
# episode_000267.mp4:  65%|███████████▋      | 4.13M/6.34M [00:03<00:01, 1.13MB/s]
#
#
# episode_000267.mp4:  42%|███████▌          | 4.49M/10.7M [00:03<00:05, 1.24MB/s]
# episode_000267.mp4:  68%|████████████▎     | 4.33M/6.34M [00:03<00:01, 1.12MB/s]
#
#
# episode_000267.mp4:  44%|███████▉          | 4.75M/10.7M [00:03<00:04, 1.32MB/s]
# episode_000267.mp4:  72%|█████████████     | 4.59M/6.34M [00:03<00:01, 1.10MB/s]
#
#
# episode_000267.mp4:  46%|████████▎         | 4.95M/10.7M [00:03<00:04, 1.24MB/s]
# episode_000267.mp4:  75%|█████████████▌    | 4.77M/6.34M [00:03<00:01, 1.11MB/s]
#
#
# episode_000267.mp4:  48%|████████▌         | 5.14M/10.7M [00:03<00:04, 1.26MB/s]
#
#
# episode_000267.mp4:  50%|████████▉         | 5.32M/10.7M [00:03<00:04, 1.23MB/s]
# episode_000267.mp4:  79%|██████████████▎   | 5.03M/6.34M [00:04<00:01, 1.13MB/s]
#
#
# episode_000267.mp4:  51%|█████████▏        | 5.52M/10.7M [00:04<00:04, 1.22MB/s]
# episode_000267.mp4:  83%|███████████████   | 5.29M/6.34M [00:04<00:00, 1.14MB/s]
#
#
# episode_000267.mp4:  53%|█████████▌        | 5.72M/10.7M [00:04<00:04, 1.22MB/s]
# episode_000267.mp4:  87%|███████████████▋  | 5.54M/6.34M [00:04<00:00, 1.14MB/s]
#
#
# episode_000267.mp4:  55%|█████████▉        | 5.91M/10.7M [00:04<00:03, 1.23MB/s]
#
#
# episode_000267.mp4:  57%|██████████▏       | 6.09M/10.7M [00:04<00:03, 1.31MB/s]
# episode_000267.mp4:  90%|████████████████▎ | 5.73M/6.34M [00:04<00:00, 1.08MB/s]
#
#
# episode_000267.mp4:  59%|██████████▋       | 6.36M/10.7M [00:04<00:03, 1.28MB/s]
# episode_000267.mp4:  95%|█████████████████ | 6.00M/6.34M [00:04<00:00, 1.15MB/s]
#
#
# episode_000267.mp4:  61%|██████████▉       | 6.55M/10.7M [00:05<00:03, 1.15MB/s]
# episode_000267.mp4:  98%|█████████████████▋| 6.24M/6.34M [00:05<00:00, 1.19MB/s]
#
#
# episode_000267.mp4:  63%|███████████▎      | 6.73M/10.7M [00:05<00:03, 1.21MB/s]
#
#
# episode_000267.mp4:  64%|███████████▌      | 6.93M/10.7M [00:05<00:02, 1.32MB/s]
#
#
# episode_000267.mp4:  66%|███████████▉      | 7.13M/10.7M [00:05<00:02, 1.26MB/s]
#
#
# episode_000267.mp4:  68%|████████████▎     | 7.32M/10.7M [00:05<00:02, 1.32MB/s]
#
#
# episode_000267.mp4:  70%|████████████▋     | 7.57M/10.7M [00:05<00:02, 1.55MB/s]
#
#
# episode_000267.mp4: 100%|██████████████████| 6.34M/6.34M [00:05<00:00, 1.07MB/s]
#
#
#
# episode_000267.mp4:  77%|█████████████▊    | 8.22M/10.7M [00:05<00:01, 1.96MB/s]
#
#
# episode_000267.mp4:  80%|██████████████▍   | 8.60M/10.7M [00:06<00:01, 2.09MB/s]
#
#
# episode_000267.mp4:  84%|███████████████   | 8.99M/10.7M [00:06<00:00, 2.22MB/s]
#
#
# episode_000267.mp4:  86%|███████████████▍  | 9.24M/10.7M [00:06<00:00, 2.25MB/s]
#
#
# episode_000267.mp4:  88%|███████████████▉  | 9.50M/10.7M [00:06<00:00, 2.25MB/s]
#
#
# episode_000267.mp4:  91%|████████████████▎ | 9.76M/10.7M [00:06<00:00, 2.33MB/s]
#
#
# episode_000267.mp4:  94%|████████████████▉ | 10.1M/10.7M [00:06<00:00, 2.35MB/s]
#
#
# episode_000267.mp4: 100%|██████████████████| 10.7M/10.7M [00:07<00:00, 1.42MB/s]
#
#
# Upload 3 LFS files: 100%|█████████████████████████| 3/3 [00:07<00:00,  2.62s/it]
# INFO 2025-04-13 17:12:06 ls/utils.py:200 Exiting
# Loaded home positions from /home/jacob/lerobot/.cache/calibration/so100/red_home_position.json
# Connected to red robot on port /dev/ttyACM1
# Calibration loaded.
# Moving to preset position...
# Positions after moving to preset:
#   shoulder_pan: -0.09
#   shoulder_lift: 163.48
#   elbow_flex: 124.01
#   wrist_flex: 79.10
#   wrist_roll: -100.72
#   gripper: 0.37
# Moving to home position...
# Final positions (home):
#   shoulder_pan: -0.44
#   shoulder_lift: 179.65
#   elbow_flex: 131.66
#   wrist_flex: 87.19
#   wrist_roll: -90.09
#   gripper: 0.59
# Disconnected.

# %%
#add a single episode to the Blue dataset
#Blue side dataset record instruction
# !python lerobot/scripts/control_robot.py \
  --robot.type=so100-blue \
  --control.type=record \
  --control.fps=30 \
  --control.single_task="Move the blue chess pieces as indicated by the highlighted squares" \
  --control.repo_id="Chojins/chess_game_001_blue_stereo" \
  --control.tags='["so100","chess"]' \
  --control.warmup_time_s=25 \
  --control.episode_time_s=360 \
  --control.reset_time_s=20 \
  --control.num_episodes=1 \
  --control.push_to_hub=true \
  --control.resume=true

#home
# !python /home/jacob/Documents/robot_control/move_home.py blue
# Out:
# INFO 2025-04-13 17:16:12 ol_robot.py:369 {'control': {'display_cameras': True,
#              'episode_time_s': 360,
#              'fps': 30,
#              'num_episodes': 1,
#              'num_image_writer_processes': 0,
#              'num_image_writer_threads_per_camera': 4,
#              'play_sounds': True,
#              'policy': None,
#              'private': False,
#              'push_to_hub': True,
#              'repo_id': 'Chojins/chess_game_001_blue_stereo',
#              'reset_time_s': 20,
#              'resume': True,
#              'root': None,
#              'single_task': 'Move the blue chess pieces as indicated by the '
#                             'highlighted squares',
#              'tags': ['so100', 'chess'],
#              'video': True,
#              'warmup_time_s': 25},
#  'robot': {'calibration_dir': '.cache/calibration/so100-blue',
#            'cameras': {'laptop': {'camera_index': 4,
#                                   'channels': 3,
#                                   'color_mode': 'rgb',
#                                   'fps': 30,
#                                   'height': 480,
#                                   'mock': False,
#                                   'rotation': None,
#                                   'width': 640},
#                        'phone': {'camera_index': 5,
#                                  'channels': 3,
#                                  'color_mode': 'rgb',
#                                  'fps': 30,
#                                  'height': 480,
#                                  'mock': False,
#                                  'rotation': None,
#                                  'width': 640}},
#            'follower_arms': {'main': {'mock': False,
#                                       'motors': {'elbow_flex': [3, 'sts3215'],
#                                                  'gripper': [6, 'sts3215'],
#                                                  'shoulder_lift': [2,
#                                                                    'sts3215'],
#                                                  'shoulder_pan': [1, 'sts3215'],
#                                                  'wrist_flex': [4, 'sts3215'],
#                                                  'wrist_roll': [5, 'sts3215']},
#                                       'port': '/dev/ttyACM2'}},
#            'gripper_open_degree': None,
#            'leader_arms': {'main': {'mock': False,
#                                     'motors': {'elbow_flex': [3, 'sts3215'],
#                                                'gripper': [6, 'sts3215'],
#                                                'shoulder_lift': [2, 'sts3215'],
#                                                'shoulder_pan': [1, 'sts3215'],
#                                                'wrist_flex': [4, 'sts3215'],
#                                                'wrist_roll': [5, 'sts3215']},
#                                     'port': '/dev/ttyACM0'}},
#            'max_relative_target': None,
#            'mock': False}}
# Resolving data files: 100%|████████████████| 307/307 [00:00<00:00, 88797.42it/s]
# Downloading data: 100%|████████████████| 307/307 [00:00<00:00, 108580.09files/s]
# Generating train split: 109125 examples [00:00, 532033.26 examples/s]
# Connecting main follower arm.
# Connecting main leader arm.
# Activating torque on main follower arm.
# INFO 2025-04-13 17:16:14 ls/utils.py:200 Warmup record
# INFO 2025-04-13 17:16:15 rol_utils.py:82 dt:125.37 (8.0hz) dtRlead: 1.66 (603.4hz) dtWfoll: 0.27 (3711.9hz) dtRfoll: 1.72 (580.0hz) dtRlaptop:21.87 (45.7hz) dtRphone:24.74 (40.4hz)
# INFO 2025-04-13 17:16:15 rol_utils.py:82 dt:33.43 (29.9hz) dtRlead: 1.76 (567.1hz) dtWfoll: 0.24 (4136.5hz) dtRfoll: 1.70 (588.4hz) dtRlaptop:31.26 (32.0hz) dtRphone:31.41 (31.8hz)
# INFO 2025-04-13 17:16:15 rol_utils.py:82 dt:33.38 (30.0hz) dtRlead: 1.91 (523.2hz) dtWfoll: 0.40 (2483.1hz) dtRfoll: 1.95 (512.7hz) dtRlaptop:41.09 (24.3hz) dtRphone:41.18 (24.3hz)
# INFO 2025-04-13 17:16:15 rol_utils.py:82 dt:33.46 (29.9hz) dtRlead: 1.92 (521.9hz) dtWfoll: 0.28 (3545.6hz) dtRfoll: 1.69 (591.2hz) dtRlaptop:41.09 (24.3hz) dtRphone:41.18 (24.3hz)
# INFO 2025-04-13 17:16:15 rol_utils.py:82 dt:33.44 (29.9hz) dtRlead: 1.95 (513.1hz) dtWfoll: 0.32 (3171.6hz) dtRfoll: 1.82 (549.0hz) dtRlaptop:33.81 (29.6hz) dtRphone:33.76 (29.6hz)
# INFO 2025-04-13 17:16:15 rol_utils.py:82 dt:33.41 (29.9hz) dtRlead: 1.88 (533.0hz) dtWfoll: 0.32 (3159.1hz) dtRfoll: 1.67 (598.1hz) dtRlaptop:33.81 (29.6hz) dtRphone:33.76 (29.6hz)
# INFO 2025-04-13 17:16:15 rol_utils.py:82 dt:33.44 (29.9hz) dtRlead: 1.76 (567.3hz) dtWfoll: 0.28 (3565.3hz) dtRfoll: 1.81 (553.2hz) dtRlaptop:31.95 (31.3hz) dtRphone:32.12 (31.1hz)
# INFO 2025-04-13 17:16:15 rol_utils.py:82 dt:33.43 (29.9hz) dtRlead: 2.01 (496.5hz) dtWfoll: 0.40 (2485.3hz) dtRfoll: 1.72 (580.2hz) dtRlaptop:31.95 (31.3hz) dtRphone:32.12 (31.1hz)
# INFO 2025-04-13 17:16:15 rol_utils.py:82 dt:33.43 (29.9hz) dtRlead: 1.77 (563.4hz) dtWfoll: 0.30 (3308.5hz) dtRfoll: 1.87 (534.6hz) dtRlaptop:25.87 (38.7hz) dtRphone:42.87 (23.3hz)
# INFO 2025-04-13 17:16:15 rol_utils.py:82 dt:33.43 (29.9hz) dtRlead: 2.07 (483.5hz) dtWfoll: 0.38 (2647.4hz) dtRfoll: 1.82 (550.6hz) dtRlaptop:25.87 (38.7hz) dtRphone:25.74 (38.8hz)
# INFO 2025-04-13 17:16:15 rol_utils.py:82 dt:33.42 (29.9hz) dtRlead: 1.86 (537.2hz) dtWfoll: 0.39 (2532.2hz) dtRfoll: 1.67 (600.6hz) dtRlaptop:31.48 (31.8hz) dtRphone:31.17 (32.1hz)
# INFO 2025-04-13 17:16:15 rol_utils.py:82 dt:33.41 (29.9hz) dtRlead: 1.89 (529.8hz) dtWfoll: 0.32 (3167.4hz) dtRfoll: 1.76 (568.9hz) dtRlaptop:31.48 (31.8hz) dtRphone:31.17 (32.1hz)
# INFO 2025-04-13 17:16:15 rol_utils.py:82 dt:33.36 (30.0hz) dtRlead: 1.82 (548.5hz) dtWfoll: 0.38 (2605.6hz) dtRfoll: 1.62 (617.8hz) dtRlaptop:30.67 (32.6hz) dtRphone:30.77 (32.5hz)
# INFO 2025-04-13 17:16:15 rol_utils.py:82 dt:33.42 (29.9hz) dtRlead: 1.79 (559.2hz) dtWfoll: 0.40 (2485.1hz) dtRfoll: 1.63 (613.6hz) dtRlaptop:28.44 (35.2hz) dtRphone:28.23 (35.4hz)
# INFO 2025-04-13 17:16:15 rol_utils.py:82 dt:33.40 (29.9hz) dtRlead: 1.91 (524.9hz) dtWfoll: 0.32 (3111.4hz) dtRfoll: 1.72 (580.5hz) dtRlaptop:28.44 (35.2hz) dtRphone:28.23 (35.4hz)
# INFO 2025-04-13 17:16:15 rol_utils.py:82 dt:33.41 (29.9hz) dtRlead: 1.71 (583.8hz) dtWfoll: 0.23 (4372.4hz) dtRfoll: 1.66 (603.8hz) dtRlaptop:28.68 (34.9hz) dtRphone:28.30 (35.3hz)
# INFO 2025-04-13 17:16:15 rol_utils.py:82 dt:33.42 (29.9hz) dtRlead: 1.79 (560.1hz) dtWfoll: 0.24 (4184.0hz) dtRfoll: 1.68 (595.8hz) dtRlaptop:33.44 (29.9hz) dtRphone:33.77 (29.6hz)
# INFO 2025-04-13 17:16:15 rol_utils.py:82 dt:33.41 (29.9hz) dtRlead: 1.83 (547.8hz) dtWfoll: 0.32 (3079.4hz) dtRfoll: 1.77 (564.2hz) dtRlaptop:36.85 (27.1hz) dtRphone:36.57 (27.3hz)
# INFO 2025-04-13 17:16:15 rol_utils.py:82 dt:33.41 (29.9hz) dtRlead: 1.76 (568.6hz) dtWfoll: 0.24 (4238.9hz) dtRfoll: 1.71 (584.3hz) dtRlaptop:29.66 (33.7hz) dtRphone:29.28 (34.2hz)
# INFO 2025-04-13 17:16:15 rol_utils.py:82 dt:33.41 (29.9hz) dtRlead: 1.77 (564.3hz) dtWfoll: 0.27 (3652.4hz) dtRfoll: 1.77 (565.0hz) dtRlaptop:33.48 (29.9hz) dtRphone:33.57 (29.8hz)
# INFO 2025-04-13 17:16:15 rol_utils.py:82 dt:33.41 (29.9hz) dtRlead: 1.88 (532.9hz) dtWfoll: 0.39 (2555.9hz) dtRfoll: 1.96 (511.1hz) dtRlaptop:37.91 (26.4hz) dtRphone:37.88 (26.4hz)
# INFO 2025-04-13 17:16:15 rol_utils.py:82 dt:33.40 (29.9hz) dtRlead: 1.69 (593.3hz) dtWfoll: 0.22 (4515.6hz) dtRfoll: 1.65 (604.8hz) dtRlaptop:29.49 (33.9hz) dtRphone:29.34 (34.1hz)
# INFO 2025-04-13 17:16:15 rol_utils.py:82 dt:33.49 (29.9hz) dtRlead: 1.67 (597.3hz) dtWfoll: 0.31 (3267.3hz) dtRfoll: 1.63 (615.1hz) dtRlaptop:33.36 (30.0hz) dtRphone:34.11 (29.3hz)
# INFO 2025-04-13 17:16:15 rol_utils.py:82 dt:33.49 (29.9hz) dtRlead: 1.76 (566.8hz) dtWfoll: 0.27 (3699.3hz) dtRfoll: 1.66 (600.8hz) dtRlaptop:35.58 (28.1hz) dtRphone:35.50 (28.2hz)
# INFO 2025-04-13 17:16:15 rol_utils.py:82 dt:33.42 (29.9hz) dtRlead: 1.99 (502.7hz) dtWfoll: 0.55 (1818.1hz) dtRfoll: 2.06 (485.4hz) dtRlaptop:35.37 (28.3hz) dtRphone:34.78 (28.8hz)
# INFO 2025-04-13 17:16:15 rol_utils.py:82 dt:33.42 (29.9hz) dtRlead: 1.95 (513.4hz) dtWfoll: 0.55 (1834.7hz) dtRfoll: 1.91 (522.9hz) dtRlaptop:33.59 (29.8hz) dtRphone:33.23 (30.1hz)
# INFO 2025-04-13 17:16:15 rol_utils.py:82 dt:33.40 (29.9hz) dtRlead: 1.92 (519.7hz) dtWfoll: 0.31 (3188.2hz) dtRfoll: 1.69 (591.2hz) dtRlaptop:30.35 (32.9hz) dtRphone:30.10 (33.2hz)
# INFO 2025-04-13 17:16:15 rol_utils.py:82 dt:33.41 (29.9hz) dtRlead: 1.77 (565.4hz) dtWfoll: 0.31 (3245.1hz) dtRfoll: 1.68 (595.5hz) dtRlaptop:31.20 (32.0hz) dtRphone:31.66 (31.6hz)
# INFO 2025-04-13 17:16:15 rol_utils.py:82 dt:33.40 (29.9hz) dtRlead: 1.85 (541.1hz) dtWfoll: 0.32 (3158.5hz) dtRfoll: 1.63 (613.1hz) dtRlaptop:37.69 (26.5hz) dtRphone:37.75 (26.5hz)
# INFO 2025-04-13 17:16:15 rol_utils.py:82 dt:33.40 (29.9hz) dtRlead: 1.72 (581.6hz) dtWfoll: 0.21 (4737.0hz) dtRfoll: 1.70 (589.5hz) dtRlaptop:30.01 (33.3hz) dtRphone:30.15 (33.2hz)
# INFO 2025-04-13 17:16:16 rol_utils.py:82 dt:33.41 (29.9hz) dtRlead: 1.77 (564.7hz) dtWfoll: 0.23 (4256.9hz) dtRfoll: 1.76 (567.7hz) dtRlaptop:28.57 (35.0hz) dtRphone:28.58 (35.0hz)
# INFO 2025-04-13 17:16:16 rol_utils.py:82 dt:33.40 (29.9hz) dtRlead: 1.86 (538.4hz) dtWfoll: 0.24 (4177.4hz) dtRfoll: 1.70 (587.0hz) dtRlaptop:41.18 (24.3hz) dtRphone:41.06 (24.4hz)
# INFO 2025-04-13 17:16:16 rol_utils.py:82 dt:33.41 (29.9hz) dtRlead: 1.76 (569.7hz) dtWfoll: 0.27 (3645.0hz) dtRfoll: 1.69 (590.7hz) dtRlaptop:31.51 (31.7hz) dtRphone:31.55 (31.7hz)
# INFO 2025-04-13 17:16:16 rol_utils.py:82 dt:33.41 (29.9hz) dtRlead: 1.80 (556.8hz) dtWfoll: 0.25 (3930.5hz) dtRfoll: 1.68 (593.6hz) dtRlaptop:36.86 (27.1hz) dtRphone:36.95 (27.1hz)
# INFO 2025-04-13 17:16:16 rol_utils.py:82 dt:33.41 (29.9hz) dtRlead: 1.78 (562.9hz) dtWfoll: 0.29 (3464.8hz) dtRfoll: 1.75 (572.0hz) dtRlaptop:34.84 (28.7hz) dtRphone:35.21 (28.4hz)
# INFO 2025-04-13 17:16:16 rol_utils.py:82 dt:33.41 (29.9hz) dtRlead: 1.84 (543.8hz) dtWfoll: 0.44 (2257.9hz) dtRfoll: 1.71 (584.5hz) dtRlaptop:29.43 (34.0hz) dtRphone:29.17 (34.3hz)
# INFO 2025-04-13 17:16:16 rol_utils.py:82 dt:33.41 (29.9hz) dtRlead: 1.93 (516.8hz) dtWfoll: 0.39 (2551.7hz) dtRfoll: 1.69 (592.5hz) dtRlaptop:28.01 (35.7hz) dtRphone:28.00 (35.7hz)
# INFO 2025-04-13 17:16:16 rol_utils.py:82 dt:33.42 (29.9hz) dtRlead: 1.69 (593.1hz) dtWfoll: 0.28 (3510.1hz) dtRfoll: 1.70 (589.6hz) dtRlaptop:40.01 (25.0hz) dtRphone:39.97 (25.0hz)
# INFO 2025-04-13 17:16:16 rol_utils.py:82 dt:33.43 (29.9hz) dtRlead: 1.97 (508.6hz) dtWfoll: 0.35 (2860.2hz) dtRfoll: 1.77 (564.1hz) dtRlaptop:28.32 (35.3hz) dtRphone:28.29 (35.3hz)
# INFO 2025-04-13 17:16:16 rol_utils.py:82 dt:33.48 (29.9hz) dtRlead: 2.02 (495.3hz) dtWfoll: 0.42 (2356.5hz) dtRfoll: 2.73 (366.4hz) dtRlaptop:45.15 (22.1hz) dtRphone:44.24 (22.6hz)
# INFO 2025-04-13 17:16:16 rol_utils.py:82 dt:33.44 (29.9hz) dtRlead: 1.69 (590.6hz) dtWfoll: 0.35 (2818.0hz) dtRfoll: 1.73 (578.1hz) dtRlaptop:25.74 (38.8hz) dtRphone:26.65 (37.5hz)
# INFO 2025-04-13 17:16:16 rol_utils.py:82 dt:33.46 (29.9hz) dtRlead: 1.66 (601.9hz) dtWfoll: 0.31 (3248.0hz) dtRfoll: 1.66 (601.7hz) dtRlaptop:24.17 (41.4hz) dtRphone:24.23 (41.3hz)
# INFO 2025-04-13 17:16:16 rol_utils.py:82 dt:35.88 (27.9hz) dtRlead: 1.69 (593.0hz) dtWfoll: 0.25 (3987.3hz) dtRfoll: 1.69 (592.5hz) dtRlaptop:42.36 (23.6hz) dtRphone:42.35 (23.6hz)
# INFO 2025-04-13 17:16:16 rol_utils.py:82 dt:33.39 (30.0hz) dtRlead: 1.77 (565.4hz) dtWfoll: 0.24 (4236.0hz) dtRfoll: 1.76 (568.5hz) dtRlaptop:37.40 (26.7hz) dtRphone:37.40 (26.7hz)
# INFO 2025-04-13 17:16:16 rol_utils.py:82 dt:33.40 (29.9hz) dtRlead: 1.65 (605.3hz) dtWfoll: 0.19 (5171.8hz) dtRfoll: 1.63 (613.8hz) dtRlaptop:25.46 (39.3hz) dtRphone:25.45 (39.3hz)
# INFO 2025-04-13 17:16:16 rol_utils.py:82 dt:33.41 (29.9hz) dtRlead: 1.64 (611.1hz) dtWfoll: 0.27 (3764.0hz) dtRfoll: 1.56 (640.5hz) dtRlaptop:31.31 (31.9hz) dtRphone:31.31 (31.9hz)
# INFO 2025-04-13 17:16:16 rol_utils.py:82 dt:33.41 (29.9hz) dtRlead: 1.87 (535.9hz) dtWfoll: 0.34 (2945.6hz) dtRfoll: 1.78 (560.8hz) dtRlaptop:28.27 (35.4hz) dtRphone:28.28 (35.4hz)
# INFO 2025-04-13 17:16:16 rol_utils.py:82 dt:33.41 (29.9hz) dtRlead: 1.85 (541.0hz) dtWfoll: 0.37 (2712.7hz) dtRfoll: 1.75 (571.9hz) dtRlaptop:37.68 (26.5hz) dtRphone:37.71 (26.5hz)
# INFO 2025-04-13 17:16:16 rol_utils.py:82 dt:33.42 (29.9hz) dtRlead: 1.71 (585.4hz) dtWfoll: 0.28 (3589.7hz) dtRfoll: 1.72 (582.3hz) dtRlaptop:44.22 (22.6hz) dtRphone:44.44 (22.5hz)
# INFO 2025-04-13 17:16:16 rol_utils.py:82 dt:33.42 (29.9hz) dtRlead: 1.88 (530.9hz) dtWfoll: 0.38 (2638.4hz) dtRfoll: 1.83 (545.0hz) dtRlaptop:25.76 (38.8hz) dtRphone:25.66 (39.0hz)
# INFO 2025-04-13 17:16:16 rol_utils.py:82 dt:33.41 (29.9hz) dtRlead: 1.98 (504.1hz) dtWfoll: 0.41 (2458.0hz) dtRfoll: 2.01 (497.7hz) dtRlaptop:29.40 (34.0hz) dtRphone:29.25 (34.2hz)
# INFO 2025-04-13 17:16:16 rol_utils.py:82 dt:33.42 (29.9hz) dtRlead: 1.83 (547.9hz) dtWfoll: 0.25 (3925.2hz) dtRfoll: 1.80 (555.0hz) dtRlaptop:42.61 (23.5hz) dtRphone:42.56 (23.5hz)
# INFO 2025-04-13 17:16:16 rol_utils.py:82 dt:33.42 (29.9hz) dtRlead: 2.07 (483.5hz) dtWfoll: 0.39 (2545.7hz) dtRfoll: 1.80 (556.5hz) dtRlaptop:27.49 (36.4hz) dtRphone:27.60 (36.2hz)
# INFO 2025-04-13 17:16:16 rol_utils.py:82 dt:33.42 (29.9hz) dtRlead: 2.06 (484.9hz) dtWfoll: 0.44 (2256.3hz) dtRfoll: 1.91 (523.4hz) dtRlaptop:32.19 (31.1hz) dtRphone:32.19 (31.1hz)
# INFO 2025-04-13 17:16:16 rol_utils.py:82 dt:33.43 (29.9hz) dtRlead: 2.03 (492.2hz) dtWfoll: 0.44 (2284.7hz) dtRfoll: 1.91 (522.8hz) dtRlaptop:37.76 (26.5hz) dtRphone:37.94 (26.4hz)
# INFO 2025-04-13 17:16:16 rol_utils.py:82 dt:33.47 (29.9hz) dtRlead: 2.09 (477.6hz) dtWfoll: 0.38 (2615.1hz) dtRfoll: 1.89 (529.7hz) dtRlaptop:31.44 (31.8hz) dtRphone:31.43 (31.8hz)
# INFO 2025-04-13 17:16:16 rol_utils.py:82 dt:33.49 (29.9hz) dtRlead: 2.18 (458.0hz) dtWfoll: 0.36 (2763.6hz) dtRfoll: 2.04 (490.2hz) dtRlaptop:36.84 (27.1hz) dtRphone:36.81 (27.2hz)
# INFO 2025-04-13 17:16:16 rol_utils.py:82 dt:33.44 (29.9hz) dtRlead: 2.20 (453.9hz) dtWfoll: 0.51 (1951.5hz) dtRfoll: 2.04 (489.2hz) dtRlaptop:30.11 (33.2hz) dtRphone:30.01 (33.3hz)
# INFO 2025-04-13 17:16:16 rol_utils.py:82 dt:33.50 (29.9hz) dtRlead: 2.03 (492.6hz) dtWfoll: 0.48 (2069.6hz) dtRfoll: 1.91 (523.1hz) dtRlaptop:35.13 (28.5hz) dtRphone:35.25 (28.4hz)
# INFO 2025-04-13 17:16:17 rol_utils.py:82 dt:33.48 (29.9hz) dtRlead: 2.07 (482.2hz) dtWfoll: 0.52 (1920.1hz) dtRfoll: 1.92 (521.4hz) dtRlaptop:30.87 (32.4hz) dtRphone:30.78 (32.5hz)
# INFO 2025-04-13 17:16:17 rol_utils.py:82 dt:33.56 (29.8hz) dtRlead: 1.91 (524.4hz) dtWfoll: 0.35 (2892.9hz) dtRfoll: 1.82 (548.7hz) dtRlaptop:34.07 (29.4hz) dtRphone:34.16 (29.3hz)
# INFO 2025-04-13 17:16:17 rol_utils.py:82 dt:33.44 (29.9hz) dtRlead: 2.64 (378.9hz) dtWfoll: 0.68 (1478.0hz) dtRfoll: 2.09 (479.2hz) dtRlaptop:35.08 (28.5hz) dtRphone:35.19 (28.4hz)
# INFO 2025-04-13 17:16:17 rol_utils.py:82 dt:33.42 (29.9hz) dtRlead: 2.12 (472.7hz) dtWfoll: 0.48 (2092.3hz) dtRfoll: 2.06 (484.4hz) dtRlaptop:37.69 (26.5hz) dtRphone:37.62 (26.6hz)
# INFO 2025-04-13 17:16:17 rol_utils.py:82 dt:33.51 (29.8hz) dtRlead: 2.15 (464.2hz) dtWfoll: 0.42 (2392.9hz) dtRfoll: 1.89 (528.0hz) dtRlaptop:27.59 (36.2hz) dtRphone:27.47 (36.4hz)
# INFO 2025-04-13 17:16:17 rol_utils.py:82 dt:33.44 (29.9hz) dtRlead: 2.22 (450.2hz) dtWfoll: 0.38 (2616.3hz) dtRfoll: 1.97 (508.5hz) dtRlaptop:37.24 (26.9hz) dtRphone:37.29 (26.8hz)
# INFO 2025-04-13 17:16:17 rol_utils.py:82 dt:33.48 (29.9hz) dtRlead: 2.21 (452.3hz) dtWfoll: 0.54 (1849.7hz) dtRfoll: 1.95 (512.7hz) dtRlaptop:33.29 (30.0hz) dtRphone:33.88 (29.5hz)
# INFO 2025-04-13 17:16:17 rol_utils.py:82 dt:33.48 (29.9hz) dtRlead: 2.15 (465.7hz) dtWfoll: 0.50 (2005.3hz) dtRfoll: 2.64 (378.4hz) dtRlaptop:36.35 (27.5hz) dtRphone:36.78 (27.2hz)
# INFO 2025-04-13 17:16:17 rol_utils.py:82 dt:33.43 (29.9hz) dtRlead: 2.43 (411.8hz) dtWfoll: 0.63 (1576.0hz) dtRfoll: 2.07 (484.0hz) dtRlaptop:27.43 (36.5hz) dtRphone:26.87 (37.2hz)
# INFO 2025-04-13 17:16:17 rol_utils.py:82 dt:33.41 (29.9hz) dtRlead: 2.02 (495.7hz) dtWfoll: 0.37 (2723.1hz) dtRfoll: 1.89 (530.4hz) dtRlaptop:39.36 (25.4hz) dtRphone:39.29 (25.5hz)
# INFO 2025-04-13 17:16:17 rol_utils.py:82 dt:33.50 (29.8hz) dtRlead: 1.86 (536.2hz) dtWfoll: 0.31 (3269.1hz) dtRfoll: 1.65 (606.5hz) dtRlaptop:23.56 (42.4hz) dtRphone:23.14 (43.2hz)
# INFO 2025-04-13 17:16:17 rol_utils.py:82 dt:33.44 (29.9hz) dtRlead: 2.02 (494.1hz) dtWfoll: 0.38 (2652.4hz) dtRfoll: 2.00 (499.1hz) dtRlaptop:35.84 (27.9hz) dtRphone:35.84 (27.9hz)
# INFO 2025-04-13 17:16:17 rol_utils.py:82 dt:33.41 (29.9hz) dtRlead: 2.33 (429.1hz) dtWfoll: 0.53 (1894.4hz) dtRfoll: 1.89 (529.3hz) dtRlaptop:40.76 (24.5hz) dtRphone:40.91 (24.4hz)
# INFO 2025-04-13 17:16:17 rol_utils.py:82 dt:33.42 (29.9hz) dtRlead: 1.68 (593.6hz) dtWfoll: 0.22 (4470.8hz) dtRfoll: 1.70 (587.7hz) dtRlaptop:26.04 (38.4hz) dtRphone:26.00 (38.5hz)
# INFO 2025-04-13 17:16:17 rol_utils.py:82 dt:33.43 (29.9hz) dtRlead: 2.05 (487.9hz) dtWfoll: 1.43 (700.6hz) dtRfoll: 2.10 (475.2hz) dtRlaptop:32.90 (30.4hz) dtRphone:32.74 (30.5hz)
# INFO 2025-04-13 17:16:17 rol_utils.py:82 dt:33.50 (29.8hz) dtRlead: 2.04 (490.1hz) dtWfoll: 0.53 (1885.4hz) dtRfoll: 1.87 (535.3hz) dtRlaptop:39.67 (25.2hz) dtRphone:39.98 (25.0hz)
# INFO 2025-04-13 17:16:17 rol_utils.py:82 dt:33.47 (29.9hz) dtRlead: 2.09 (478.2hz) dtWfoll: 0.81 (1227.6hz) dtRfoll: 2.04 (491.0hz) dtRlaptop:31.86 (31.4hz) dtRphone:32.31 (31.0hz)
# INFO 2025-04-13 17:16:17 rol_utils.py:82 dt:33.44 (29.9hz) dtRlead: 2.11 (474.9hz) dtWfoll: 0.48 (2095.4hz) dtRfoll: 1.86 (536.7hz) dtRlaptop:29.31 (34.1hz) dtRphone:28.91 (34.6hz)
# INFO 2025-04-13 17:16:17 rol_utils.py:82 dt:33.57 (29.8hz) dtRlead: 1.98 (506.2hz) dtWfoll: 0.39 (2543.1hz) dtRfoll: 2.07 (483.5hz) dtRlaptop:38.71 (25.8hz) dtRphone:38.05 (26.3hz)
# INFO 2025-04-13 17:16:17 rol_utils.py:82 dt:33.45 (29.9hz) dtRlead: 2.42 (413.8hz) dtWfoll: 0.63 (1584.2hz) dtRfoll: 2.16 (463.1hz) dtRlaptop:32.61 (30.7hz) dtRphone:33.12 (30.2hz)
# INFO 2025-04-13 17:16:17 rol_utils.py:82 dt:33.44 (29.9hz) dtRlead: 2.13 (469.5hz) dtWfoll: 0.38 (2664.6hz) dtRfoll: 2.00 (500.6hz) dtRlaptop:39.76 (25.1hz) dtRphone:39.85 (25.1hz)
# INFO 2025-04-13 17:16:17 rol_utils.py:82 dt:33.48 (29.9hz) dtRlead: 2.52 (397.5hz) dtWfoll: 0.58 (1713.0hz) dtRfoll: 2.43 (411.3hz) dtRlaptop:26.55 (37.7hz) dtRphone:26.38 (37.9hz)
# INFO 2025-04-13 17:16:17 rol_utils.py:82 dt:33.45 (29.9hz) dtRlead: 2.67 (375.2hz) dtWfoll: 0.60 (1673.1hz) dtRfoll: 2.12 (472.7hz) dtRlaptop:31.89 (31.4hz) dtRphone:31.90 (31.3hz)
# INFO 2025-04-13 17:16:17 rol_utils.py:82 dt:33.53 (29.8hz) dtRlead: 2.50 (399.6hz) dtWfoll: 0.59 (1703.1hz) dtRfoll: 2.70 (370.3hz) dtRlaptop:33.76 (29.6hz) dtRphone:33.75 (29.6hz)
# INFO 2025-04-13 17:16:17 rol_utils.py:82 dt:33.43 (29.9hz) dtRlead: 2.60 (384.1hz) dtWfoll: 0.66 (1517.0hz) dtRfoll: 2.43 (412.2hz) dtRlaptop:33.23 (30.1hz) dtRphone:33.21 (30.1hz)
# INFO 2025-04-13 17:16:17 rol_utils.py:82 dt:33.51 (29.8hz) dtRlead: 2.02 (495.7hz) dtWfoll: 0.55 (1824.4hz) dtRfoll: 1.80 (556.4hz) dtRlaptop:35.88 (27.9hz) dtRphone:35.90 (27.9hz)
# INFO 2025-04-13 17:16:17 rol_utils.py:82 dt:33.51 (29.8hz) dtRlead: 1.98 (504.7hz) dtWfoll: 0.51 (1976.6hz) dtRfoll: 1.86 (536.8hz) dtRlaptop:28.16 (35.5hz) dtRphone:28.16 (35.5hz)
# INFO 2025-04-13 17:16:17 rol_utils.py:82 dt:33.50 (29.9hz) dtRlead: 2.08 (480.4hz) dtWfoll: 0.63 (1585.2hz) dtRfoll: 1.74 (574.5hz) dtRlaptop:37.35 (26.8hz) dtRphone:36.93 (27.1hz)
# INFO 2025-04-13 17:16:17 rol_utils.py:82 dt:33.43 (29.9hz) dtRlead: 2.03 (493.7hz) dtWfoll: 0.52 (1940.6hz) dtRfoll: 1.58 (634.5hz) dtRlaptop:32.03 (31.2hz) dtRphone:31.80 (31.5hz)
# INFO 2025-04-13 17:16:17 rol_utils.py:82 dt:33.45 (29.9hz) dtRlead: 2.14 (468.1hz) dtWfoll: 0.40 (2505.9hz) dtRfoll: 1.76 (567.5hz) dtRlaptop:34.57 (28.9hz) dtRphone:34.71 (28.8hz)
# INFO 2025-04-13 17:16:18 rol_utils.py:82 dt:33.49 (29.9hz) dtRlead: 2.40 (417.3hz) dtWfoll: 0.71 (1409.8hz) dtRfoll: 2.31 (432.6hz) dtRlaptop:38.38 (26.1hz) dtRphone:38.35 (26.1hz)
# INFO 2025-04-13 17:16:18 rol_utils.py:82 dt:33.43 (29.9hz) dtRlead: 2.53 (395.2hz) dtWfoll: 0.71 (1403.1hz) dtRfoll: 1.95 (511.7hz) dtRlaptop:30.96 (32.3hz) dtRphone:31.48 (31.8hz)
# INFO 2025-04-13 17:16:18 rol_utils.py:82 dt:33.50 (29.9hz) dtRlead: 2.50 (399.8hz) dtWfoll: 0.56 (1787.3hz) dtRfoll: 1.99 (502.6hz) dtRlaptop:30.68 (32.6hz) dtRphone:30.82 (32.4hz)
# INFO 2025-04-13 17:16:18 rol_utils.py:82 dt:33.45 (29.9hz) dtRlead: 2.58 (387.1hz) dtWfoll: 0.75 (1331.3hz) dtRfoll: 2.07 (482.0hz) dtRlaptop:31.82 (31.4hz) dtRphone:31.83 (31.4hz)
# INFO 2025-04-13 17:16:18 rol_utils.py:82 dt:33.41 (29.9hz) dtRlead: 2.43 (411.7hz) dtWfoll: 0.68 (1470.0hz) dtRfoll: 1.85 (539.3hz) dtRlaptop:36.47 (27.4hz) dtRphone:35.74 (28.0hz)
# INFO 2025-04-13 17:16:18 rol_utils.py:82 dt:33.50 (29.9hz) dtRlead: 2.05 (488.2hz) dtWfoll: 0.33 (3049.5hz) dtRfoll: 1.98 (504.9hz) dtRlaptop:32.11 (31.1hz) dtRphone:32.81 (30.5hz)
# INFO 2025-04-13 17:16:18 rol_utils.py:82 dt:33.46 (29.9hz) dtRlead: 2.17 (461.3hz) dtWfoll: 0.56 (1796.0hz) dtRfoll: 2.08 (481.5hz) dtRlaptop:31.79 (31.5hz) dtRphone:31.70 (31.5hz)
# INFO 2025-04-13 17:16:18 rol_utils.py:82 dt:33.42 (29.9hz) dtRlead: 1.93 (518.3hz) dtWfoll: 0.41 (2428.1hz) dtRfoll: 2.02 (494.7hz) dtRlaptop:49.16 (20.3hz) dtRphone:49.26 (20.3hz)
# INFO 2025-04-13 17:16:18 rol_utils.py:82 dt:33.42 (29.9hz) dtRlead: 1.59 (628.6hz) dtWfoll: 0.15 (6570.9hz) dtRfoll: 1.61 (620.2hz) dtRlaptop:14.65 (68.2hz) dtRphone:14.66 (68.2hz)
# INFO 2025-04-13 17:16:18 rol_utils.py:82 dt:33.46 (29.9hz) dtRlead: 2.15 (465.6hz) dtWfoll: 0.36 (2783.1hz) dtRfoll: 2.01 (497.5hz) dtRlaptop:14.65 (68.2hz) dtRphone:14.66 (68.2hz)
# INFO 2025-04-13 17:16:18 rol_utils.py:82 dt:33.42 (29.9hz) dtRlead: 1.91 (524.0hz) dtWfoll: 0.27 (3754.3hz) dtRfoll: 1.69 (592.6hz) dtRlaptop:48.08 (20.8hz) dtRphone:48.23 (20.7hz)
# INFO 2025-04-13 17:16:18 rol_utils.py:82 dt:33.44 (29.9hz) dtRlead: 2.14 (467.5hz) dtWfoll: 0.51 (1964.3hz) dtRfoll: 2.04 (490.5hz) dtRlaptop:26.31 (38.0hz) dtRphone:26.25 (38.1hz)
# INFO 2025-04-13 17:16:18 rol_utils.py:82 dt:33.55 (29.8hz) dtRlead: 2.40 (417.4hz) dtWfoll: 2.31 (432.9hz) dtRfoll: 1.85 (540.8hz) dtRlaptop:38.91 (25.7hz) dtRphone:38.90 (25.7hz)
# INFO 2025-04-13 17:16:18 rol_utils.py:82 dt:33.41 (29.9hz) dtRlead: 2.07 (482.1hz) dtWfoll: 0.35 (2874.0hz) dtRfoll: 2.02 (495.9hz) dtRlaptop:32.68 (30.6hz) dtRphone:28.37 (35.2hz)
# INFO 2025-04-13 17:16:18 rol_utils.py:82 dt:33.47 (29.9hz) dtRlead: 1.78 (561.6hz) dtWfoll: 0.30 (3309.4hz) dtRfoll: 1.73 (577.2hz) dtRlaptop:30.14 (33.2hz) dtRphone:30.37 (32.9hz)
# INFO 2025-04-13 17:16:18 rol_utils.py:82 dt:33.41 (29.9hz) dtRlead: 2.07 (483.1hz) dtWfoll: 0.20 (4994.2hz) dtRfoll: 1.76 (566.7hz) dtRlaptop:34.58 (28.9hz) dtRphone:34.44 (29.0hz)
# INFO 2025-04-13 17:16:18 rol_utils.py:82 dt:33.41 (29.9hz) dtRlead: 1.72 (582.9hz) dtWfoll: 0.23 (4263.9hz) dtRfoll: 1.70 (589.5hz) dtRlaptop:34.58 (28.9hz) dtRphone:34.44 (29.0hz)
# INFO 2025-04-13 17:16:18 rol_utils.py:82 dt:33.43 (29.9hz) dtRlead: 1.86 (537.1hz) dtWfoll: 0.35 (2846.2hz) dtRfoll: 1.68 (594.2hz) dtRlaptop:35.60 (28.1hz) dtRphone:35.64 (28.1hz)
# INFO 2025-04-13 17:16:18 rol_utils.py:82 dt:33.40 (29.9hz) dtRlead: 1.96 (511.1hz) dtWfoll: 0.44 (2251.6hz) dtRfoll: 1.96 (509.6hz) dtRlaptop:33.78 (29.6hz) dtRphone:33.92 (29.5hz)
# INFO 2025-04-13 17:16:18 rol_utils.py:82 dt:33.41 (29.9hz) dtRlead: 2.14 (466.4hz) dtWfoll: 0.41 (2456.3hz) dtRfoll: 1.91 (523.2hz) dtRlaptop:37.68 (26.5hz) dtRphone:37.36 (26.8hz)
# INFO 2025-04-13 17:16:18 rol_utils.py:82 dt:33.49 (29.9hz) dtRlead: 2.03 (492.5hz) dtWfoll: 0.26 (3878.8hz) dtRfoll: 1.83 (545.0hz) dtRlaptop:29.55 (33.8hz) dtRphone:29.74 (33.6hz)
# INFO 2025-04-13 17:16:18 rol_utils.py:82 dt:33.41 (29.9hz) dtRlead: 2.48 (402.7hz) dtWfoll: 0.65 (1543.9hz) dtRfoll: 2.07 (482.0hz) dtRlaptop:29.55 (33.8hz) dtRphone:29.74 (33.6hz)
# INFO 2025-04-13 17:16:18 rol_utils.py:82 dt:33.50 (29.9hz) dtRlead: 1.89 (529.4hz) dtWfoll: 0.34 (2920.6hz) dtRfoll: 1.78 (560.3hz) dtRlaptop:22.94 (43.6hz) dtRphone:22.90 (43.7hz)
# INFO 2025-04-13 17:16:18 rol_utils.py:82 dt:33.47 (29.9hz) dtRlead: 1.75 (569.8hz) dtWfoll: 0.25 (4061.1hz) dtRfoll: 1.70 (588.3hz) dtRlaptop:35.88 (27.9hz) dtRphone:35.91 (27.9hz)
# INFO 2025-04-13 17:16:18 rol_utils.py:82 dt:33.49 (29.9hz) dtRlead: 1.82 (549.7hz) dtWfoll: 0.44 (2248.3hz) dtRfoll: 1.85 (540.7hz) dtRlaptop:35.88 (27.9hz) dtRphone:35.91 (27.9hz)
# INFO 2025-04-13 17:16:18 rol_utils.py:82 dt:33.40 (29.9hz) dtRlead: 1.94 (514.6hz) dtWfoll: 0.32 (3082.8hz) dtRfoll: 1.73 (577.4hz) dtRlaptop:32.68 (30.6hz) dtRphone:32.49 (30.8hz)
# INFO 2025-04-13 17:16:18 rol_utils.py:82 dt:33.47 (29.9hz) dtRlead: 1.61 (622.0hz) dtWfoll: 0.27 (3712.8hz) dtRfoll: 1.61 (622.2hz) dtRlaptop:27.39 (36.5hz) dtRphone:27.86 (35.9hz)
# INFO 2025-04-13 17:16:18 rol_utils.py:82 dt:33.46 (29.9hz) dtRlead: 1.94 (515.3hz) dtWfoll: 0.37 (2680.2hz) dtRfoll: 1.78 (562.2hz) dtRlaptop:36.98 (27.0hz) dtRphone:37.27 (26.8hz)
# INFO 2025-04-13 17:16:18 rol_utils.py:82 dt:33.54 (29.8hz) dtRlead: 1.98 (505.4hz) dtWfoll: 0.45 (2200.7hz) dtRfoll: 1.73 (578.8hz) dtRlaptop:34.53 (29.0hz) dtRphone:33.68 (29.7hz)
# INFO 2025-04-13 17:16:19 rol_utils.py:82 dt:33.49 (29.9hz) dtRlead: 1.80 (554.2hz) dtWfoll: 0.38 (2638.3hz) dtRfoll: 1.72 (580.6hz) dtRlaptop:31.90 (31.3hz) dtRphone:32.58 (30.7hz)
# INFO 2025-04-13 17:16:19 rol_utils.py:82 dt:33.49 (29.9hz) dtRlead: 1.77 (564.5hz) dtWfoll: 0.38 (2661.0hz) dtRfoll: 1.83 (547.7hz) dtRlaptop:34.20 (29.2hz) dtRphone:33.88 (29.5hz)
# INFO 2025-04-13 17:16:19 rol_utils.py:82 dt:33.42 (29.9hz) dtRlead: 2.19 (455.6hz) dtWfoll: 0.47 (2110.5hz) dtRfoll: 2.01 (498.7hz) dtRlaptop:37.44 (26.7hz) dtRphone:37.63 (26.6hz)
# INFO 2025-04-13 17:16:19 rol_utils.py:82 dt:33.42 (29.9hz) dtRlead: 1.89 (529.0hz) dtWfoll: 0.35 (2863.5hz) dtRfoll: 1.83 (545.7hz) dtRlaptop:24.40 (41.0hz) dtRphone:24.27 (41.2hz)
# INFO 2025-04-13 17:16:19 rol_utils.py:82 dt:33.48 (29.9hz) dtRlead: 1.91 (523.4hz) dtWfoll: 0.89 (1126.3hz) dtRfoll: 1.73 (577.4hz) dtRlaptop:38.23 (26.2hz) dtRphone:38.92 (25.7hz)
# INFO 2025-04-13 17:16:19 rol_utils.py:82 dt:33.52 (29.8hz) dtRlead: 1.72 (581.8hz) dtWfoll: 0.34 (2918.6hz) dtRfoll: 1.68 (596.9hz) dtRlaptop:29.17 (34.3hz) dtRphone:28.79 (34.7hz)
# INFO 2025-04-13 17:16:19 rol_utils.py:82 dt:33.46 (29.9hz) dtRlead: 1.90 (525.1hz) dtWfoll: 0.34 (2946.7hz) dtRfoll: 1.80 (554.9hz) dtRlaptop:42.52 (23.5hz) dtRphone:28.79 (34.7hz)
# INFO 2025-04-13 17:16:19 rol_utils.py:82 dt:33.51 (29.8hz) dtRlead: 1.91 (524.2hz) dtWfoll: 0.36 (2761.5hz) dtRfoll: 1.91 (524.3hz) dtRlaptop:22.18 (45.1hz) dtRphone:21.57 (46.4hz)
# INFO 2025-04-13 17:16:19 rol_utils.py:82 dt:33.41 (29.9hz) dtRlead: 2.07 (483.2hz) dtWfoll: 0.47 (2138.1hz) dtRfoll: 2.00 (499.7hz) dtRlaptop:43.16 (23.2hz) dtRphone:43.48 (23.0hz)
# INFO 2025-04-13 17:16:19 rol_utils.py:82 dt:33.42 (29.9hz) dtRlead: 1.72 (580.3hz) dtWfoll: 0.26 (3776.2hz) dtRfoll: 1.66 (603.2hz) dtRlaptop:29.15 (34.3hz) dtRphone:28.51 (35.1hz)
# INFO 2025-04-13 17:16:19 rol_utils.py:82 dt:33.41 (29.9hz) dtRlead: 1.81 (552.5hz) dtWfoll: 0.32 (3121.7hz) dtRfoll: 1.74 (574.8hz) dtRlaptop:40.23 (24.9hz) dtRphone:28.51 (35.1hz)
# INFO 2025-04-13 17:16:19 rol_utils.py:82 dt:33.41 (29.9hz) dtRlead: 1.75 (570.2hz) dtWfoll: 0.27 (3697.0hz) dtRfoll: 1.89 (530.0hz) dtRlaptop:23.26 (43.0hz) dtRphone:22.93 (43.6hz)
# INFO 2025-04-13 17:16:19 rol_utils.py:82 dt:33.41 (29.9hz) dtRlead: 1.74 (573.7hz) dtWfoll: 0.29 (3472.4hz) dtRfoll: 1.71 (586.0hz) dtRlaptop:38.52 (26.0hz) dtRphone:38.68 (25.9hz)
# INFO 2025-04-13 17:16:19 rol_utils.py:82 dt:33.41 (29.9hz) dtRlead: 1.67 (599.8hz) dtWfoll: 0.28 (3589.1hz) dtRfoll: 1.66 (601.8hz) dtRlaptop:34.26 (29.2hz) dtRphone:34.18 (29.3hz)
# INFO 2025-04-13 17:16:19 rol_utils.py:82 dt:33.45 (29.9hz) dtRlead: 1.75 (571.2hz) dtWfoll: 0.26 (3820.8hz) dtRfoll: 1.68 (593.9hz) dtRlaptop:29.77 (33.6hz) dtRphone:29.81 (33.6hz)
# INFO 2025-04-13 17:16:19 rol_utils.py:82 dt:33.46 (29.9hz) dtRlead: 1.89 (529.6hz) dtWfoll: 0.31 (3215.9hz) dtRfoll: 2.95 (338.4hz) dtRlaptop:31.35 (31.9hz) dtRphone:31.01 (32.2hz)
# INFO 2025-04-13 17:16:19 rol_utils.py:82 dt:33.42 (29.9hz) dtRlead: 1.79 (557.2hz) dtWfoll: 0.44 (2273.2hz) dtRfoll: 1.94 (515.5hz) dtRlaptop:34.30 (29.2hz) dtRphone:34.69 (28.8hz)
# INFO 2025-04-13 17:16:19 rol_utils.py:82 dt:33.40 (29.9hz) dtRlead: 1.64 (610.2hz) dtWfoll: 0.27 (3636.8hz) dtRfoll: 1.66 (603.0hz) dtRlaptop:34.92 (28.6hz) dtRphone:34.77 (28.8hz)
# INFO 2025-04-13 17:16:19 rol_utils.py:82 dt:33.40 (29.9hz) dtRlead: 1.59 (627.7hz) dtWfoll: 1.51 (664.4hz) dtRfoll: 1.44 (693.1hz) dtRlaptop:30.87 (32.4hz) dtRphone:30.84 (32.4hz)
# INFO 2025-04-13 17:16:19 rol_utils.py:82 dt:33.41 (29.9hz) dtRlead: 1.88 (533.2hz) dtWfoll: 0.29 (3390.5hz) dtRfoll: 1.80 (556.3hz) dtRlaptop:31.48 (31.8hz) dtRphone:31.62 (31.6hz)
# INFO 2025-04-13 17:16:19 rol_utils.py:82 dt:33.41 (29.9hz) dtRlead: 1.85 (540.6hz) dtWfoll: 0.41 (2421.9hz) dtRfoll: 1.69 (590.6hz) dtRlaptop:36.61 (27.3hz) dtRphone:36.50 (27.4hz)
# INFO 2025-04-13 17:16:19 rol_utils.py:82 dt:33.50 (29.9hz) dtRlead: 1.74 (576.3hz) dtWfoll: 0.29 (3506.9hz) dtRfoll: 1.73 (577.5hz) dtRlaptop:38.60 (25.9hz) dtRphone:38.84 (25.7hz)
# INFO 2025-04-13 17:16:19 rol_utils.py:82 dt:33.45 (29.9hz) dtRlead: 1.89 (529.3hz) dtWfoll: 0.39 (2596.2hz) dtRfoll: 1.94 (514.7hz) dtRlaptop:27.38 (36.5hz) dtRphone:27.24 (36.7hz)
# INFO 2025-04-13 17:16:19 rol_utils.py:82 dt:33.47 (29.9hz) dtRlead: 1.81 (552.1hz) dtWfoll: 0.38 (2612.3hz) dtRfoll: 1.80 (554.3hz) dtRlaptop:35.05 (28.5hz) dtRphone:35.19 (28.4hz)
# INFO 2025-04-13 17:16:19 rol_utils.py:82 dt:33.48 (29.9hz) dtRlead: 1.82 (548.6hz) dtWfoll: 0.33 (3014.2hz) dtRfoll: 1.83 (546.7hz) dtRlaptop:32.45 (30.8hz) dtRphone:32.36 (30.9hz)
# INFO 2025-04-13 17:16:19 rol_utils.py:82 dt:33.46 (29.9hz) dtRlead: 2.04 (490.4hz) dtWfoll: 0.32 (3126.4hz) dtRfoll: 1.85 (540.5hz) dtRlaptop:32.04 (31.2hz) dtRphone:32.00 (31.3hz)
# INFO 2025-04-13 17:16:19 rol_utils.py:82 dt:33.46 (29.9hz) dtRlead: 1.68 (594.7hz) dtWfoll: 0.23 (4279.7hz) dtRfoll: 1.71 (585.0hz) dtRlaptop:35.49 (28.2hz) dtRphone:35.64 (28.1hz)
# INFO 2025-04-13 17:16:19 rol_utils.py:82 dt:33.42 (29.9hz) dtRlead: 1.70 (586.6hz) dtWfoll: 0.35 (2890.4hz) dtRfoll: 1.56 (641.9hz) dtRlaptop:37.61 (26.6hz) dtRphone:37.63 (26.6hz)
# INFO 2025-04-13 17:16:19 rol_utils.py:82 dt:33.43 (29.9hz) dtRlead: 1.94 (516.5hz) dtWfoll: 0.60 (1662.4hz) dtRfoll: 2.00 (500.3hz) dtRlaptop:29.09 (34.4hz) dtRphone:28.95 (34.5hz)
# INFO 2025-04-13 17:16:19 rol_utils.py:82 dt:33.42 (29.9hz) dtRlead: 1.75 (571.3hz) dtWfoll: 0.33 (2992.0hz) dtRfoll: 1.65 (606.3hz) dtRlaptop:35.36 (28.3hz) dtRphone:35.55 (28.1hz)
# INFO 2025-04-13 17:16:20 rol_utils.py:82 dt:33.41 (29.9hz) dtRlead: 1.81 (552.8hz) dtWfoll: 0.29 (3488.7hz) dtRfoll: 1.79 (557.9hz) dtRlaptop:31.86 (31.4hz) dtRphone:31.68 (31.6hz)
# INFO 2025-04-13 17:16:20 rol_utils.py:82 dt:33.41 (29.9hz) dtRlead: 1.71 (586.2hz) dtWfoll: 0.31 (3272.1hz) dtRfoll: 1.65 (607.3hz) dtRlaptop:25.32 (39.5hz) dtRphone:25.55 (39.1hz)
# INFO 2025-04-13 17:16:20 rol_utils.py:82 dt:33.47 (29.9hz) dtRlead: 1.66 (603.7hz) dtWfoll: 0.22 (4573.7hz) dtRfoll: 1.74 (575.8hz) dtRlaptop:39.48 (25.3hz) dtRphone:39.87 (25.1hz)
# INFO 2025-04-13 17:16:20 rol_utils.py:82 dt:33.49 (29.9hz) dtRlead: 2.12 (472.5hz) dtWfoll: 0.50 (1992.1hz) dtRfoll: 1.99 (502.0hz) dtRlaptop:32.32 (30.9hz) dtRphone:32.22 (31.0hz)
# INFO 2025-04-13 17:16:20 rol_utils.py:82 dt:33.50 (29.8hz) dtRlead: 2.06 (486.1hz) dtWfoll: 0.48 (2102.3hz) dtRfoll: 2.02 (494.6hz) dtRlaptop:37.82 (26.4hz) dtRphone:37.54 (26.6hz)
# INFO 2025-04-13 17:16:20 rol_utils.py:82 dt:33.40 (29.9hz) dtRlead: 2.06 (485.2hz) dtWfoll: 0.42 (2355.8hz) dtRfoll: 1.90 (527.0hz) dtRlaptop:28.38 (35.2hz) dtRphone:28.26 (35.4hz)
# INFO 2025-04-13 17:16:20 rol_utils.py:82 dt:33.40 (29.9hz) dtRlead: 1.82 (549.1hz) dtWfoll: 1.45 (691.8hz) dtRfoll: 1.68 (595.6hz) dtRlaptop:34.33 (29.1hz) dtRphone:34.28 (29.2hz)
# INFO 2025-04-13 17:16:20 rol_utils.py:82 dt:33.43 (29.9hz) dtRlead: 1.82 (550.4hz) dtWfoll: 0.33 (3058.1hz) dtRfoll: 1.83 (547.2hz) dtRlaptop:32.90 (30.4hz) dtRphone:32.78 (30.5hz)
# INFO 2025-04-13 17:16:20 rol_utils.py:82 dt:33.41 (29.9hz) dtRlead: 1.84 (543.5hz) dtWfoll: 0.32 (3102.7hz) dtRfoll: 1.74 (573.8hz) dtRlaptop:35.79 (27.9hz) dtRphone:35.92 (27.8hz)
# INFO 2025-04-13 17:16:20 rol_utils.py:82 dt:33.50 (29.9hz) dtRlead: 1.95 (512.5hz) dtWfoll: 0.43 (2318.2hz) dtRfoll: 1.95 (511.6hz) dtRlaptop:30.01 (33.3hz) dtRphone:30.05 (33.3hz)
# INFO 2025-04-13 17:16:20 rol_utils.py:82 dt:33.47 (29.9hz) dtRlead: 2.16 (464.0hz) dtWfoll: 0.58 (1709.6hz) dtRfoll: 1.92 (521.0hz) dtRlaptop:36.64 (27.3hz) dtRphone:36.62 (27.3hz)
# INFO 2025-04-13 17:16:20 rol_utils.py:82 dt:33.40 (29.9hz) dtRlead: 1.89 (529.5hz) dtWfoll: 0.36 (2746.1hz) dtRfoll: 1.77 (565.1hz) dtRlaptop:36.69 (27.3hz) dtRphone:36.76 (27.2hz)
# INFO 2025-04-13 17:16:20 rol_utils.py:82 dt:33.42 (29.9hz) dtRlead: 1.98 (504.7hz) dtWfoll: 0.43 (2323.5hz) dtRfoll: 1.73 (577.3hz) dtRlaptop:27.48 (36.4hz) dtRphone:27.33 (36.6hz)
# INFO 2025-04-13 17:16:20 rol_utils.py:82 dt:33.47 (29.9hz) dtRlead: 1.96 (511.1hz) dtWfoll: 0.41 (2444.5hz) dtRfoll: 1.76 (568.2hz) dtRlaptop:35.33 (28.3hz) dtRphone:35.44 (28.2hz)
# INFO 2025-04-13 17:16:20 rol_utils.py:82 dt:33.47 (29.9hz) dtRlead: 1.67 (599.9hz) dtWfoll: 0.33 (3000.9hz) dtRfoll: 1.65 (604.6hz) dtRlaptop:39.75 (25.2hz) dtRphone:39.88 (25.1hz)
# INFO 2025-04-13 17:16:20 rol_utils.py:82 dt:33.43 (29.9hz) dtRlead: 2.00 (500.2hz) dtWfoll: 0.39 (2570.9hz) dtRfoll: 1.80 (556.9hz) dtRlaptop:26.72 (37.4hz) dtRphone:26.77 (37.4hz)
# INFO 2025-04-13 17:16:20 rol_utils.py:82 dt:33.40 (29.9hz) dtRlead: 1.93 (519.5hz) dtWfoll: 0.46 (2157.5hz) dtRfoll: 1.83 (545.9hz) dtRlaptop:37.32 (26.8hz) dtRphone:37.13 (26.9hz)
# INFO 2025-04-13 17:16:20 rol_utils.py:82 dt:33.49 (29.9hz) dtRlead: 1.65 (606.3hz) dtWfoll: 0.20 (4902.3hz) dtRfoll: 1.72 (583.0hz) dtRlaptop:23.94 (41.8hz) dtRphone:24.23 (41.3hz)
# INFO 2025-04-13 17:16:20 rol_utils.py:82 dt:33.44 (29.9hz) dtRlead: 2.37 (422.1hz) dtWfoll: 0.46 (2188.5hz) dtRfoll: 1.87 (534.7hz) dtRlaptop:40.33 (24.8hz) dtRphone:40.02 (25.0hz)
# INFO 2025-04-13 17:16:20 rol_utils.py:82 dt:33.53 (29.8hz) dtRlead: 2.02 (494.6hz) dtWfoll: 0.37 (2715.5hz) dtRfoll: 1.91 (522.2hz) dtRlaptop:35.91 (27.8hz) dtRphone:36.10 (27.7hz)
# INFO 2025-04-13 17:16:20 rol_utils.py:82 dt:33.42 (29.9hz) dtRlead: 2.46 (406.3hz) dtWfoll: 0.59 (1693.8hz) dtRfoll: 2.47 (404.6hz) dtRlaptop:36.02 (27.8hz) dtRphone:36.17 (27.6hz)
# INFO 2025-04-13 17:16:20 rol_utils.py:82 dt:33.50 (29.8hz) dtRlead: 1.99 (503.7hz) dtWfoll: 0.43 (2346.0hz) dtRfoll: 1.82 (550.6hz) dtRlaptop:32.40 (30.9hz) dtRphone:32.64 (30.6hz)
# INFO 2025-04-13 17:16:20 rol_utils.py:82 dt:33.43 (29.9hz) dtRlead: 1.84 (543.9hz) dtWfoll: 0.35 (2829.7hz) dtRfoll: 1.86 (538.3hz) dtRlaptop:32.37 (30.9hz) dtRphone:32.41 (30.9hz)
# INFO 2025-04-13 17:16:20 rol_utils.py:82 dt:33.45 (29.9hz) dtRlead: 1.87 (536.1hz) dtWfoll: 0.32 (3145.4hz) dtRfoll: 1.79 (558.5hz) dtRlaptop:32.92 (30.4hz) dtRphone:33.04 (30.3hz)
# INFO 2025-04-13 17:16:20 rol_utils.py:82 dt:33.42 (29.9hz) dtRlead: 1.93 (517.1hz) dtWfoll: 0.35 (2825.1hz) dtRfoll: 1.85 (541.8hz) dtRlaptop:35.23 (28.4hz) dtRphone:35.43 (28.2hz)
# INFO 2025-04-13 17:16:20 rol_utils.py:82 dt:33.42 (29.9hz) dtRlead: 1.87 (533.7hz) dtWfoll: 0.29 (3455.7hz) dtRfoll: 1.69 (592.6hz) dtRlaptop:36.71 (27.2hz) dtRphone:36.51 (27.4hz)
# INFO 2025-04-13 17:16:20 rol_utils.py:82 dt:33.42 (29.9hz) dtRlead: 2.01 (497.8hz) dtWfoll: 0.35 (2860.9hz) dtRfoll: 1.84 (544.1hz) dtRlaptop:27.80 (36.0hz) dtRphone:27.73 (36.1hz)
# INFO 2025-04-13 17:16:20 rol_utils.py:82 dt:33.41 (29.9hz) dtRlead: 2.02 (495.2hz) dtWfoll: 0.41 (2419.2hz) dtRfoll: 1.87 (535.6hz) dtRlaptop:28.71 (34.8hz) dtRphone:28.48 (35.1hz)
# INFO 2025-04-13 17:16:20 rol_utils.py:82 dt:33.53 (29.8hz) dtRlead: 1.80 (554.3hz) dtWfoll: 0.25 (3965.2hz) dtRfoll: 1.74 (576.1hz) dtRlaptop:40.06 (25.0hz) dtRphone:39.87 (25.1hz)
# INFO 2025-04-13 17:16:20 rol_utils.py:82 dt:33.43 (29.9hz) dtRlead: 2.12 (471.4hz) dtWfoll: 0.42 (2399.8hz) dtRfoll: 1.91 (523.2hz) dtRlaptop:29.40 (34.0hz) dtRphone:29.26 (34.2hz)
# INFO 2025-04-13 17:16:21 rol_utils.py:82 dt:33.41 (29.9hz) dtRlead: 1.96 (511.2hz) dtWfoll: 0.35 (2886.2hz) dtRfoll: 1.84 (543.7hz) dtRlaptop:32.46 (30.8hz) dtRphone:32.46 (30.8hz)
# INFO 2025-04-13 17:16:21 rol_utils.py:82 dt:33.53 (29.8hz) dtRlead: 1.54 (651.1hz) dtWfoll: 0.19 (5288.9hz) dtRfoll: 1.62 (616.3hz) dtRlaptop:39.57 (25.3hz) dtRphone:39.50 (25.3hz)
# INFO 2025-04-13 17:16:21 rol_utils.py:82 dt:33.43 (29.9hz) dtRlead: 2.22 (450.7hz) dtWfoll: 0.51 (1974.4hz) dtRfoll: 2.26 (443.1hz) dtRlaptop:25.11 (39.8hz) dtRphone:25.14 (39.8hz)
# INFO 2025-04-13 17:16:21 rol_utils.py:82 dt:33.42 (29.9hz) dtRlead: 1.93 (518.0hz) dtWfoll: 0.39 (2588.9hz) dtRfoll: 1.95 (513.5hz) dtRlaptop:32.55 (30.7hz) dtRphone:32.53 (30.7hz)
# INFO 2025-04-13 17:16:21 rol_utils.py:82 dt:33.48 (29.9hz) dtRlead: 1.62 (618.2hz) dtWfoll: 0.22 (4540.0hz) dtRfoll: 2.39 (418.9hz) dtRlaptop:44.03 (22.7hz) dtRphone:44.78 (22.3hz)
# INFO 2025-04-13 17:16:21 rol_utils.py:82 dt:33.49 (29.9hz) dtRlead: 2.86 (349.1hz) dtWfoll: 0.52 (1913.3hz) dtRfoll: 1.89 (528.7hz) dtRlaptop:23.25 (43.0hz) dtRphone:22.82 (43.8hz)
# INFO 2025-04-13 17:16:21 rol_utils.py:82 dt:33.46 (29.9hz) dtRlead: 1.85 (541.1hz) dtWfoll: 0.62 (1612.0hz) dtRfoll: 1.86 (538.8hz) dtRlaptop:49.00 (20.4hz) dtRphone:49.46 (20.2hz)
# INFO 2025-04-13 17:16:21 rol_utils.py:82 dt:33.42 (29.9hz) dtRlead: 1.54 (650.5hz) dtWfoll: 0.28 (3531.2hz) dtRfoll: 1.67 (597.5hz) dtRlaptop:21.72 (46.0hz) dtRphone:20.93 (47.8hz)
# INFO 2025-04-13 17:16:21 rol_utils.py:82 dt:33.42 (29.9hz) dtRlead: 1.93 (518.8hz) dtWfoll: 0.37 (2676.3hz) dtRfoll: 1.82 (549.8hz) dtRlaptop:25.28 (39.6hz) dtRphone:25.14 (39.8hz)
# INFO 2025-04-13 17:16:21 rol_utils.py:82 dt:33.65 (29.7hz) dtRlead: 2.04 (489.4hz) dtWfoll: 0.45 (2227.3hz) dtRfoll: 2.46 (406.6hz) dtRlaptop:42.66 (23.4hz) dtRphone:42.94 (23.3hz)
# INFO 2025-04-13 17:16:21 rol_utils.py:82 dt:33.52 (29.8hz) dtRlead: 2.55 (392.9hz) dtWfoll: 0.65 (1536.3hz) dtRfoll: 2.06 (485.4hz) dtRlaptop:37.39 (26.7hz) dtRphone:37.57 (26.6hz)
# INFO 2025-04-13 17:16:21 rol_utils.py:82 dt:33.49 (29.9hz) dtRlead: 2.45 (408.4hz) dtWfoll: 1.09 (918.0hz) dtRfoll: 2.60 (384.1hz) dtRlaptop:28.53 (35.0hz) dtRphone:28.85 (34.7hz)
# INFO 2025-04-13 17:16:21 rol_utils.py:82 dt:33.43 (29.9hz) dtRlead: 1.97 (506.4hz) dtWfoll: 0.52 (1927.0hz) dtRfoll: 1.98 (505.7hz) dtRlaptop:35.52 (28.2hz) dtRphone:35.50 (28.2hz)
# INFO 2025-04-13 17:16:21 rol_utils.py:82 dt:33.43 (29.9hz) dtRlead: 2.10 (475.1hz) dtWfoll: 0.54 (1845.8hz) dtRfoll: 2.07 (482.7hz) dtRlaptop:33.77 (29.6hz) dtRphone:32.51 (30.8hz)
# INFO 2025-04-13 17:16:21 rol_utils.py:82 dt:33.45 (29.9hz) dtRlead: 2.25 (445.0hz) dtWfoll: 0.81 (1239.9hz) dtRfoll: 2.02 (495.6hz) dtRlaptop:33.04 (30.3hz) dtRphone:33.02 (30.3hz)
# INFO 2025-04-13 17:16:21 rol_utils.py:82 dt:33.44 (29.9hz) dtRlead: 2.40 (416.0hz) dtWfoll: 0.75 (1324.8hz) dtRfoll: 2.34 (427.8hz) dtRlaptop:37.13 (26.9hz) dtRphone:37.85 (26.4hz)
# INFO 2025-04-13 17:16:21 rol_utils.py:82 dt:33.45 (29.9hz) dtRlead: 2.51 (399.0hz) dtWfoll: 0.72 (1386.9hz) dtRfoll: 2.22 (450.6hz) dtRlaptop:31.86 (31.4hz) dtRphone:31.95 (31.3hz)
# INFO 2025-04-13 17:16:21 rol_utils.py:82 dt:33.41 (29.9hz) dtRlead: 2.09 (479.6hz) dtWfoll: 0.46 (2190.3hz) dtRfoll: 1.78 (560.4hz) dtRlaptop:31.85 (31.4hz) dtRphone:31.79 (31.5hz)
# INFO 2025-04-13 17:16:21 rol_utils.py:82 dt:33.42 (29.9hz) dtRlead: 1.93 (517.5hz) dtWfoll: 0.36 (2756.4hz) dtRfoll: 1.81 (553.2hz) dtRlaptop:30.86 (32.4hz) dtRphone:30.63 (32.6hz)
# INFO 2025-04-13 17:16:21 rol_utils.py:82 dt:33.42 (29.9hz) dtRlead: 2.69 (371.8hz) dtWfoll: 0.68 (1472.7hz) dtRfoll: 2.55 (392.1hz) dtRlaptop:35.29 (28.3hz) dtRphone:35.64 (28.1hz)
# INFO 2025-04-13 17:16:21 rol_utils.py:82 dt:33.43 (29.9hz) dtRlead: 2.02 (494.3hz) dtWfoll: 0.40 (2480.0hz) dtRfoll: 1.86 (538.4hz) dtRlaptop:33.22 (30.1hz) dtRphone:33.20 (30.1hz)
# INFO 2025-04-13 17:16:21 rol_utils.py:82 dt:33.45 (29.9hz) dtRlead: 1.84 (543.9hz) dtWfoll: 0.39 (2557.5hz) dtRfoll: 1.58 (634.2hz) dtRlaptop:36.94 (27.1hz) dtRphone:37.04 (27.0hz)
# INFO 2025-04-13 17:16:21 rol_utils.py:82 dt:33.36 (30.0hz) dtRlead: 1.67 (599.1hz) dtWfoll: 0.27 (3768.7hz) dtRfoll: 1.57 (637.1hz) dtRlaptop:27.49 (36.4hz) dtRphone:27.32 (36.6hz)
# INFO 2025-04-13 17:16:21 rol_utils.py:82 dt:33.41 (29.9hz) dtRlead: 1.68 (593.9hz) dtWfoll: 0.30 (3306.7hz) dtRfoll: 1.70 (586.6hz) dtRlaptop:29.19 (34.3hz) dtRphone:29.60 (33.8hz)
# INFO 2025-04-13 17:16:21 rol_utils.py:82 dt:33.41 (29.9hz) dtRlead: 1.62 (616.3hz) dtWfoll: 0.24 (4223.6hz) dtRfoll: 1.75 (570.1hz) dtRlaptop:29.51 (33.9hz) dtRphone:29.51 (33.9hz)
# INFO 2025-04-13 17:16:21 rol_utils.py:82 dt:33.42 (29.9hz) dtRlead: 2.11 (474.6hz) dtWfoll: 0.51 (1953.5hz) dtRfoll: 1.88 (530.8hz) dtRlaptop:29.51 (33.9hz) dtRphone:29.51 (33.9hz)
# INFO 2025-04-13 17:16:21 rol_utils.py:82 dt:33.44 (29.9hz) dtRlead: 1.69 (590.8hz) dtWfoll: 0.22 (4489.4hz) dtRfoll: 1.62 (617.3hz) dtRlaptop:21.06 (47.5hz) dtRphone:20.65 (48.4hz)
# INFO 2025-04-13 17:16:21 rol_utils.py:82 dt:33.42 (29.9hz) dtRlead: 2.10 (475.9hz) dtWfoll: 0.49 (2053.4hz) dtRfoll: 1.91 (523.7hz) dtRlaptop:21.06 (47.5hz) dtRphone:20.65 (48.4hz)
# INFO 2025-04-13 17:16:21 rol_utils.py:82 dt:33.45 (29.9hz) dtRlead: 1.72 (582.0hz) dtWfoll: 0.28 (3516.9hz) dtRfoll: 1.73 (577.9hz) dtRlaptop:24.85 (40.2hz) dtRphone:24.78 (40.4hz)
# INFO 2025-04-13 17:16:22 rol_utils.py:82 dt:33.41 (29.9hz) dtRlead: 1.60 (624.3hz) dtWfoll: 0.25 (3973.4hz) dtRfoll: 1.61 (621.3hz) dtRlaptop:32.94 (30.4hz) dtRphone:32.90 (30.4hz)
# INFO 2025-04-13 17:16:22 rol_utils.py:82 dt:33.41 (29.9hz) dtRlead: 1.91 (522.6hz) dtWfoll: 0.32 (3093.6hz) dtRfoll: 1.67 (598.4hz) dtRlaptop:35.26 (28.4hz) dtRphone:36.07 (27.7hz)
# INFO 2025-04-13 17:16:22 rol_utils.py:82 dt:33.41 (29.9hz) dtRlead: 1.96 (509.2hz) dtWfoll: 0.37 (2688.1hz) dtRfoll: 1.72 (582.8hz) dtRlaptop:35.26 (28.4hz) dtRphone:36.07 (27.7hz)
# INFO 2025-04-13 17:16:22 rol_utils.py:82 dt:33.40 (29.9hz) dtRlead: 1.70 (589.5hz) dtWfoll: 0.24 (4130.0hz) dtRfoll: 1.69 (592.8hz) dtRlaptop:24.37 (41.0hz) dtRphone:23.95 (41.8hz)
# INFO 2025-04-13 17:16:22 rol_utils.py:82 dt:33.42 (29.9hz) dtRlead: 1.69 (591.2hz) dtWfoll: 0.25 (4072.4hz) dtRfoll: 1.67 (598.5hz) dtRlaptop:33.64 (29.7hz) dtRphone:23.95 (41.8hz)
# INFO 2025-04-13 17:16:22 rol_utils.py:82 dt:33.44 (29.9hz) dtRlead: 2.09 (478.0hz) dtWfoll: 0.44 (2275.4hz) dtRfoll: 1.82 (548.4hz) dtRlaptop:33.64 (29.7hz) dtRphone:33.93 (29.5hz)
# INFO 2025-04-13 17:16:22 rol_utils.py:82 dt:33.41 (29.9hz) dtRlead: 1.84 (542.6hz) dtWfoll: 0.38 (2625.7hz) dtRfoll: 1.83 (547.6hz) dtRlaptop:41.53 (24.1hz) dtRphone:41.53 (24.1hz)
# INFO 2025-04-13 17:16:22 rol_utils.py:82 dt:33.42 (29.9hz) dtRlead: 1.71 (585.8hz) dtWfoll: 0.27 (3677.0hz) dtRfoll: 1.65 (605.3hz) dtRlaptop:29.39 (34.0hz) dtRphone:29.20 (34.2hz)
# INFO 2025-04-13 17:16:22 rol_utils.py:82 dt:33.43 (29.9hz) dtRlead: 1.95 (512.1hz) dtWfoll: 0.40 (2531.3hz) dtRfoll: 1.99 (501.6hz) dtRlaptop:29.39 (34.0hz) dtRphone:29.20 (34.2hz)
# INFO 2025-04-13 17:16:22 rol_utils.py:82 dt:33.44 (29.9hz) dtRlead: 1.99 (502.7hz) dtWfoll: 0.33 (2999.8hz) dtRfoll: 1.82 (550.4hz) dtRlaptop:23.50 (42.6hz) dtRphone:23.10 (43.3hz)
# INFO 2025-04-13 17:16:22 rol_utils.py:82 dt:33.44 (29.9hz) dtRlead: 1.95 (513.1hz) dtWfoll: 0.49 (2024.8hz) dtRfoll: 1.84 (543.3hz) dtRlaptop:23.50 (42.6hz) dtRphone:23.10 (43.3hz)
# INFO 2025-04-13 17:16:22 rol_utils.py:82 dt:33.49 (29.9hz) dtRlead: 2.09 (478.9hz) dtWfoll: 0.48 (2064.8hz) dtRfoll: 1.87 (534.9hz) dtRlaptop:42.00 (23.8hz) dtRphone:42.05 (23.8hz)
# INFO 2025-04-13 17:16:22 rol_utils.py:82 dt:33.41 (29.9hz) dtRlead: 2.37 (422.5hz) dtWfoll: 0.81 (1228.9hz) dtRfoll: 1.84 (542.8hz) dtRlaptop:31.70 (31.5hz) dtRphone:31.47 (31.8hz)
# INFO 2025-04-13 17:16:22 rol_utils.py:82 dt:33.42 (29.9hz) dtRlead: 1.60 (626.7hz) dtWfoll: 0.22 (4533.0hz) dtRfoll: 1.80 (554.5hz) dtRlaptop:34.79 (28.7hz) dtRphone:35.19 (28.4hz)
# INFO 2025-04-13 17:16:22 rol_utils.py:82 dt:33.42 (29.9hz) dtRlead: 1.87 (533.5hz) dtWfoll: 0.27 (3673.1hz) dtRfoll: 1.75 (572.5hz) dtRlaptop:33.77 (29.6hz) dtRphone:32.95 (30.3hz)
# INFO 2025-04-13 17:16:22 rol_utils.py:82 dt:33.41 (29.9hz) dtRlead: 1.76 (568.9hz) dtWfoll: 0.24 (4171.7hz) dtRfoll: 1.69 (590.4hz) dtRlaptop:23.96 (41.7hz) dtRphone:24.11 (41.5hz)
# INFO 2025-04-13 17:16:22 rol_utils.py:82 dt:33.41 (29.9hz) dtRlead: 1.52 (657.3hz) dtWfoll: 0.24 (4175.4hz) dtRfoll: 1.74 (574.8hz) dtRlaptop:23.96 (41.7hz) dtRphone:24.11 (41.5hz)
# INFO 2025-04-13 17:16:22 rol_utils.py:82 dt:33.41 (29.9hz) dtRlead: 1.68 (596.0hz) dtWfoll: 0.27 (3704.4hz) dtRfoll: 1.69 (592.7hz) dtRlaptop:32.17 (31.1hz) dtRphone:31.90 (31.3hz)
# INFO 2025-04-13 17:16:22 rol_utils.py:82 dt:33.42 (29.9hz) dtRlead: 1.64 (611.5hz) dtWfoll: 0.26 (3835.0hz) dtRfoll: 1.66 (601.5hz) dtRlaptop:30.03 (33.3hz) dtRphone:29.96 (33.4hz)
# INFO 2025-04-13 17:16:22 rol_utils.py:82 dt:33.47 (29.9hz) dtRlead: 2.03 (492.0hz) dtWfoll: 0.58 (1726.4hz) dtRfoll: 1.87 (536.0hz) dtRlaptop:30.03 (33.3hz) dtRphone:29.96 (33.4hz)
# INFO 2025-04-13 17:16:22 rol_utils.py:82 dt:33.41 (29.9hz) dtRlead: 1.73 (579.5hz) dtWfoll: 0.30 (3362.9hz) dtRfoll: 1.65 (606.7hz) dtRlaptop:19.25 (51.9hz) dtRphone:19.58 (51.1hz)
# INFO 2025-04-13 17:16:22 rol_utils.py:82 dt:33.42 (29.9hz) dtRlead: 1.75 (571.0hz) dtWfoll: 0.30 (3373.5hz) dtRfoll: 1.70 (589.2hz) dtRlaptop:35.84 (27.9hz) dtRphone:35.94 (27.8hz)
# INFO 2025-04-13 17:16:22 rol_utils.py:82 dt:33.40 (29.9hz) dtRlead: 2.07 (483.8hz) dtWfoll: 0.55 (1827.5hz) dtRfoll: 2.02 (495.9hz) dtRlaptop:35.84 (27.9hz) dtRphone:35.94 (27.8hz)
# INFO 2025-04-13 17:16:22 rol_utils.py:82 dt:33.48 (29.9hz) dtRlead: 1.72 (579.9hz) dtWfoll: 0.20 (4895.2hz) dtRfoll: 1.81 (552.8hz) dtRlaptop:21.11 (47.4hz) dtRphone:20.55 (48.7hz)
# INFO 2025-04-13 17:16:22 rol_utils.py:82 dt:33.42 (29.9hz) dtRlead: 1.85 (541.2hz) dtWfoll: 0.29 (3459.4hz) dtRfoll: 1.80 (554.7hz) dtRlaptop:35.76 (28.0hz) dtRphone:35.83 (27.9hz)
# INFO 2025-04-13 17:16:22 rol_utils.py:82 dt:33.49 (29.9hz) dtRlead: 2.02 (494.1hz) dtWfoll: 0.55 (1829.5hz) dtRfoll: 1.79 (558.0hz) dtRlaptop:35.63 (28.1hz) dtRphone:35.89 (27.9hz)
# INFO 2025-04-13 17:16:22 rol_utils.py:82 dt:33.41 (29.9hz) dtRlead: 1.75 (570.9hz) dtWfoll: 0.28 (3635.9hz) dtRfoll: 1.68 (594.7hz) dtRlaptop:26.79 (37.3hz) dtRphone:26.53 (37.7hz)
# INFO 2025-04-13 17:16:22 rol_utils.py:82 dt:33.41 (29.9hz) dtRlead: 1.68 (596.4hz) dtWfoll: 0.28 (3608.5hz) dtRfoll: 1.68 (595.0hz) dtRlaptop:37.98 (26.3hz) dtRphone:37.98 (26.3hz)
# INFO 2025-04-13 17:16:22 rol_utils.py:82 dt:33.41 (29.9hz) dtRlead: 1.84 (544.1hz) dtWfoll: 0.34 (2933.0hz) dtRfoll: 1.78 (561.1hz) dtRlaptop:34.56 (28.9hz) dtRphone:35.03 (28.5hz)
# INFO 2025-04-13 17:16:22 rol_utils.py:82 dt:33.47 (29.9hz) dtRlead: 1.74 (573.6hz) dtWfoll: 0.19 (5194.4hz) dtRfoll: 1.97 (508.1hz) dtRlaptop:32.54 (30.7hz) dtRphone:31.92 (31.3hz)
# Right arrow key pressed. Exiting loop...
# INFO 2025-04-13 17:16:23 rol_utils.py:82 dt:33.42 (29.9hz) dtRlead: 1.93 (518.5hz) dtWfoll: 0.40 (2488.2hz) dtRfoll: 1.91 (523.2hz) dtRlaptop:32.25 (31.0hz) dtRphone:32.52 (30.8hz)
# INFO 2025-04-13 17:16:23 ls/utils.py:200 Recording episode 307
# INFO 2025-04-13 17:16:23 rol_utils.py:82 dt:33.40 (29.9hz) dtRlead: 1.64 (608.9hz) dtWfoll: 0.19 (5206.7hz) dtRfoll: 1.67 (600.1hz) dtRlaptop:26.52 (37.7hz) dtRphone:26.62 (37.6hz)
# INFO 2025-04-13 17:16:23 rol_utils.py:82 dt:33.40 (29.9hz) dtRlead: 1.60 (624.6hz) dtWfoll: 0.22 (4467.0hz) dtRfoll: 1.71 (585.5hz) dtRlaptop:30.79 (32.5hz) dtRphone:30.77 (32.5hz)
# INFO 2025-04-13 17:16:23 rol_utils.py:82 dt:33.46 (29.9hz) dtRlead: 1.68 (596.4hz) dtWfoll: 0.22 (4496.2hz) dtRfoll: 1.74 (576.4hz) dtRlaptop:36.38 (27.5hz) dtRphone:36.35 (27.5hz)
# INFO 2025-04-13 17:16:23 rol_utils.py:82 dt:33.40 (29.9hz) dtRlead: 1.66 (603.4hz) dtWfoll: 0.23 (4375.9hz) dtRfoll: 1.74 (576.2hz) dtRlaptop:31.96 (31.3hz) dtRphone:32.06 (31.2hz)
# INFO 2025-04-13 17:16:23 rol_utils.py:82 dt:33.40 (29.9hz) dtRlead: 1.70 (589.8hz) dtWfoll: 0.24 (4237.6hz) dtRfoll: 1.74 (573.2hz) dtRlaptop:32.31 (31.0hz) dtRphone:32.13 (31.1hz)
# INFO 2025-04-13 17:16:23 rol_utils.py:82 dt:33.40 (29.9hz) dtRlead: 1.76 (569.8hz) dtWfoll: 0.31 (3244.7hz) dtRfoll: 1.65 (606.9hz) dtRlaptop:35.67 (28.0hz) dtRphone:35.43 (28.2hz)
# INFO 2025-04-13 17:16:23 rol_utils.py:82 dt:33.40 (29.9hz) dtRlead: 1.71 (583.8hz) dtWfoll: 0.20 (4966.2hz) dtRfoll: 1.68 (595.1hz) dtRlaptop:31.64 (31.6hz) dtRphone:32.07 (31.2hz)
# INFO 2025-04-13 17:16:23 rol_utils.py:82 dt:33.40 (29.9hz) dtRlead: 1.63 (612.7hz) dtWfoll: 0.21 (4824.5hz) dtRfoll: 1.69 (591.1hz) dtRlaptop:31.67 (31.6hz) dtRphone:31.61 (31.6hz)
# ...
# INFO 2025-04-13 17:16:34 rol_utils.py:82 dt:33.44 (29.9hz) dtRlead: 1.60 (625.7hz) dtWfoll: 0.24 (4171.3hz) dtRfoll: 1.60 (626.1hz) dtRlaptop:31.93 (31.3hz) dtRphone:31.98 (31.3hz)
# INFO 2025-04-13 17:16:34 rol_utils.py:82 dt:33.44 (29.9hz) dtRlead: 1.57 (638.4hz) dtWfoll: 0.32 (3108.6hz) dtRfoll: 1.63 (615.1hz) dtRlaptop:36.00 (27.8hz) dtRphone:36.04 (27.7hz)
# INFO 2025-04-13 17:16:34 rol_utils.py:82 dt:33.44 (29.9hz) dtRlead: 1.61 (619.5hz) dtWfoll: 0.32 (3160.7hz) dtRfoll: 1.56 (639.2hz) dtRlaptop:32.75 (30.5hz) dtRphone:33.01 (30.3hz)
# INFO 2025-04-13 17:16:34 rol_utils.py:82 dt:33.40 (29.9hz) dtRlead: 1.67 (598.9hz) dtWfoll: 0.27 (3713.1hz) dtRfoll: 1.67 (598.6hz) dtRlaptop:30.68 (32.6hz) dtRphone:30.58 (32.7hz)
# INFO 2025-04-13 17:16:34 rol_utils.py:82 dt:33.41 (29.9hz) dtRlead: 1.63 (614.3hz) dtWfoll: 0.28 (3528.3hz) dtRfoll: 1.67 (597.5hz) dtRlaptop:38.02 (26.3hz) dtRphone:38.22 (26.2hz)
# INFO 2025-04-13 17:16:34 rol_utils.py:82 dt:33.40 (29.9hz) dtRlead: 1.65 (605.4hz) dtWfoll: 0.28 (3541.4hz) dtRfoll: 1.59 (628.3hz) dtRlaptop:31.15 (32.1hz) dtRphone:30.77 (32.5hz)
# INFO 2025-04-13 17:16:34 rol_utils.py:82 dt:33.40 (29.9hz) dtRlead: 1.65 (605.1hz) dtWfoll: 0.23 (4312.5hz) dtRfoll: 1.61 (621.2hz) dtRlaptop:31.05 (32.2hz) dtRphone:31.19 (32.1hz)
# INFO 2025-04-13 17:16:34 rol_utils.py:82 dt:33.40 (29.9hz) dtRlead: 1.66 (602.6hz) dtWfoll: 0.19 (5358.9hz) dtRfoll: 1.72 (582.8hz) dtRlaptop:37.94 (26.4hz) dtRphone:37.87 (26.4hz)
# INFO 2025-04-13 17:16:34 rol_utils.py:82 dt:33.44 (29.9hz) dtRlead: 1.62 (618.1hz) dtWfoll: 0.20 (4895.6hz) dtRfoll: 1.67 (599.5hz) dtRlaptop:30.63 (32.6hz) dtRphone:30.48 (32.8hz)
# INFO 2025-04-13 17:16:34 rol_utils.py:82 dt:33.44 (29.9hz) dtRlead: 1.71 (585.7hz) dtWfoll: 0.25 (4040.6hz) dtRfoll: 1.70 (587.2hz) dtRlaptop:32.35 (30.9hz) dtRphone:32.36 (30.9hz)
# INFO 2025-04-13 17:16:34 rol_utils.py:82 dt:33.45 (29.9hz) dtRlead: 1.68 (596.0hz) dtWfoll: 0.25 (4056.1hz) dtRfoll: 1.67 (597.3hz) dtRlaptop:35.23 (28.4hz) dtRphone:35.24 (28.4hz)
# INFO 2025-04-13 17:16:34 rol_utils.py:82 dt:33.39 (29.9hz) dtRlead: 1.70 (589.1hz) dtWfoll: 0.20 (5000.7hz) dtRfoll: 1.66 (603.1hz) dtRlaptop:32.32 (30.9hz) dtRphone:32.42 (30.8hz)
# INFO 2025-04-13 17:16:34 rol_utils.py:82 dt:33.45 (29.9hz) dtRlead: 1.63 (614.3hz) dtWfoll: 0.24 (4128.2hz) dtRfoll: 1.65 (605.4hz) dtRlaptop:33.39 (30.0hz) dtRphone:33.42 (29.9hz)
# INFO 2025-04-13 17:16:34 rol_utils.py:82 dt:33.45 (29.9hz) dtRlead: 1.73 (576.8hz) dtWfoll: 0.29 (3404.5hz) dtRfoll: 1.66 (601.0hz) dtRlaptop:35.86 (27.9hz) dtRphone:35.86 (27.9hz)
# INFO 2025-04-13 17:16:34 rol_utils.py:82 dt:33.40 (29.9hz) dtRlead: 1.75 (572.2hz) dtWfoll: 0.26 (3815.6hz) dtRfoll: 1.69 (591.7hz) dtRlaptop:30.67 (32.6hz) dtRphone:30.61 (32.7hz)
# INFO 2025-04-13 17:16:34 rol_utils.py:82 dt:33.40 (29.9hz) dtRlead: 1.64 (610.6hz) dtWfoll: 0.25 (4012.3hz) dtRfoll: 1.71 (585.4hz) dtRlaptop:32.98 (30.3hz) dtRphone:33.02 (30.3hz)
# INFO 2025-04-13 17:16:34 rol_utils.py:82 dt:33.40 (29.9hz) dtRlead: 1.62 (618.8hz) dtWfoll: 0.23 (4442.0hz) dtRfoll: 1.57 (637.5hz) dtRlaptop:34.62 (28.9hz) dtRphone:34.55 (28.9hz)
# INFO 2025-04-13 17:16:35 rol_utils.py:82 dt:33.40 (29.9hz) dtRlead: 1.56 (640.5hz) dtWfoll: 0.25 (4060.1hz) dtRfoll: 1.64 (609.0hz) dtRlaptop:32.19 (31.1hz) dtRphone:32.27 (31.0hz)
# INFO 2025-04-13 17:16:35 rol_utils.py:82 dt:33.40 (29.9hz) dtRlead: 1.63 (615.0hz) dtWfoll: 0.23 (4430.4hz) dtRfoll: 1.70 (589.8hz) dtRlaptop:36.22 (27.6hz) dtRphone:36.13 (27.7hz)
# INFO 2025-04-13 17:16:35 rol_utils.py:82 dt:33.40 (29.9hz) dtRlead: 1.71 (585.8hz) dtWfoll: 0.26 (3868.7hz) dtRfoll: 1.56 (643.0hz) dtRlaptop:31.74 (31.5hz) dtRphone:31.72 (31.5hz)
# INFO 2025-04-13 17:16:35 rol_utils.py:82 dt:33.40 (29.9hz) dtRlead: 1.62 (616.0hz) dtWfoll: 0.16 (6232.2hz) dtRfoll: 1.66 (603.4hz) dtRlaptop:31.80 (31.4hz) dtRphone:31.84 (31.4hz)
# INFO 2025-04-13 17:16:35 rol_utils.py:82 dt:33.40 (29.9hz) dtRlead: 1.58 (631.3hz) dtWfoll: 0.23 (4401.1hz) dtRfoll: 1.65 (606.1hz) dtRlaptop:36.27 (27.6hz) dtRphone:36.10 (27.7hz)
# INFO 2025-04-13 17:16:35 rol_utils.py:82 dt:33.44 (29.9hz) dtRlead: 1.72 (581.0hz) dtWfoll: 0.26 (3876.6hz) dtRfoll: 1.63 (614.1hz) dtRlaptop:32.14 (31.1hz) dtRphone:32.11 (31.1hz)
# INFO 2025-04-13 17:16:35 rol_utils.py:82 dt:33.40 (29.9hz) dtRlead: 1.71 (584.1hz) dtWfoll: 0.27 (3690.9hz) dtRfoll: 1.73 (577.9hz) dtRlaptop:33.50 (29.8hz) dtRphone:33.51 (29.8hz)
# INFO 2025-04-13 17:16:35 rol_utils.py:82 dt:33.40 (29.9hz) dtRlead: 1.64 (609.7hz) dtWfoll: 0.17 (5898.5hz) dtRfoll: 1.65 (605.8hz) dtRlaptop:34.45 (29.0hz) dtRphone:34.44 (29.0hz)
# INFO 2025-04-13 17:16:35 rol_utils.py:82 dt:33.40 (29.9hz) dtRlead: 1.60 (623.5hz) dtWfoll: 0.28 (3602.2hz) dtRfoll: 1.75 (571.3hz) dtRlaptop:32.56 (30.7hz) dtRphone:32.54 (30.7hz)
# INFO 2025-04-13 17:16:35 rol_utils.py:82 dt:33.40 (29.9hz) dtRlead: 1.78 (562.2hz) dtWfoll: 0.24 (4177.2hz) dtRfoll: 1.66 (600.8hz) dtRlaptop:33.10 (30.2hz) dtRphone:33.24 (30.1hz)
# INFO 2025-04-13 17:16:35 rol_utils.py:82 dt:33.40 (29.9hz) dtRlead: 1.73 (578.6hz) dtWfoll: 0.21 (4752.1hz) dtRfoll: 1.65 (607.8hz) dtRlaptop:34.41 (29.1hz) dtRphone:34.31 (29.1hz)
# INFO 2025-04-13 17:16:35 rol_utils.py:82 dt:33.45 (29.9hz) dtRlead: 1.62 (616.1hz) dtWfoll: 0.27 (3694.8hz) dtRfoll: 1.74 (573.9hz) dtRlaptop:33.59 (29.8hz) dtRphone:33.52 (29.8hz)
# INFO 2025-04-13 17:16:35 rol_utils.py:82 dt:33.45 (29.9hz) dtRlead: 1.84 (544.7hz) dtWfoll: 0.28 (3558.3hz) dtRfoll: 1.73 (578.3hz) dtRlaptop:30.63 (32.6hz) dtRphone:30.99 (32.3hz)
# INFO 2025-04-13 17:16:35 rol_utils.py:82 dt:33.40 (29.9hz) dtRlead: 1.68 (596.7hz) dtWfoll: 0.19 (5254.1hz) dtRfoll: 2.00 (498.8hz) dtRlaptop:35.10 (28.5hz) dtRphone:35.06 (28.5hz)
# INFO 2025-04-13 17:16:35 rol_utils.py:82 dt:33.40 (29.9hz) dtRlead: 1.56 (642.4hz) dtWfoll: 0.19 (5375.0hz) dtRfoll: 1.63 (613.9hz) dtRlaptop:32.21 (31.0hz) dtRphone:32.21 (31.0hz)
# INFO 2025-04-13 17:16:35 rol_utils.py:82 dt:33.44 (29.9hz) dtRlead: 1.66 (603.4hz) dtWfoll: 0.18 (5667.3hz) dtRfoll: 1.63 (614.2hz) dtRlaptop:35.58 (28.1hz) dtRphone:35.55 (28.1hz)
# INFO 2025-04-13 17:16:35 rol_utils.py:82 dt:33.40 (29.9hz) dtRlead: 1.68 (596.6hz) dtWfoll: 0.24 (4218.3hz) dtRfoll: 1.70 (589.5hz) dtRlaptop:32.24 (31.0hz) dtRphone:32.16 (31.1hz)
# INFO 2025-04-13 17:16:35 rol_utils.py:82 dt:33.40 (29.9hz) dtRlead: 1.68 (595.4hz) dtWfoll: 0.21 (4732.5hz) dtRfoll: 1.60 (623.3hz) dtRlaptop:32.55 (30.7hz) dtRphone:32.58 (30.7hz)
# INFO 2025-04-13 17:16:35 rol_utils.py:82 dt:33.46 (29.9hz) dtRlead: 1.65 (606.4hz) dtWfoll: 0.24 (4207.2hz) dtRfoll: 1.73 (577.4hz) dtRlaptop:35.65 (28.0hz) dtRphone:35.67 (28.0hz)
# INFO 2025-04-13 17:16:35 rol_utils.py:82 dt:33.40 (29.9hz) dtRlead: 1.76 (567.9hz) dtWfoll: 0.31 (3241.2hz) dtRfoll: 1.82 (550.0hz) dtRlaptop:32.17 (31.1hz) dtRphone:32.15 (31.1hz)
# INFO 2025-04-13 17:16:35 rol_utils.py:82 dt:33.40 (29.9hz) dtRlead: 1.83 (545.6hz) dtWfoll: 0.29 (3489.4hz) dtRfoll: 1.74 (575.4hz) dtRlaptop:33.07 (30.2hz) dtRphone:33.23 (30.1hz)
# INFO 2025-04-13 17:16:35 rol_utils.py:82 dt:33.40 (29.9hz) dtRlead: 1.69 (590.9hz) dtWfoll: 0.26 (3807.4hz) dtRfoll: 1.66 (603.4hz) dtRlaptop:35.30 (28.3hz) dtRphone:35.30 (28.3hz)
# INFO 2025-04-13 17:16:35 rol_utils.py:82 dt:33.40 (29.9hz) dtRlead: 1.75 (572.7hz) dtWfoll: 0.26 (3902.5hz) dtRfoll: 2.09 (477.8hz) dtRlaptop:31.13 (32.1hz) dtRphone:31.06 (32.2hz)
# INFO 2025-04-13 17:16:35 rol_utils.py:82 dt:33.41 (29.9hz) dtRlead: 1.64 (608.7hz) dtWfoll: 0.20 (5105.3hz) dtRfoll: 1.67 (600.6hz) dtRlaptop:31.80 (31.5hz) dtRphone:32.13 (31.1hz)
# INFO 2025-04-13 17:16:35 rol_utils.py:82 dt:33.40 (29.9hz) dtRlead: 1.61 (620.4hz) dtWfoll: 0.23 (4322.8hz) dtRfoll: 1.66 (601.5hz) dtRlaptop:36.06 (27.7hz) dtRphone:36.03 (27.8hz)
# INFO 2025-04-13 17:16:35 rol_utils.py:82 dt:33.40 (29.9hz) dtRlead: 1.64 (611.6hz) dtWfoll: 0.25 (3923.2hz) dtRfoll: 1.70 (586.6hz) dtRlaptop:32.04 (31.2hz) dtRphone:31.96 (31.3hz)
# INFO 2025-04-13 17:16:35 rol_utils.py:82 dt:33.38 (30.0hz) dtRlead: 1.80 (554.7hz) dtWfoll: 0.25 (4077.2hz) dtRfoll: 1.76 (567.5hz) dtRlaptop:32.06 (31.2hz) dtRphone:32.01 (31.2hz)
# INFO 2025-04-13 17:16:35 rol_utils.py:82 dt:33.43 (29.9hz) dtRlead: 1.76 (566.6hz) dtWfoll: 0.30 (3334.8hz) dtRfoll: 1.83 (547.4hz) dtRlaptop:35.87 (27.9hz) dtRphone:35.96 (27.8hz)
# INFO 2025-04-13 17:16:35 rol_utils.py:82 dt:33.44 (29.9hz) dtRlead: 1.76 (569.0hz) dtWfoll: 0.25 (4020.1hz) dtRfoll: 1.74 (573.7hz) dtRlaptop:31.86 (31.4hz) dtRphone:31.85 (31.4hz)
# INFO 2025-04-13 17:16:35 rol_utils.py:82 dt:33.41 (29.9hz) dtRlead: 1.72 (581.2hz) dtWfoll: 0.31 (3222.4hz) dtRfoll: 1.68 (593.7hz) dtRlaptop:38.01 (26.3hz) dtRphone:38.01 (26.3hz)
# INFO 2025-04-13 17:16:36 rol_utils.py:82 dt:33.40 (29.9hz) dtRlead: 1.84 (542.1hz) dtWfoll: 0.34 (2953.6hz) dtRfoll: 1.76 (569.4hz) dtRlaptop:30.27 (33.0hz) dtRphone:30.25 (33.1hz)
# Right arrow key pressed. Exiting loop...
# INFO 2025-04-13 17:16:36 rol_utils.py:82 dt:33.47 (29.9hz) dtRlead: 1.79 (559.0hz) dtWfoll: 0.34 (2902.7hz) dtRfoll: 1.83 (545.8hz) dtRlaptop:31.94 (31.3hz) dtRphone:31.97 (31.3hz)
# Map: 100%|███████████████████████████| 389/389 [00:00<00:00, 5174.87 examples/s]
# Creating parquet from Arrow format: 100%|███████| 1/1 [00:00<00:00, 2165.36ba/s]
# Svt[info]: -------------------------------------------
# Svt[info]: SVT [version]:	SVT-AV1 Encoder Lib v3.0.0
# Svt[info]: SVT [build]  :	GCC 13.3.0	 64 bit
# Svt[info]: LIB Build date: Feb 21 2025 00:07:10
# Svt[info]: -------------------------------------------
# Svt[info]: Level of Parallelism: 6
# Svt[info]: Number of PPCS 305
# Svt[info]: [asm level on system : up to avx2]
# Svt[info]: [asm level selected : up to avx2]
# Svt[info]: -------------------------------------------
# Svt[info]: SVT [config]: main profile	tier (auto)	level (auto)
# Svt[info]: SVT [config]: width / height / fps numerator / fps denominator 		: 640 / 480 / 30 / 1
# Svt[info]: SVT [config]: bit-depth / color format 					: 8 / YUV420
# Svt[info]: SVT [config]: preset / tune / pred struct 					: 8 / PSNR / random access
# Svt[info]: SVT [config]: gop size / mini-gop size / key-frame type 			: 2 / 32 / key frame
# Svt[info]: SVT [config]: BRC mode / rate factor 					: CRF / 30
# Svt[info]: SVT [config]: AQ mode / variance boost 					: 2 / 0
# Svt[info]: SVT [config]: sharpness / luminance-based QP bias 			: 0 / 0
# Svt[info]: Svt[info]: -------------------------------------------
# Svt[info]: -------------------------------------------
# Svt[info]: SVT [version]:	SVT-AV1 Encoder Lib v3.0.0
# Svt[info]: SVT [build]  :	GCC 13.3.0	 64 bit
# Svt[info]: LIB Build date: Feb 21 2025 00:07:10
# Svt[info]: -------------------------------------------
# Svt[info]: Level of Parallelism: 6
# Svt[info]: Number of PPCS 305
# Svt[info]: [asm level on system : up to avx2]
# Svt[info]: [asm level selected : up to avx2]
# Svt[info]: -------------------------------------------
# Svt[info]: SVT [config]: main profile	tier (auto)	level (auto)
# Svt[info]: SVT [config]: width / height / fps numerator / fps denominator 		: 640 / 480 / 30 / 1
# Svt[info]: SVT [config]: bit-depth / color format 					: 8 / YUV420
# Svt[info]: SVT [config]: preset / tune / pred struct 					: 8 / PSNR / random access
# Svt[info]: SVT [config]: gop size / mini-gop size / key-frame type 			: 2 / 32 / key frame
# Svt[info]: SVT [config]: BRC mode / rate factor 					: CRF / 30
# Svt[info]: SVT [config]: AQ mode / variance boost 					: 2 / 0
# Svt[info]: SVT [config]: sharpness / luminance-based QP bias 			: 0 / 0
# Svt[info]: Svt[info]: -------------------------------------------
# INFO 2025-04-13 17:16:39 ls/utils.py:200 Stop recording
# It seems you are trying to upload a large folder at once. This might take some time and then fail if the folder is too large. For such cases, it is recommended to upload in smaller batches or to use `HfApi().upload_large_folder(...)`/`huggingface-cli upload-large-folder` instead. For more details, check out https://huggingface.co/docs/huggingface_hub/main/en/guides/upload#upload-a-large-folder.
# WARNING 2025-04-13 17:16:41 /hf_api.py:9196 It seems you are trying to upload a large folder at once. This might take some time and then fail if the folder is too large. For such cases, it is recommended to upload in smaller batches or to use `HfApi().upload_large_folder(...)`/`huggingface-cli upload-large-folder` instead. For more details, check out https://huggingface.co/docs/huggingface_hub/main/en/guides/upload#upload-a-large-folder.
# episode_000306.parquet:   0%|                       | 0.00/3.94k [00:00<?, ?B/s]
# episode_000307.parquet:   0%|                       | 0.00/22.7k [00:00<?, ?B/s]
#
# episode_000306.mp4:   0%|                            | 0.00/259k [00:00<?, ?B/s]
#
#
# episode_000307.mp4:   0%|                           | 0.00/6.43M [00:00<?, ?B/s]
#
#
#
# Upload 6 LFS files:   0%|                                 | 0/6 [00:00<?, ?it/s]
#
#
#
#
# episode_000306.mp4:   0%|                            | 0.00/408k [00:00<?, ?B/s]
#
#
#
#
# episode_000306.mp4:  76%|███████████████▏    | 311k/408k [00:00<00:00, 2.88MB/s]
#
#
# episode_000306.parquet: 100%|██████████████| 3.94k/3.94k [00:00<00:00, 13.1kB/s]
#
#
#
# episode_000307.mp4:   9%|█▋                 | 590k/6.43M [00:00<00:03, 1.58MB/s]
#
#
# episode_000307.mp4:  14%|██▌                | 868k/6.43M [00:00<00:03, 1.74MB/s]
#
#
# episode_000307.mp4:  19%|███▍              | 1.25M/6.43M [00:00<00:02, 2.17MB/s]
#
#
#
# episode_000307.mp4:   0%|                           | 0.00/6.40M [00:00<?, ?B/s]
#
#
# episode_000307.parquet: 100%|██████████████| 22.7k/22.7k [00:00<00:00, 23.9kB/s]
# episode_000306.mp4: 100%|█████████████████████| 259k/259k [00:00<00:00, 271kB/s]
#
#
#
# episode_000307.mp4:   5%|▉                  | 311k/6.40M [00:00<00:04, 1.25MB/s]
#
#
# episode_000306.mp4: 100%|█████████████████████| 408k/408k [00:01<00:00, 353kB/s]
# episode_000307.mp4:   7%|█▎                 | 442k/6.40M [00:00<00:05, 1.07MB/s]
#
#
# episode_000307.mp4:   9%|█▋                 | 573k/6.40M [00:00<00:05, 1.09MB/s]
#
#
#
# episode_000307.mp4:  13%|██▍                | 819k/6.40M [00:00<00:04, 1.24MB/s]
#
#
# episode_000307.mp4:  24%|████▏             | 1.51M/6.40M [00:01<00:03, 1.54MB/s]
#
#
# episode_000307.mp4:  29%|█████▏            | 1.85M/6.40M [00:01<00:03, 1.38MB/s]
#
#
# episode_000307.mp4:  33%|█████▉            | 2.11M/6.40M [00:01<00:03, 1.41MB/s]
#
#
# episode_000307.mp4:  40%|███████▏          | 2.56M/6.40M [00:01<00:02, 1.39MB/s]
#
#
# episode_000307.mp4:  42%|███████▌          | 2.70M/6.40M [00:01<00:02, 1.40MB/s]
#
#
# episode_000307.mp4:  45%|████████          | 2.88M/6.40M [00:02<00:03, 1.13MB/s]
#
#
# episode_000307.mp4:  49%|████████▊         | 3.15M/6.40M [00:02<00:03, 1.08MB/s]
#
#
# episode_000307.mp4:  51%|█████████▏        | 3.26M/6.40M [00:02<00:03, 1.03MB/s]
#
#
# episode_000307.mp4:  57%|██████████▎       | 3.65M/6.40M [00:02<00:02, 1.25MB/s]
#
#
# episode_000307.mp4:  59%|██████████▋       | 3.78M/6.40M [00:03<00:02, 1.13MB/s]
#
#
# episode_000307.mp4:  65%|███████████▋      | 4.16M/6.40M [00:03<00:02, 1.11MB/s]
#
#
# episode_000307.mp4:  67%|████████████      | 4.29M/6.40M [00:03<00:01, 1.11MB/s]
#
#
# episode_000307.mp4:  71%|████████████▊     | 4.54M/6.40M [00:03<00:01, 1.12MB/s]
#
#
# episode_000307.mp4:  75%|█████████████▍    | 4.80M/6.40M [00:03<00:01, 1.18MB/s]
#
#
# episode_000307.mp4: 100%|██████████████████| 6.43M/6.43M [00:05<00:00, 1.14MB/s]
#
#
#
#
# episode_000307.mp4: 100%|██████████████████| 6.40M/6.40M [00:05<00:00, 1.23MB/s]
#
#
#
#
# Upload 6 LFS files: 100%|█████████████████████████| 6/6 [00:06<00:00,  1.04s/it]
# INFO 2025-04-13 17:17:02 ls/utils.py:200 Exiting
# Loaded home positions from /home/jacob/lerobot/.cache/calibration/so100/blue_home_position.json
# Connected to blue robot on port /dev/ttyACM2
# Calibration loaded.
# Moving to preset position...
# Positions after moving to preset:
#   shoulder_pan: -0.09
#   shoulder_lift: 163.39
#   elbow_flex: 123.93
#   wrist_flex: 78.93
#   wrist_roll: -100.81
#   gripper: 0.38
# Moving to home position...
# Final positions (home):
#   shoulder_pan: -0.97
#   shoulder_lift: 180.97
#   elbow_flex: 134.56
#   wrist_flex: 84.29
#   wrist_roll: -88.33
#   gripper: 0.38
# Disconnected.

# %%
while True:
    move_blue()
    home_blue()
    next_move()

    move_red()
    home_red()
    next_move()
# Out:
# Removing existing folder: /home/jacob/.cache/huggingface/lerobot/Chojins/eval_chess_game_001_blue_stereo
# INFO 2025-04-04 18:55:04 ol_robot.py:369 {'control': {'display_cameras': True,
#              'episode_time_s': 30,
#              'fps': 30,
#              'num_episodes': 1,
#              'num_image_writer_processes': 0,
#              'num_image_writer_threads_per_camera': 4,
#              'play_sounds': True,
#              'policy': {'chunk_size': 100,
#                         'device': 'cuda',
#                         'dim_feedforward': 3200,
#                         'dim_model': 512,
#                         'dropout': 0.1,
#                         'feedforward_activation': 'relu',
#                         'input_features': {'observation.images.laptop': {'shape': (3,
#                                                                                    480,
#                                                                                    640),
#                                                                          'type': <FeatureType.VISUAL: 'VISUAL'>},
#                                            'observation.images.phone': {'shape': (3,
#                                                                                   480,
#                                                                                   640),
# Loaded home positions from /home/jacob/lerobot/.cache/calibration/so100/blue_home_position.json
# Connected to blue robot on port /dev/ttyACM2
# Calibration loaded.
# Moving to preset position...
# Positions after moving to preset:
#   shoulder_pan: 0.26
#   shoulder_lift: 163.65
#   elbow_flex: 123.49
#   wrist_flex: 78.93
#   wrist_roll: -100.81
#   gripper: 0.23
# Moving to home position...
# Final positions (home):
#   shoulder_pan: -1.14
#   shoulder_lift: 180.97
#   elbow_flex: 134.56
#   wrist_flex: 84.38
#   wrist_roll: -88.33
#   gripper: 0.23
# Disconnected.
# Found window ID for 'Black side': 6291663
# Found window ID for 'White side': 6291667
# Active window now: White side
# Removing existing folder: /home/jacob/.cache/huggingface/lerobot/Chojins/eval_chess_game_001_red_stereo
# INFO 2025-04-04 18:55:20 ol_robot.py:369 {'control': {'display_cameras': True,
#              'episode_time_s': 30,
#              'fps': 30,
#              'num_episodes': 1,
#              'num_image_writer_processes': 0,
#              'num_image_writer_threads_per_camera': 4,
#              'play_sounds': True,
#              'policy': {'chunk_size': 100,
#                         'device': 'cuda',
#                         'dim_feedforward': 3200,
#                         'dim_model': 512,
#                         'dropout': 0.1,
#                         'feedforward_activation': 'relu',
#                         'input_features': {'observation.images.laptop': {'shape': (3,
#                                                                                    480,
#                                                                                    640),
#                                                                          'type': <FeatureType.VISUAL: 'VISUAL'>},
#                                            'observation.images.phone': {'shape': (3,
#                                                                                   480,
#                                                                                   640),
# Loaded home positions from /home/jacob/lerobot/.cache/calibration/so100/red_home_position.json
# Connected to red robot on port /dev/ttyACM1
# Calibration loaded.
# Moving to preset position...
# Positions after moving to preset:
#   shoulder_pan: -0.44
#   shoulder_lift: 163.39
#   elbow_flex: 123.84
#   wrist_flex: 78.93
#   wrist_roll: -100.72
#   gripper: 0.51
# Moving to home position...
# Final positions (home):
#   shoulder_pan: -0.53
#   shoulder_lift: 179.21
#   elbow_flex: 131.57
#   wrist_flex: 87.19
#   wrist_roll: -90.09
#   gripper: 0.73
# Disconnected.
# Found window ID for 'Black side': 6291663
# Found window ID for 'White side': 6291667
# Active window now: White side
# Removing existing folder: /home/jacob/.cache/huggingface/lerobot/Chojins/eval_chess_game_001_blue_stereo
# INFO 2025-04-04 18:55:37 ol_robot.py:369 {'control': {'display_cameras': True,
#              'episode_time_s': 30,
#              'fps': 30,
#              'num_episodes': 1,
#              'num_image_writer_processes': 0,
#              'num_image_writer_threads_per_camera': 4,
#              'play_sounds': True,
#              'policy': {'chunk_size': 100,
#                         'device': 'cuda',
#                         'dim_feedforward': 3200,
#                         'dim_model': 512,
#                         'dropout': 0.1,
#                         'feedforward_activation': 'relu',
#                         'input_features': {'observation.images.laptop': {'shape': (3,
#                                                                                    480,
#                                                                                    640),
#                                                                          'type': <FeatureType.VISUAL: 'VISUAL'>},
#                                            'observation.images.phone': {'shape': (3,
#                                                                                   480,
#                                                                                   640),
# Loaded home positions from /home/jacob/lerobot/.cache/calibration/so100/blue_home_position.json
# Connected to blue robot on port /dev/ttyACM2
# Calibration loaded.
# Moving to preset position...
# Positions after moving to preset:
#   shoulder_pan: 0.44
#   shoulder_lift: 163.56
#   elbow_flex: 123.84
#   wrist_flex: 78.93
#   wrist_roll: -100.81
#   gripper: 0.23
# Moving to home position...
# Final positions (home):
#   shoulder_pan: -0.97
#   shoulder_lift: 180.97
#   elbow_flex: 134.56
#   wrist_flex: 84.46
#   wrist_roll: -88.33
#   gripper: 0.23
# Disconnected.
# Found window ID for 'Black side': 6291663
# Found window ID for 'White side': 6291667
# Active window now: White side
# Removing existing folder: /home/jacob/.cache/huggingface/lerobot/Chojins/eval_chess_game_001_red_stereo
# INFO 2025-04-04 18:55:55 ol_robot.py:369 {'control': {'display_cameras': True,
#              'episode_time_s': 30,
#              'fps': 30,
#              'num_episodes': 1,
#              'num_image_writer_processes': 0,
#              'num_image_writer_threads_per_camera': 4,
#              'play_sounds': True,
#              'policy': {'chunk_size': 100,
#                         'device': 'cuda',
#                         'dim_feedforward': 3200,
#                         'dim_model': 512,
#                         'dropout': 0.1,
#                         'feedforward_activation': 'relu',
#                         'input_features': {'observation.images.laptop': {'shape': (3,
#                                                                                    480,
#                                                                                    640),
#                                                                          'type': <FeatureType.VISUAL: 'VISUAL'>},
#                                            'observation.images.phone': {'shape': (3,
#                                                                                   480,
#                                                                                   640),
# Loaded home positions from /home/jacob/lerobot/.cache/calibration/so100/red_home_position.json
# Connected to red robot on port /dev/ttyACM1
# Calibration loaded.
# Moving to preset position...
# Positions after moving to preset:
#   shoulder_pan: -0.44
#   shoulder_lift: 163.39
#   elbow_flex: 123.84
#   wrist_flex: 78.93
#   wrist_roll: -100.81
#   gripper: 0.51
# Moving to home position...
# Final positions (home):
#   shoulder_pan: -0.53
#   shoulder_lift: 179.30
#   elbow_flex: 131.57
#   wrist_flex: 87.28
#   wrist_roll: -90.09
#   gripper: 0.73
# Disconnected.
# Found window ID for 'Black side': 6291663
# Found window ID for 'White side': 6291667
# Active window now: White side
# Removing existing folder: /home/jacob/.cache/huggingface/lerobot/Chojins/eval_chess_game_001_blue_stereo
# INFO 2025-04-04 18:56:15 ol_robot.py:369 {'control': {'display_cameras': True,
#              'episode_time_s': 30,
#              'fps': 30,
#              'num_episodes': 1,
#              'num_image_writer_processes': 0,
#              'num_image_writer_threads_per_camera': 4,
#              'play_sounds': True,
#              'policy': {'chunk_size': 100,
#                         'device': 'cuda',
#                         'dim_feedforward': 3200,
#                         'dim_model': 512,
#                         'dropout': 0.1,
#                         'feedforward_activation': 'relu',
#                         'input_features': {'observation.images.laptop': {'shape': (3,
#                                                                                    480,
#                                                                                    640),
#                                                                          'type': <FeatureType.VISUAL: 'VISUAL'>},
#                                            'observation.images.phone': {'shape': (3,
#                                                                                   480,
#                                                                                   640),
# Loaded home positions from /home/jacob/lerobot/.cache/calibration/so100/blue_home_position.json
# Connected to blue robot on port /dev/ttyACM2
# Calibration loaded.
# Moving to preset position...
# Positions after moving to preset:
#   shoulder_pan: -0.18
#   shoulder_lift: 163.65
#   elbow_flex: 123.84
#   wrist_flex: 78.93
#   wrist_roll: -100.81
#   gripper: 0.15
# Moving to home position...
# Final positions (home):
#   shoulder_pan: -1.14
#   shoulder_lift: 180.97
#   elbow_flex: 134.56
#   wrist_flex: 84.38
#   wrist_roll: -88.33
#   gripper: 0.15
# Disconnected.
# Found window ID for 'Black side': 6291663
# Found window ID for 'White side': 6291667
# Active window now: White side
# Removing existing folder: /home/jacob/.cache/huggingface/lerobot/Chojins/eval_chess_game_001_red_stereo
# INFO 2025-04-04 18:56:35 ol_robot.py:369 {'control': {'display_cameras': True,
#              'episode_time_s': 30,
#              'fps': 30,
#              'num_episodes': 1,
#              'num_image_writer_processes': 0,
#              'num_image_writer_threads_per_camera': 4,
#              'play_sounds': True,
#              'policy': {'chunk_size': 100,
#                         'device': 'cuda',
#                         'dim_feedforward': 3200,
#                         'dim_model': 512,
#                         'dropout': 0.1,
#                         'feedforward_activation': 'relu',
#                         'input_features': {'observation.images.laptop': {'shape': (3,
#                                                                                    480,
#                                                                                    640),
#                                                                          'type': <FeatureType.VISUAL: 'VISUAL'>},
#                                            'observation.images.phone': {'shape': (3,
#                                                                                   480,
#                                                                                   640),
# Loaded home positions from /home/jacob/lerobot/.cache/calibration/so100/red_home_position.json
# Connected to red robot on port /dev/ttyACM1
# Calibration loaded.
# Moving to preset position...
# Positions after moving to preset:
#   shoulder_pan: -0.44
#   shoulder_lift: 163.39
#   elbow_flex: 123.84
#   wrist_flex: 78.93
#   wrist_roll: -100.81
#   gripper: 0.29
# Moving to home position...
# Final positions (home):
#   shoulder_pan: -0.53
#   shoulder_lift: 179.30
#   elbow_flex: 131.66
#   wrist_flex: 87.28
#   wrist_roll: -90.09
#   gripper: 0.59
# Disconnected.
# Found window ID for 'Black side': 6291663
# Found window ID for 'White side': 6291667
# Active window now: White side
# Removing existing folder: /home/jacob/.cache/huggingface/lerobot/Chojins/eval_chess_game_001_blue_stereo
# INFO 2025-04-04 18:56:55 ol_robot.py:369 {'control': {'display_cameras': True,
#              'episode_time_s': 30,
#              'fps': 30,
#              'num_episodes': 1,
#              'num_image_writer_processes': 0,
#              'num_image_writer_threads_per_camera': 4,
#              'play_sounds': True,
#              'policy': {'chunk_size': 100,
#                         'device': 'cuda',
#                         'dim_feedforward': 3200,
#                         'dim_model': 512,
#                         'dropout': 0.1,
#                         'feedforward_activation': 'relu',
#                         'input_features': {'observation.images.laptop': {'shape': (3,
#                                                                                    480,
#                                                                                    640),
#                                                                          'type': <FeatureType.VISUAL: 'VISUAL'>},
#                                            'observation.images.phone': {'shape': (3,
#                                                                                   480,
#                                                                                   640),
# Loaded home positions from /home/jacob/lerobot/.cache/calibration/so100/blue_home_position.json
# Connected to blue robot on port /dev/ttyACM2
# Calibration loaded.
# Moving to preset position...
# Positions after moving to preset:
#   shoulder_pan: -0.18
#   shoulder_lift: 163.48
#   elbow_flex: 123.49
#   wrist_flex: 78.93
#   wrist_roll: -100.81
#   gripper: 0.15
# Moving to home position...
# Final positions (home):
#   shoulder_pan: -0.97
#   shoulder_lift: 180.97
#   elbow_flex: 134.56
#   wrist_flex: 84.38
#   wrist_roll: -88.42
#   gripper: 0.15
# Disconnected.
# Found window ID for 'Black side': 6291663
# Found window ID for 'White side': 6291667
# Active window now: White side
# Removing existing folder: /home/jacob/.cache/huggingface/lerobot/Chojins/eval_chess_game_001_red_stereo
# INFO 2025-04-04 18:57:10 ol_robot.py:369 {'control': {'display_cameras': True,
#              'episode_time_s': 30,
#              'fps': 30,
#              'num_episodes': 1,
#              'num_image_writer_processes': 0,
#              'num_image_writer_threads_per_camera': 4,
#              'play_sounds': True,
#              'policy': {'chunk_size': 100,
#                         'device': 'cuda',
#                         'dim_feedforward': 3200,
#                         'dim_model': 512,
#                         'dropout': 0.1,
#                         'feedforward_activation': 'relu',
#                         'input_features': {'observation.images.laptop': {'shape': (3,
#                                                                                    480,
#                                                                                    640),
#                                                                          'type': <FeatureType.VISUAL: 'VISUAL'>},
#                                            'observation.images.phone': {'shape': (3,
#                                                                                   480,
#                                                                                   640),
# Loaded home positions from /home/jacob/lerobot/.cache/calibration/so100/red_home_position.json
# Connected to red robot on port /dev/ttyACM1
# Calibration loaded.
# Moving to preset position...
# Positions after moving to preset:
#   shoulder_pan: -0.53
#   shoulder_lift: 163.39
#   elbow_flex: 123.93
#   wrist_flex: 79.01
#   wrist_roll: -100.81
#   gripper: 0.51
# Moving to home position...
# Final positions (home):
#   shoulder_pan: -0.53
#   shoulder_lift: 179.21
#   elbow_flex: 131.57
#   wrist_flex: 87.28
#   wrist_roll: -90.00
#   gripper: 0.73
# Disconnected.
# Found window ID for 'Black side': 6291663
# Found window ID for 'White side': 6291667
# Active window now: White side
# Removing existing folder: /home/jacob/.cache/huggingface/lerobot/Chojins/eval_chess_game_001_blue_stereo
# INFO 2025-04-04 18:57:27 ol_robot.py:369 {'control': {'display_cameras': True,
#              'episode_time_s': 30,
#              'fps': 30,
#              'num_episodes': 1,
#              'num_image_writer_processes': 0,
#              'num_image_writer_threads_per_camera': 4,
#              'play_sounds': True,
#              'policy': {'chunk_size': 100,
#                         'device': 'cuda',
#                         'dim_feedforward': 3200,
#                         'dim_model': 512,
#                         'dropout': 0.1,
#                         'feedforward_activation': 'relu',
#                         'input_features': {'observation.images.laptop': {'shape': (3,
#                                                                                    480,
#                                                                                    640),
#                                                                          'type': <FeatureType.VISUAL: 'VISUAL'>},
#                                            'observation.images.phone': {'shape': (3,
#                                                                                   480,
#                                                                                   640),
# Loaded home positions from /home/jacob/lerobot/.cache/calibration/so100/blue_home_position.json
# Connected to blue robot on port /dev/ttyACM2
# Calibration loaded.
# Moving to preset position...
# Positions after moving to preset:
#   shoulder_pan: 0.44
#   shoulder_lift: 163.56
#   elbow_flex: 123.84
#   wrist_flex: 78.93
#   wrist_roll: -100.81
#   gripper: 0.23
# Moving to home position...
# Final positions (home):
#   shoulder_pan: -0.97
#   shoulder_lift: 180.88
#   elbow_flex: 134.56
#   wrist_flex: 84.38
#   wrist_roll: -88.33
#   gripper: 0.23
# Disconnected.
# Found window ID for 'Black side': 6291663
# Found window ID for 'White side': 6291667
# Active window now: White side
# Removing existing folder: /home/jacob/.cache/huggingface/lerobot/Chojins/eval_chess_game_001_red_stereo
# INFO 2025-04-04 18:57:50 ol_robot.py:369 {'control': {'display_cameras': True,
#              'episode_time_s': 30,
#              'fps': 30,
#              'num_episodes': 1,
#              'num_image_writer_processes': 0,
#              'num_image_writer_threads_per_camera': 4,
#              'play_sounds': True,
#              'policy': {'chunk_size': 100,
#                         'device': 'cuda',
#                         'dim_feedforward': 3200,
#                         'dim_model': 512,
#                         'dropout': 0.1,
#                         'feedforward_activation': 'relu',
#                         'input_features': {'observation.images.laptop': {'shape': (3,
#                                                                                    480,
#                                                                                    640),
#                                                                          'type': <FeatureType.VISUAL: 'VISUAL'>},
#                                            'observation.images.phone': {'shape': (3,
#                                                                                   480,
#                                                                                   640),
# Loaded home positions from /home/jacob/lerobot/.cache/calibration/so100/red_home_position.json
# Connected to red robot on port /dev/ttyACM1
# Calibration loaded.
# Moving to preset position...
# Positions after moving to preset:
#   shoulder_pan: -0.44
#   shoulder_lift: 163.48
#   elbow_flex: 123.93
#   wrist_flex: 78.93
#   wrist_roll: -100.81
#   gripper: 0.51
# Moving to home position...
# Final positions (home):
#   shoulder_pan: -0.53
#   shoulder_lift: 179.30
#   elbow_flex: 131.57
#   wrist_flex: 87.10
#   wrist_roll: -90.00
#   gripper: 0.73
# Disconnected.
# Found window ID for 'Black side': 6291663
# Found window ID for 'White side': 6291667
# Active window now: White side
# Removing existing folder: /home/jacob/.cache/huggingface/lerobot/Chojins/eval_chess_game_001_blue_stereo
# INFO 2025-04-04 18:58:12 ol_robot.py:369 {'control': {'display_cameras': True,
#              'episode_time_s': 30,
#              'fps': 30,
#              'num_episodes': 1,
#              'num_image_writer_processes': 0,
#              'num_image_writer_threads_per_camera': 4,
#              'play_sounds': True,
#              'policy': {'chunk_size': 100,
#                         'device': 'cuda',
#                         'dim_feedforward': 3200,
#                         'dim_model': 512,
#                         'dropout': 0.1,
#                         'feedforward_activation': 'relu',
#                         'input_features': {'observation.images.laptop': {'shape': (3,
#                                                                                    480,
#                                                                                    640),
#                                                                          'type': <FeatureType.VISUAL: 'VISUAL'>},
#                                            'observation.images.phone': {'shape': (3,
#                                                                                   480,
#                                                                                   640),
# Loaded home positions from /home/jacob/lerobot/.cache/calibration/so100/blue_home_position.json
# Connected to blue robot on port /dev/ttyACM2
# Calibration loaded.
# Moving to preset position...
# Positions after moving to preset:
#   shoulder_pan: 0.44
#   shoulder_lift: 163.56
#   elbow_flex: 123.84
#   wrist_flex: 78.93
#   wrist_roll: -100.81
#   gripper: 0.23
# Moving to home position...
# Final positions (home):
#   shoulder_pan: -1.05
#   shoulder_lift: 180.97
#   elbow_flex: 134.56
#   wrist_flex: 84.46
#   wrist_roll: -88.33
#   gripper: 0.23
# Disconnected.
# Found window ID for 'Black side': 6291663
# Found window ID for 'White side': 6291667
# Active window now: White side
# Removing existing folder: /home/jacob/.cache/huggingface/lerobot/Chojins/eval_chess_game_001_red_stereo
# INFO 2025-04-04 18:58:29 ol_robot.py:369 {'control': {'display_cameras': True,
#              'episode_time_s': 30,
#              'fps': 30,
#              'num_episodes': 1,
#              'num_image_writer_processes': 0,
#              'num_image_writer_threads_per_camera': 4,
#              'play_sounds': True,
#              'policy': {'chunk_size': 100,
#                         'device': 'cuda',
#                         'dim_feedforward': 3200,
#                         'dim_model': 512,
#                         'dropout': 0.1,
#                         'feedforward_activation': 'relu',
#                         'input_features': {'observation.images.laptop': {'shape': (3,
#                                                                                    480,
#                                                                                    640),
#                                                                          'type': <FeatureType.VISUAL: 'VISUAL'>},
#                                            'observation.images.phone': {'shape': (3,
#                                                                                   480,
#                                                                                   640),
# Loaded home positions from /home/jacob/lerobot/.cache/calibration/so100/red_home_position.json
# Connected to red robot on port /dev/ttyACM1
# Calibration loaded.
# Moving to preset position...
# Positions after moving to preset:
#   shoulder_pan: -0.26
#   shoulder_lift: 163.39
#   elbow_flex: 123.93
#   wrist_flex: 79.10
#   wrist_roll: -100.72
#   gripper: 0.51
# Moving to home position...
# Final positions (home):
#   shoulder_pan: -0.35
#   shoulder_lift: 179.21
#   elbow_flex: 131.66
#   wrist_flex: 87.19
#   wrist_roll: -90.09
#   gripper: 0.73
# Disconnected.
# Found window ID for 'Black side': 6291663
# Found window ID for 'White side': 6291667
# Active window now: White side
# Removing existing folder: /home/jacob/.cache/huggingface/lerobot/Chojins/eval_chess_game_001_blue_stereo
# INFO 2025-04-04 18:58:46 ol_robot.py:369 {'control': {'display_cameras': True,
#              'episode_time_s': 30,
#              'fps': 30,
#              'num_episodes': 1,
#              'num_image_writer_processes': 0,
#              'num_image_writer_threads_per_camera': 4,
#              'play_sounds': True,
#              'policy': {'chunk_size': 100,
#                         'device': 'cuda',
#                         'dim_feedforward': 3200,
#                         'dim_model': 512,
#                         'dropout': 0.1,
#                         'feedforward_activation': 'relu',
#                         'input_features': {'observation.images.laptop': {'shape': (3,
#                                                                                    480,
#                                                                                    640),
#                                                                          'type': <FeatureType.VISUAL: 'VISUAL'>},
#                                            'observation.images.phone': {'shape': (3,
#                                                                                   480,
#                                                                                   640),
# ^C
# ^C
# Traceback (most recent call last):
#   File "/home/jacob/Documents/robot_control/move_home.py", line 8, in <module>
#     from lerobot.common.robot_devices.motors.feetech import FeetechMotorsBus
#   File "/home/jacob/lerobot/lerobot/common/robot_devices/motors/feetech.py", line 27, in <module>
#     from lerobot.common.utils.utils import capture_timestamp_utc
#   File "/home/jacob/lerobot/lerobot/common/utils/utils.py", line 26, in <module>
#     import torch
#   File "/home/jacob/miniconda3/envs/lerobot/lib/python3.10/site-packages/torch/__init__.py", line 411, in <module>
#     from torch._C import *  # noqa: F403
#   File "<frozen importlib._bootstrap>", line 216, in _lock_unlock_module
# KeyboardInterrupt
# Found window ID for 'Black side': 6291663
# Found window ID for 'White side': 6291667
# Active window now: Black side
# Removing existing folder: /home/jacob/.cache/huggingface/lerobot/Chojins/eval_chess_game_001_red_stereo
# ^C
# Traceback (most recent call last):
#   File "/home/jacob/Documents/robot_control/move_home.py", line 8, in <module>
#     from lerobot.common.robot_devices.motors.feetech import FeetechMotorsBus
#   File "/home/jacob/lerobot/lerobot/common/robot_devices/motors/feetech.py", line 22, in <module>
#     import numpy as np
#   File "/home/jacob/miniconda3/envs/lerobot/lib/python3.10/site-packages/numpy/__init__.py", line 181, in <module>
#     from . import lib
#   File "/home/jacob/miniconda3/envs/lerobot/lib/python3.10/site-packages/numpy/lib/__init__.py", line 36, in <module>
#     from . import _arraypad_impl
#   File "/home/jacob/miniconda3/envs/lerobot/lib/python3.10/site-packages/numpy/lib/_arraypad_impl.py", line 546, in <module>
#     def pad(array, pad_width, mode='constant', **kwargs):
#   File "/home/jacob/miniconda3/envs/lerobot/lib/python3.10/site-packages/numpy/_core/overrides.py", line 145, in decorator
#     verify_matching_signatures(implementation, dispatcher)
#   File "/home/jacob/miniconda3/envs/lerobot/lib/python3.10/site-packages/numpy/_core/overrides.py", line 85, in verify_matching_signatures
#     implementation_spec = ArgSpec(*getargspec(implementation))
#   File "<string>", line 1, in <lambda>
# KeyboardInterrupt
# Found window ID for 'Black side': 6291663
# Found window ID for 'White side': 6291667
# Active window now: White side
# Removing existing folder: /home/jacob/.cache/huggingface/lerobot/Chojins/eval_chess_game_001_blue_stereo
# KeyboardInterrupt

# %%
# Out:
# Found window ID for 'Black side': 6291460
# Found window ID for 'White side': 6291464
# Active window now: White side
